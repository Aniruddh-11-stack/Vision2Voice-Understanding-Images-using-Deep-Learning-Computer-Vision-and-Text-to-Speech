# %%
#import opendatasets as od

# %%
#'od.download("https://www.kaggle.com/datasets/adityajn105/flickr8k")'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#os library for dealing with files
import os
#used to store features extracted by vggnet -16
import pickle
#To deal with string data type
import string
#To create nueral networks
import tensorflow
#Libraries for computation and visualization
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from os import listdir
from pickle import dump
from keras.applications.vgg16 import VGG16
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.models import Model

# %%
os.getcwd()
# Out:
# '/content'

# %%
'''
#extract features from each photo in the directory
def extract_features(directory):
	# load the model
	model = VGG16()
	# re-structure the model
	model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
	# summarize
	print(model.summary())
	# extract features from each photo
	features = dict()
	for name in listdir(directory):
		# load an image from file
		filename = directory + '/' + name
		image = load_img(filename, target_size=(224, 224))
		# convert the image pixels to a numpy array
		image = img_to_array(image)
		# reshape data for the model
		image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
		# prepare the image for the VGG model
		image = preprocess_input(image)
		# get features
		feature = model.predict(image, verbose=0)
		# get image id
		image_id = name.split('.')[0]
		# store feature
		features[image_id] = feature
		print('>%s' % name)
	return features

# extract features from all images
directory = "flickr8K/Images"
features = extract_features(directory)
print('Extracted Features: %d' % len(features))
# save to file
dump(features, open('features.pkl', 'wb'))
'''
# Out:
# '\n#extract features from each photo in the directory\ndef extract_features(directory):\n\t# load the model\n\tmodel = VGG16()\n\t# re-structure the model\n\tmodel = Model(inputs=model.inputs, outputs=model.layers[-2].output)\n\t# summarize\n\tprint(model.summary())\n\t# extract features from each photo\n\tfeatures = dict()\n\tfor name in listdir(directory):\n\t\t# load an image from file\n\t\tfilename = directory + \'/\' + name\n\t\timage = load_img(filename, target_size=(224, 224))\n\t\t# convert the image pixels to a numpy array\n\t\timage = img_to_array(image)\n\t\t# reshape data for the model\n\t\timage = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))\n\t\t# prepare the image for the VGG model\n\t\timage = preprocess_input(image)\n\t\t# get features\n\t\tfeature = model.predict(image, verbose=0)\n\t\t# get image id\n\t\timage_id = name.split(\'.\')[0]\n\t\t# store feature\n\t\tfeatures[image_id] = feature\n\t\tprint(\'>%s\' % name)\n\treturn features\n\n# extract features from all images\ndirectory = "flickr8K/Images"\nfeatures = extract_features(directory)\nprint(\'Extracted Features: %d\' % len(features))\n# save to file\ndump(features, open(\'features.pkl\', \'wb\'))\n'

# %%
 #load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

filename =  '/content/drive/My Drive/Capstone Data/flickr8k/Flickr8k_text/Flickr8k.token.txt'
# load descriptions
doc = load_doc(filename)

# %%
# extract descriptions for images
def load_descriptions(doc):
	mapping = dict()
	# process lines
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		if len(line) < 2:
			continue
		# take the first token as the image id, the rest as the description
		image_id, image_desc = tokens[0], tokens[1:]
		# remove filename from image id
		image_id = image_id.split('.')[0]
		# convert description tokens back to string
		image_desc = ' '.join(image_desc)
		# create the list if needed
		if image_id not in mapping:
			mapping[image_id] = list()
		# store description
		mapping[image_id].append(image_desc)
	return mapping

# parse descriptions
descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))
# Out:
# Loaded: 8092

# %%
descriptions #print all the descriptions
# Out:
# {'1000268201_693b08cb0e': ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#   'A girl going into a wooden building .',
#   'A little girl climbing into a wooden playhouse .',
#   'A little girl climbing the stairs to her playhouse .',
#   'A little girl in a pink dress going into a wooden cabin .'],
#  '1001773457_577c3a7d70': ['A black dog and a spotted dog are fighting',
#   'A black dog and a tri-colored dog playing with each other on the road .',
#   'A black dog and a white dog with brown spots are staring at each other in the street .',
#   'Two dogs of different breeds looking at each other on the road .',
#   'Two dogs on pavement moving toward each other .'],
#  '1002674143_1b742ab4b8': ['A little girl covered in paint sits in front of a painted rainbow with her hands in a bowl .',
#   'A little girl is sitting in front of a large painted rainbow .',
#   'A small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it .',
#   'There is a girl with pigtails sitting in front of a rainbow painting .',
#   'Young girl with pigtails painting outside in the grass .'],
#  '1003163366_44323f5815': ['A man lays on a bench while his dog sits by him .',
#   'A man lays on the bench to which a white dog is also tied .',
#   'a man sleeping on a bench outside with a white and black dog sitting next to him .',
#   'A shirtless man lies on a park bench with his dog .',
#   'man laying on bench holding leash of dog sitting on ground'],
#  '1007129816_e794419615': ['A man in an orange hat starring at something .',
#   'A man wears an orange hat and glasses .',
#   'A man with gauges and glasses is wearing a Blitz hat .',
#   'A man with glasses is wearing a beer can crocheted hat .',
#   'The man with pierced ears is wearing glasses and an orange hat .'],
#  '1007320043_627395c3d8': ['A child playing on a rope net .',
#   'A little girl climbing on red roping .',
#   'A little girl in pink climbs a rope bridge at the park .',
#   'A small child grips onto the red ropes at the playground .',
#   'The small child climbs on a red ropes on a playground .'],
#  '1009434119_febe49276a': ['A black and white dog is running in a grassy garden surrounded by a white fence .',
#   'A black and white dog is running through the grass .',
#   'A Boston terrier is running in the grass .',
#   'A Boston Terrier is running on lush green grass in front of a white fence .',
#   'A dog runs on the green grass near a wooden fence .'],
#  '1012212859_01547e3f17': ['A dog shakes its head near the shore , a red ball next to it .',
#   'A white dog shakes on the edge of a beach with an orange ball .',
#   'Dog with orange ball at feet , stands on shore shaking off water',
#   'White dog playing with a red ball on the shore near the water .',
#   'White dog with brown ears standing near water with head turned to one side .'],
#  '1015118661_980735411b': ['A boy smiles in front of a stony wall in a city .',
#   'A little boy is standing on the street while a man in overalls is working on a stone wall .',
#   'A young boy runs aross the street .',
#   'A young child is walking on a stone paved street with a metal pole and a man behind him .',
#   'Smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him .'],
#  '1015584366_dfcec3c85a': ['A black dog leaps over a log .',
#   'A grey dog is leaping over a fallen tree .',
#   'A large black dog leaps a fallen log .',
#   'A mottled black and grey dog in a blue collar jumping over a fallen tree .',
#   'The black dog jumped the tree stump .'],
#  '101654506_8eb26cfb60': ['A brown and white dog is running through the snow .',
#   'A dog is running in the snow',
#   'A dog running through snow .',
#   'a white and brown dog is running through a snow covered field .',
#   'The white and brown dog is running over the surface of the snow .'],
#  '101669240_b2d3e7f17b': ['A man in a hat is displaying pictures next to a skier in a blue hat .',
#   'A man skis past another man displaying paintings in the snow .',
#   'A person wearing skis looking at framed pictures set up in the snow .',
#   'A skier looks at framed pictures in the snow next to trees .',
#   'Man on skis looking at artwork for sale in the snow'],
#  '1016887272_03199f49c4': ['A collage of one person climbing a cliff .',
#   'A group of people are rock climbing on a rock climbing wall .',
#   'A group of people climbing a rock while one man belays',
#   'Seven climbers are ascending a rock face whilst another man stands holding the rope .',
#   'Several climbers in a row are climbing the rock while the man in red watches and holds the line .'],
#  '1019077836_6fc9b15408': ['A brown dog chases the water from a sprinkler on a lawn .',
#   'a brown dog plays with the hose .',
#   'A brown dog running on a lawn near a garden hose',
#   'A dog is playing with a hose .',
#   'Large brown dog running away from the sprinkler in the grass .'],
#  '1019604187_d087bf9a5f': ['A dog prepares to catch a thrown object in a field with nearby cars .',
#   'A white dog is about to catch a yellow ball in its mouth .',
#   'A white dog is about to catch a yellow dog toy .',
#   'A white dog is ready to catch a yellow ball flying through the air .',
#   'A white dog running after a yellow ball'],
#  '1020651753_06077ec457': ['a black and white dog jumping in the air to get a toy .',
#   'A black and white dog jumps up towards a yellow toy .',
#   'A dog leaps to catch a ball in a field .',
#   'A white dog is trying to catch a ball in midair over a grassy field .',
#   'The white dog is playing in a green field with a yellow toy .'],
#  '1022454332_6af2c1449a': ['A child and a woman are at waters edge in a big city .',
#   'a large lake with a lone duck swimming in it with several people around the edge of it .',
#   'A little boy at a lake watching a duck .',
#   'A young boy waves his hand at the duck in the water surrounded by a green park .',
#   'Two people are at the edge of a lake , facing the water and the city skyline .'],
#  '1022454428_b6b660a67b': ['A couple and an infant , being held by the male , sitting next to a pond with a near by stroller .',
#   'A couple sit on the grass with a baby and stroller .',
#   'A couple with their newborn baby sitting under a tree facing a lake .',
#   'A man and woman care for an infant along the side of a body of water .',
#   'Couple with a baby sit outdoors next to their stroller .'],
#  '1022975728_75515238d8': ['A black dog running in the surf .',
#   'A black lab with tags frolicks in the water .',
#   'A dog splashes in the water',
#   'The black dog runs through the water .',
#   'This is a black dog splashing in the water .'],
#  '102351840_323e3de834': ['A man drilling a hole in the ice .',
#   'A man is drilling through the frozen ice of a pond .',
#   'A person in the snow drilling a hole in the ice .',
#   'A person standing on a frozen lake .',
#   'Two men are ice fishing .'],
#  '1024138940_f1fefbdce1': ['Two different breeds of brown and white dogs play on the beach .',
#   'Two dogs are making a turn on a soft sand beach .',
#   'Two dogs playing in the sand at the beach .',
#   'Two dogs playing together on a beach .',
#   'Two large tan dogs play along a sandy beach .'],
#  '102455176_5f8ead62d5': ['A man uses ice picks and crampons to scale ice .',
#   'an ice climber in a blue jacket and black pants is scaling a frozen ice wall .',
#   'An ice climber scaling a frozen waterfall .',
#   'A person in blue and red ice climbing with two picks .',
#   'Climber climbing an ice wall'],
#  '1026685415_0431cbf574': ['A black dog carries a green toy in his mouth as he walks through the grass .',
#   'A black dog carrying something through the grass .',
#   'A black dog has a blue toy in its mouth .',
#   'A dog in grass with a blue item in his mouth .',
#   'A wet black dog is carrying a green toy through the grass .'],
#  '1028205764_7e8df9a2ea': ['A man and a baby are in a yellow kayak on water .',
#   'A man and a little boy in blue life jackets are rowing a yellow canoe .',
#   'A man and child kayak through gentle waters .',
#   'A man and young boy ride in a yellow kayak .',
#   'Man and child in yellow kayak'],
#  '1030985833_b0902ea560': ['A black dog and a brown dog are jumping up to catch a red toy .',
#   'A black dog and a brown dog play with a red toy on a courtyard .',
#   'A brown and black lab are outside and the black lab is catching a toy in its mouth .',
#   'Black dog snaps at red and black object as brown dog lunges .',
#   'The Chocolate Lab jumps too late to get the toy as the Black Lab captures it in the driveway .'],
#  '103106960_e8a41d64f8': ['A boy with a stick kneeling in front of a goalie net',
#   'A child in a red jacket playing street hockey guarding a goal .',
#   'A young kid playing the goalie in a hockey rink .',
#   'A young male kneeling in front of a hockey goal with a hockey stick in his right hand .',
#   'Hockey goalie boy in red jacket crouches by goal , with stick .'],
#  '103195344_5d2dc613a3': ['A man in black is sitting next to a modern art structure in front of a glass building .',
#   'A man sits and reads a newspaper by a sculpture outside of an office building .',
#   'a man sits near a large statue .',
#   'A man sitting in front of a metal sculpture in front of a building .',
#   'The man with the backpack is sitting in a buildings courtyard in front of an art sculpture reading .'],
#  '103205630_682ca7285b': ['A tent is being set up on the ice .',
#   'Two men are about to enter an ice fishing tent on a snow covered lake .',
#   'two men setting up a blue ice fishing hut on an iced over lake',
#   'Two men , standing on an ice , looking into something covered with a blue tarp .',
#   'Two people standing outside a blue tent structure on a snowy surface .'],
#  '1032122270_ea6f0beedb': ['A woman crouches near three dogs in a field .',
#   'Three dogs are playing on grassy hill with a blue sky .',
#   'Three dogs are standing in the grass and a person is sitting next to them',
#   'Three dogs on a grassy hill',
#   'Three dogs stand in a grassy field while a person kneels nearby .'],
#  '1032460886_4a598ed535': ['a man is standing in front of a skyscraper',
#   'A man stands in front of a skyscraper .',
#   'A man stands in front of a very tall building .',
#   'Behind the man in a red shirt stands a large skyscraper .',
#   'There is a skyscraper in the distance with a man walking in front of the camera .'],
#  '1034276567_49bb87c51c': ['A boy bites hard into a treat while he sits outside .',
#   'A child biting into a baked good .',
#   'A small boy putting something in his mouth with both hands .',
#   'The boy eats his food outside at the table .',
#   'The boy is eating pizza over a tin dish .'],
#  '104136873_5b5d41be75': ['People sit on the mountainside and check out the view .',
#   'Three people are on a hilltop overlooking a green valley .',
#   'Three people hang out on top of a big hill .',
#   'Three people overlook a green valley .',
#   'Three people rest on a ledge above the moutains .'],
#  '1042020065_fb3d3ba5ba': ['A boy in a green shirt is looking down at many inflatable boats .',
#   'A boy in a green shirt watches kayakers .',
#   'A boy looks over a railing at the many boats and rafts below in the water .',
#   'A young boy overlooking a crowd of inflatable boats .',
#   'A young boy wearing a jersey looks down over a ledge at many boats in the water .'],
#  '1042590306_95dea0916c': ['A man and woman pose for the camera while another man looks on .',
#   'A man is holding the hand of a woman up to his mouth in front of some buildings while another man looks on .',
#   'A multiracial couple posing for a picture',
#   'Asian man and blond woman holding hands outdoors , man in background watches .',
#   'Guy in blue shirt biting hand of girl in black striped jacket while another guy watches'],
#  '1045521051_108ebc19be': ['A person eats takeout while watching a small television .',
#   'A person sits on the floor and eats in front of a television .',
#   'A television with a picture of a girl on it .',
#   'A young man sits on the floor by the television with a fast food meal in front of him .',
#   'Someone is laying in front of the TV eating food .'],
#  '1048710776_bb5b0a5c7c': ['a couple of several people sitting on a ledge overlooking the beach',
#   'A group of people sit on a wall at the beach .',
#   'A group of teens sit on a wall by a beach .',
#   'Crowd of people at the beach .',
#   'Several young people sitting on a rail above a crowded beach .'],
#  '1052358063_eae6744153': ['A boy takes a jump on his skateboard while another boy with a skateboard watches .',
#   'A child is performing a skateboard trick while another child with a skateboard leans on a wall .',
#   'A little boy skateboarder is doing a trick on his board while another young skateboarder watches .',
#   'a young boy skateboarder jumping on a platform on a skateboard .',
#   'Two skateboarders .'],
#  '105342180_4d4a40b47f': ['A girl paddling down a large river , as seen from behind her .',
#   'A woman kayaking down a river .',
#   'A woman paddles a boat down a river .',
#   'A woman with a paddle .',
#   'A woman with a paddle sits in a boat on the water .'],
#  '1053804096_ad278b25f1': ['A girl in pigtails splashes in the shallow water .',
#   'A girls plays in the surf .',
#   'a girl with pigtails is playing in the ocean by the beach .',
#   'A girl with pigtails plays in the water .',
#   'A young girl in pigtails plays in the water .'],
#  '1055623002_8195a43714': ['A group of four children wearing pajamas have a pillow fight .',
#   'A group of kids have a pillow-fight .',
#   'A group of young children playing pillow fight on a bed .',
#   'Children having a pillow fight .',
#   'Four children are having a pillow fight .'],
#  '1055753357_4fa3d8d693': ['Two constructions workers sit on a beam taking a break .',
#   'Two construction workers are sitting up on the side of a building .',
#   'Two construction workers sitting on an I-beam .',
#   'Two construction workers take a seat on a steel beam .',
#   'Two men take a break from construction .'],
#  '1056249424_ef2a2e041c': ['The children are playing in the water .',
#   'Two boys , one with a yellow and orange ball , play in some water in front of a field .',
#   'Two boys play in a puddle .',
#   'Two children play with a balloon in mud on a sunny day .',
#   'Two kids are running and playing in some water .'],
#  '1056338697_4f7d7ce270': ['A blond woman in a blue shirt appears to wait for a ride .',
#   'A blond woman is on the street hailing a taxi .',
#   'A woman is signaling is to traffic , as seen from behind .',
#   'A woman with blonde hair wearing a blue tube top is waving on the side of the street .',
#   'The woman in the blue dress is holding out her arm at oncoming traffic .'],
#  '1056359656_662cee0814': ['A little girl looking at a brochure on train rides',
#   'a young blond girl with a magizine in her hands',
#   'A young girl on a train reads a book about train rides .',
#   'A young girl sits on a seat and looks at a train pamphlet .',
#   'Child sitting down looking at train ride brochure'],
#  '1056873310_49c665eb22': ['A brown dog is running after a black dog on a rocky shore .',
#   'A brown dog is running after the black dog .',
#   'Two dogs playing on a beach .',
#   'Two dogs run across stones near a body of water .',
#   'Two dogs run towards each other on a rocky area with water in the background .'],
#  '1057089366_ca83da0877': ['A boy descends off the end of a high diving board .',
#   'A child jumps off a high diving board into the pool .',
#   'A kid jumps off the diving board and into the swimming pool below .',
#   'A little kid is jumping off a high dive at the pool .',
#   'The boy is jumping off a high diving board into the pool .'],
#  '1057210460_09c6f4c6c1': ['A guy stands by a window taking his overshirt off .',
#   'A man in a tank top stands next to a chrome door .',
#   'A man puts his shirt on near an elevator .',
#   'A man stands by an elevator with his head down .',
#   'The man is putting on his shirt near an elevator .'],
#  '1057251835_6ded4ada9c': ['A light-colored dog runs on the beach .',
#   'A small yellow dog runs on a beach',
#   'A tan dog runs on a sandy beach .',
#   'A white dog is running down a rocky beach .',
#   'Light brown dog running along the beach .'],
#  '106490881_5a2dd9b7bd': ['A boy in his blue swim shorts at the beach .',
#   'A boy smiles for the camera at a beach .',
#   'A young boy in swimming trunks is walking with his arms outstretched on the beach .',
#   'Children playing on the beach .',
#   'The boy is playing on the shore of an ocean .'],
#  '106514190_bae200f463': ['A hiker standing high on a bluff overlooking the mountains below .',
#   "a person on ski 's looks from hill over snow covered landscape",
#   'A skier is overlooking a snow-covered mountain .',
#   'A skier is overlooking the beautiful white snow covered landscape .',
#   'A skier pauses on a mountaintop .'],
#  '1067180831_a59dc64344': ['A black and white dog is attempting to catch a yellow and purple object in a low cut yard .',
#   'A black and white dog jumps after a yellow toy .',
#   'a black and white dog jumps to get the Frisbee .',
#   'A black dog is jumping up to catch a purple and green toy .',
#   'A dog jumps to catch a toy .'],
#  '1067675215_7336a694d6': ['A man in blue shorts is laying in the street .',
#   'A man in blue shorts lays down outside in a parking lot .',
#   'A man laying down in middle of street during heavy traffic .',
#   'A man lies on a mat in a parking lot between a brown SUV and a yellow pickup with an open door .',
#   'A shirtless man is laying down in the middle of a busy street .'],
#  '1067790824_f3cc97239b': ['A white and black dog and a brown dog in sandy terrain .',
#   'A woolly dog chases a Doberman on a beach .',
#   'One dog is chasing another one on the beach .',
#   'The two large dogs are running through sand .',
#   'Two large dogs chasing each other at the beach .'],
#  '1072153132_53d2bb1b60': ['A black and white dog catches a toy in midair .',
#   'A dog and a tennis ball .',
#   'A dog is jumping to catch a object thrown at it ,',
#   'A dog leaps while chasing a tennis ball through a grassy field .',
#   'A multicolor dog jumping to catch a tennis ball in a grassy field .'],
#  '107318069_e9f2ef32de': ['A crowd watching air balloons at night .',
#   'A group of hot air balloons lit up at night .',
#   'People are watching hot air balloons in the park .',
#   'People watching hot air balloons .',
#   'Seven large balloons are lined up at nighttime near a crowd .'],
#  '1075716537_62105738b4': ['A child with a helmet on his head rides a bike .',
#   'A little boy rides a bike down a hill on a miniature dirt bike .',
#   'A young boy in a helmet rides a bike on the road .',
#   'The little boy rides his bicycle in a race .',
#   'The young boy pedals quickly at a BMX race .'],
#  '107582366_d86f2d3347': ['A group of eight people are gathered around a table at night .',
#   'A group of people gathered around in the dark .',
#   'A group of people sit around a table outside on a porch at night .',
#   'A group of people sit outdoors together at night .',
#   'A group of people sitting at a table in a darkened room .'],
#  '1075867198_27ca2e7efe': ['A man in a brown shirt and dark shorts plays on the beach with his two black dogs .',
#   'A man in shorts with two black dogs holds a ball throwing toy at the beach .',
#   'a man playing with two black dogs on the beach',
#   'A man with two dogs on a beach',
#   'Man at the beach with two dogs .'],
#  '1075881101_d55c46bece': ['a boy cleans the bubbles off his face .',
#   'A boy covered in suds has his face wiped clean .',
#   'A boy is covered in bubbles .',
#   'A child covered in foam is climbing on a black inflatable ramp .',
#   'A person covered in soapy water is getting cleaned off .'],
#  '1077546505_a4f6c4daa9': ['A boy in blue shorts slides down a slide into a pool .',
#   'A boy in blue swimming trunks slides down a yellow slide into a wading pool with inflatable toys floating in the water .',
#   'A boy rides down a slide into a small backyard pool .',
#   'A boy sliding down a slide into a pool with colorful tubes .',
#   'A child is falling off a slide onto colored balloons floating on a pool of water .'],
#  '1077931201_1e0bb83105': ['A man in a wetsuit is throwing a baby wearing a wetsuit up into the air .',
#   'A man in a wetsuit is throwing a toddler up in the air and is ready to catch him .',
#   'A man in water throwing a little boy up in the air and waiting for him to come down so he can catch him .',
#   'The man is in the pool and throwing a small boy into the air .',
#   'While water droplets fly , a man throws a little boy up in the air .'],
#  '1079274291_9aaf896cc1': ['A little boy sticks his tongue out for the camera . Another boy looks on .',
#   'Two boys make faces .',
#   'Two young boys are looking at the camera , one smiling , the other sticking his tongue out .',
#   'Two young boys look up at the camera as one sticks out his tongue .',
#   'two young boys making silly faces .'],
#  '10815824_2997e03d76': ['A blonde horse and a blonde girl in a black sweatshirt are staring at a fire in a barrel .',
#   'A girl and her horse stand by a fire .',
#   "A girl holding a horse 's lead behind a fire .",
#   'A man , and girl and two horses are near a contained fire .',
#   'Two people and two horses watching a fire .'],
#  '1082252566_8c79beef93': ['A bulldog , a sheep dog , and a boxer standing in a yard .',
#   'A large brown dog is pushing a small Boston terrier with his face while anouther dog watches .',
#   'A large skinny dog stands near two smaller dogs int the dirt .',
#   'There are three dogs starring at a ball in the middle of them .',
#   'Three dogs of various sizes .'],
#  '1082379191_ec1e53f996': ['A lady and a man with no shirt sit on a dock .',
#   'A man and a woman are sitting on a dock together .',
#   'A man and a woman sitting on a dock .',
#   'A man and woman sitting on a deck next to a lake .',
#   'A shirtless man and a woman sitting on a dock .'],
#  '1084040636_97d9633581': ['A closeup of a white dog that is laying its head on its paws .',
#   'a large white dog lying on the floor .',
#   'A white dog has its head on the ground .',
#   'A white dog is resting its head on a tiled floor with its eyes open .',
#   'A white dog rests its head on the patio bricks .'],
#  '1084104085_3b06223afe': ['a woman in a yellow shirt and green shorts is climbing an artificial red wall whilst wearing a safety harness .',
#   'A woman in blue shorts and a white shirt is indoor rock climbing .',
#   'The girl is climbing a rock wall .',
#   'The girl is in a harness , climbing rocks .',
#   'Woman climbing an artificial rock wall .'],
#  '1087168168_70280d024a': ['A boy is jumping on an inflatable ring and a girl is watching him',
#   'A boy jumping on a water jumphouse',
#   'A teenage boy is jumping on an inflatable slide .',
#   'A young boy jumping and a young girl seating in an inflatable pool .',
#   'Two young kids are playing in the water on an inflated toy .'],
#  '1087539207_9f77ab3aaf': ['A family playing on a tractor on a beautiful day',
#   'Children ride a tractor in a field .',
#   'Several children playing on a Polaris vehicle outdoors .',
#   'The children played on the four wheeler in the field .',
#   'The four kids are riding on an ATV in a field .'],
#  '1088767354_2acee738cf': ['A woman in a red costume to the left of a man and woman standing together .',
#   'A woman wearing a red costume looks at two other people standing on a street .',
#   'A young woman in a red sequined costume and feather stands on the sidewalk .',
#   'The girl in the salmon colored bikini is standing next to two young people ; one is wearing a black outfit and the other is drinking pop .',
#   'Two young people are approached by a flamboyant young woman dressed in a red bikini and a red feathered headress .'],
#  '108898978_7713be88fc': ['Skiiers walking up the hill through a forest .',
#   'Two men are skiing in the snow in a wooded area .',
#   'Two people wearing yellow jackets cross-country skiing .',
#   'Two skiers are making their way through woodland .',
#   'Two skiers are sliding down a trail in the woods .'],
#  '108899015_bf36131a57': ['A lone skier is making their way up a mountain .',
#   'Skiiers at the top of a snow covered hill .',
#   'Two hikers climbing a snowy hill .',
#   'Two people are on a snow-covered mountain .',
#   'Two people climbing up a snowy mountain .'],
#  '1089181217_ee1167f7af': ['a brown dog running down a paved pathway',
#   'A brown dog running next to grass .',
#   'A dog is running down a road .',
#   'A light brown dog runs down a path happily .',
#   'Energetic brown dog running'],
#  '1089755335_0bfbfd30e6': ['A mother and children is fishing on a boardwalk at night .',
#   'A woman and three children stand on a deck with a fishing pole .',
#   'A woman stands with children on a boardwalk at night overlooking the sea .',
#   'Some people on a pier at night with one girl fishing off it .',
#   'Woman with three children fishing over boardwalk in the evening .'],
#  '109202756_b97fcdc62c': ['A woman dressed in a blue jacket and blue jeans rides a brown horse near a frozen lake and snow-covered mountain .',
#   'A woman in a blue jacket rides a brown pony near water .',
#   'A woman rides a horse near a frozen lake in the wintertime .',
#   'A young blond woman sitting atop a brown draft horse in the snowy mountains .',
#   'Woman n blue jacket sits on daft horse near a frozen lake .'],
#  '109202801_c6381eef15': ['Two draft horses pull a cart through the snow .',
#   'Two golden brown horses pull a sleigh driven by a woman in a blue coat .',
#   'Two horses are pulling a woman in a cart .',
#   'Two horses pull a carriage driven by a woman over snow covered ground .',
#   'Two horses pulling a sled steered by a smiling blond woman .'],
#  '109260216_85b0be5378': ['A person climbing down a sheer rock cliff using a rope',
#   'A person climbs a tall , flat mountain while holding onto a safety rope .',
#   'A person is climbing a rock while holding onto a white rope .',
#   'A person rappels down a steep incline .',
#   'A person wearing a red vest climbs up a steep rock .'],
#  '109260218_fca831f933': ['People stand inside a rock dome .',
#   'Shaft of light in a cave shows three spelunkers',
#   'Spelunkers pose inside a rock cavern while bathed in sunlight from the surface .',
#   'three people sit in a cave .',
#   'Three rock climbers are posing on big rocks .'],
#  '1093716555_801aacef79': ['a group of backpackers lay on the dry ground .',
#   'A group of hikers are resting on the ground in front of some mountains .',
#   'People camp with the mountains in the background .',
#   'Several hikers rest with their gear in front of a mountain .',
#   'The group of hikers is resting in front of a mountain .'],
#  '1093737381_b313cd49ff': ['A woman in a blue dress stands with a chalk portrait of two children playing by a stream .',
#   'A woman standing in front of a chalk drawing',
#   'A woman stands next to a chalk drawing in front of a barn-like structure .',
#   'A woman stands outside near an elaborate chalk illustration .',
#   'A woman wearing a blue dress is drawing a picture of a boy and a girl on the sidewalk with sidewalk chalk .'],
#  '1094462889_f9966dafa6': ['A brown dog plays in a deep pile of snow .',
#   'A dog looking at the camera in snow .',
#   'a dog runs through the snow .',
#   'A tan dog stand in the snow and looks up .',
#   'The brown dog is out in the snow .'],
#  '1095476286_87d4f8664e': ['A boy jumping in a fountain .',
#   'a boy plays in the fountains .',
#   'A child plays in a fountain .',
#   'A little boy playing in the water .',
#   'A young boy is jumping through water being sprayed up from the ground .'],
#  '1095580424_76f0aa8a3e': ['A Corgi runs out of a tunnel .',
#   'A dog runs out of a tunnel on a course .',
#   'Dog running out of tunnel on obstacle course',
#   'The dog is running out of the tunnel on a dog obedience course .',
#   'The small brown and white dog is running out of a small tunnel .'],
#  '1095590286_c654f7e5a9': ['A blond dog and a black and white dog run in a dirt field .',
#   'a dog chases another dog .',
#   'A yellow dog and a black and white dog are running in the dirt .',
#   'Two dogs are running in a field .',
#   'two dogs running around'],
#  '1095980313_3c94799968': ['A little girl in a blue swimsuit is walking along a wooden fence next to a sandy beach .',
#   'A little girl with arms outstretched is posing at the beach .',
#   'A young girl walks on a railing in front of the beach .',
#   'Little girl in blue swimsuit standing on a handrail near a beach .',
#   'The little girl in the blue bathing suit is posing at the beach .'],
#  '1096097967_ac305887b4': ['A black and white dog drinking water from a water spray .',
#   'A black and white dog is being soaked with a jet of water in a blue paddling pool .',
#   'A dog sticking its face into the shower from a garden hose .',
#   'A small white dog gets sprayed by water',
#   'A white and black dog is jumping into a pool .'],
#  '1096165011_cc5eb16aa6': ['a boy smiles underwater .',
#   'A red-headed boy swimming underwater .',
#   'A small boy swimming underwater',
#   'A smiling boy swims underwater in a pool .',
#   'The boys smiles underwater at the pool .'],
#  '1096395242_fc69f0ae5a': ['A boy with a toy gun .',
#   'A little boy in orange shorts playing with a toy .',
#   'A young boy with his foot outstretched aims a toy at the camera in front of a fireplace .',
#   'A young child plays with his new light-up toy .',
#   'Boy with toy gun pointed at the camera .'],
#  '109671650_f7bbc297fa': ['A boy in yellow shorts is standing on top of a cliff .',
#   'A boy wearing blue and yellow walking on a cliff edge .',
#   'A little boy standing high in the air on a rock .',
#   'A young child is standing alone on some jagged rocks .',
#   'Child stands near edge of cliff .'],
#  '109738763_90541ef30d': ['A person on a snowmobile in mid jump .',
#   'A snowmobiler flies through the air .',
#   'A snowmobile rider flies through the air on his or her machine in front of tall pine trees .',
#   'Rider jumps snowmobile high in rural area .',
#   'The man is up in the air .'],
#  '109738916_236dc456ac': ['People are riding around on snowmobiles .',
#   'People pose with helmets and goggles on while riding snowmobiles .',
#   'Several people are taking a break while on a snowmobiling ride .',
#   'Three people and two snowmobiles .',
#   'Two helmeted men sit on yellow snowmobiles while another man stands behind watching .'],
#  '109823394_83fcb735e1': ['Three people drive ATVs .',
#   'Three people on ATVs in a brown field turn their heads to look at the camera .',
#   "Three people on ATV 's outside .",
#   "three people on four wheel ATV 's in a field .",
#   'Three people ride their four wheelers through the field .'],
#  '109823395_6fb423a90f': ['A four wheeler jumping in an empty field .',
#   'A man on a four wheeler is flying through the air .',
#   'A person is riding an orange ATV in a large empty field .',
#   'Man jumping with all terrain vehicle',
#   'Man on an ATV catching air !'],
#  '109823397_e35154645f': ['A man jumps gin the air while riding an ATV',
#   'A man on a four-wheeler jumps near a small building .',
#   'An ATV is airborne over a field in front of a white structure .',
#   'A person dressed in a tan jacket jumps a quad over a harvested cornfield in front of a small out building .',
#   'Man on four wheeler in the air .'],
#  '1100214449_d10861e633': ['A boy in s striped shirt is jumping in front of a water fountain .',
#   'A boy is jumping off the side of a running stone water fountain in front of a building .',
#   'A happy boy is jumping in front OD city fountain .',
#   'A little boy is jumping in front of a fountain .',
#   'A little boy is playfully jumping off the side of a fountain .'],
#  '1104133405_c04a00707f': ['A boy carrying a soccer ball .',
#   'A boy walks with a ball tucked under his arm .',
#   'A boy walks with a soccer ball near a fence .',
#   'A boy wearing a white t-shirt walks on the grass and carries a soccer ball .',
#   'Small boy carries a soccer ball on a field .'],
#  '1105959054_9c3a738096': ['A child painting a picture .',
#   'An artist paints clouds onto a canvas .',
#   'A young girl painting a picture .',
#   'A young girl with braids is painting with water colors on a white paper on the wall .',
#   'The child paints on a large paper with water colors .'],
#  '110595925_f3395c8bd6': ['A cyclist is riding a bicycle on a curved road up a hill .',
#   'A man in aerodynamic gear riding a bicycle down a road around a sharp curve .',
#   'A man on a mountain bike is pedaling up a hill .',
#   'Man bicycle up a road , while cows graze on a hill nearby .',
#   'The biker is riding around a curve in the road .'],
#  '1107246521_d16a476380': ['a black dog jumping to catch a rope toy',
#   'A black dog playing fetch with a ball of rope .',
#   'A black dog pounces to get a rope toy .',
#   'A black dog running after his rope toy .',
#   'A large black dog is playing in a grassy yard .'],
#  '1107471216_4336c9b328': ['A little girl is holding a cine camera in front of her face .',
#   'A young girl is looking through an old fashioned video camera .',
#   'A young girl steadies her aim with a camera',
#   'Girl with rosy cheeks and lips holding black toy gun .',
#   'There is a kid with a gun .'],
#  '1110208841_5bb6806afe': ['A black and white Border Collie catches a Frisbee in front of an audience .',
#   'a brown and white dog catches a Frisbee in it mouth in front of a group of people .',
#   'A brown and white dug jumping up to catch a Frisbee while an audience watches .',
#   'A dog jumps to catch a Frisbee , while many people watch .',
#   'An agile dog catches a Frisbee while a crowd of onlookers watches closely .'],
#  '1112212364_0c48235fc2': ['A baby is sitting on and playing with smooth rocks .',
#   'A baby is stacking rocks on the beach .',
#   'A small boy is playing with rocks',
#   'A toddler sitting on a pile of rocks holding a rock at a beach .',
#   'Toddler sits on a pile of rocks .'],
#  '111497985_38e9f88856': ['A kid rock climbing against the backdrop of a green valley',
#   'A woman in a striped shirt climbs up a mountain .',
#   'A young man climbs a rocky hill .',
#   'The person has a striped shirt on and is holding on to a rope on a mountain .',
#   'The person in the striped shirt is mountain climbing .'],
#  '111537217_082a4ba060': ['A man climbing a rock wall',
#   'A man climbing the side of a cliff .',
#   'A man is rock climbing .',
#   'Man with red shoes , white shirt and grey pants climbing .',
#   'The young man with the white t-shirt and jeans is rappeling up the rock wall .'],
#  '111537222_07e56d5a30': ['A climber wearing a blue helmet and headlamp is attached to a rope on the rock face .',
#   'A man climbs a rocky wall .',
#   'a rock climber climbs a large rock .',
#   'A woman in purple snakeskin pants climbs a rock .',
#   'Person with blue helmet and purple pants is rock climbing .'],
#  '1115565519_d976d4b1f1': ['A child playing with a fountain at the beach .',
#   'A child plays with a fountain .',
#   'A girl looks at a fountain that sprays water .',
#   'A little girl playing in water on a frog sculpture .',
#   'The little girl is playing with a toy in a public fountain .'],
#  '1115679311_245eff2f4b': ['A black dog is jumping over a log along a beach .',
#   'A black dog runs along the beach and jumps over a wood barrior .',
#   'A dog is running on the beach .',
#   'a dog jumping over a small wall at a beach near the water .',
#   'An animal is running on the beach .'],
#  '111766423_4522d36e56': ["A black and white bird eating seeds out of someone 's hand",
#   'A black and white bird standing on a hand .',
#   "A small bird sits in a person 's hand and eats seeds .",
#   'Black and white bird standing on hand of someone holding sunflower seeds',
#   'The small bird is clinging to a finger of the hand holding the seeds .'],
#  '1117972841_2b9261f95f': ['A brown dog is running in the sand .',
#   'A brown dog playing in the sand .',
#   'A brown dog plays at the beach .',
#   'A dog is standing in the sand .',
#   'A dog running fast in the sand .'],
#  '1118557877_736f339752': ['A little boy stands in the surf .',
#   'A small child wades through the water while being guided by another person .',
#   'A young boy laughs while splashing in the ocean .',
#   'a young boy wearing a colorful bathing suit splashing in the ocean',
#   'A young child splashing in water .'],
#  '1119015538_e8e796281e': ['A little tan dog with large ears running through the grass .',
#   'A playful dog is running through the grass .',
#   'A small dogs ears stick up as it runs in the grass .',
#   'The small dog is running across the lawn .',
#   'this is a small beige dog running through a grassy field'],
#  '1119418776_58e4b93eac': ['A black and white dog is running through the field .',
#   'A black , brown and white dog running through a field .',
#   'A brown , black and white dog is running through a large field with its mouth open .',
#   'A dog running in a field .',
#   'A dog with its mouth open running through a field torwards the camera .'],
#  '1119463452_69d4eecd08': ['A girl in a pink swimsuit in a pool',
#   'A girl swimming in a pool .',
#   'A little girl in a pink bathing suit swimming in a pool .',
#   'A little girl swimming in a pool .',
#   'Smiling little girl swimming in outdoor pool .'],
#  '1121416483_c7902d0d49': ['A child is standing on her head .',
#   'A little girl standing on her head .',
#   'A small child doing a handstand on a bed .',
#   'A young girl does a handstand on a bed with blue sheets .',
#   'The girl is upside down on a bed'],
#  '112178718_87270d9b4d': ['A guy stands in the sand with a snowboard behind him .',
#   'A man holds a surfboard on the beach .',
#   'a man holds his snowboard in the sand .',
#   'A man with his surfboard stands in the sand .',
#   'Man is standing on white sand and holding a snowboard .'],
#  '112243673_fd68255217': ['People on ATVs and dirt bikes are traveling along a worn path in a field surrounded by trees .',
#   "Three people are riding around on ATV 's and motorcycles .",
#   'Three people on motorbikes follow a trail through dry grass .',
#   'Three people on two dirt-bikes and one four-wheeler are riding through brown grass .',
#   'Three people ride off-road bikes through a field surrounded by trees .'],
#  '1122944218_8eb3607403': ['A baby in a white garment holds a flag with crescent moon and star .',
#   'A baby is holding a small black flag with a moon and a star on it .',
#   'A baby wearing a white gown waves a Muslim flag .',
#   'A little toddler dressed in white is smiling while a lady helps him wave a flag .',
#   'Baby in white outfit holding black and white flag .'],
#  '1124448967_2221af8dc5': ['A half naked man is sleeping on his chair outdoors .',
#   'An older man sits back and relaxes on a patio outside an adobe building where many bicycles are propped .',
#   'A shirtless man in a white cap relaxes in a deck chair , close to three parked bicycles .',
#   'Man relaxing in a folding chair on the street .',
#   'Topless old man wearing slippers , navy blue pants and a white hat while reclining in a chair outside .'],
#  '1129704496_4a61441f2c': ['A brown and white and a black and white dog hauling in a floating toy from the ocean .',
#   'Both dogs retrieve the play toy from the water .',
#   'Two dogs in the ocean playing with a toy',
#   'Two dogs run through the water with a rope in their mouths .',
#   'Two dogs tug at a chew toy in the surf .'],
#  '1130017585_1a219257ac': ['There are three young people , one dark haired holding a bottled drink , one with head tilted back and finger in her mouth , and one with spiked hair .',
#   'The young people party in the streets .',
#   'Three girls make faces as one takes a drink while they stand in a busy street .',
#   'Three women on the street drinking and posing',
#   'Three young women pose for the camera at a parade .'],
#  '1130369873_d80a1aa59c': ['A brown dog is running through neck-deep water carrying a tennis ball .',
#   'A brown dog splashes in the water while carrying a ball in its mouth .',
#   'A brown dog swims through water outdoors with a tennis ball in its mouth .',
#   'A red dog , holding a ball , splashes through vegetation filled water .',
#   'Brown dog with tennis ball in mouth , in water and bushes .'],
#  '1130401779_8c30182e3e': ['Two brown dogs are creating large splashes as they run in a river .',
#   'Two brown dogs in the water .',
#   'Two brown dogs running through water .',
#   'Two brown dogs runs through the water .',
#   'Two dogs splash through the water .'],
#  '1131155939_b4b457b05e': ['A black dog runs into the ocean next to a pile of seaweed .',
#   'A black lav runs into the water on the beach , with swimmers in the distance and sea kelp in the foreground .',
#   'A dog at the shore of an ocean , with seaweed in foreground .',
#   'A dog is running in the waves at the beach .',
#   'A pile of seaweed sits on the sand , behind it a big black dog is running in the water .'],
#  '1131340021_83f46b150a': ['A young boy runs while wearing sandals .',
#   'Little boy in a striped shirt and brown shorts is running .',
#   'The little boy , in a short sleeved shirt and shorts , is running outside .',
#   'The little boy is wearing a black pinstripe shirt and walking on a deck .',
#   'Young boy running outside on the pavement .'],
#  '1131800850_89c7ffd477': ['A brown and white dog stands outside while it snows .',
#   'A dog is looking at something near the water .',
#   'A furry dog attempts to dry itself by shaking the water off its coat .',
#   'A white and brown dog shaking its self dry .',
#   'The large brown and white dog shakes off water .'],
#  '1131804997_177c3c0640': ['Two men are sitting on the ground and going through their backpacks .',
#   'Two men sitting in front of a railing are looking at something .',
#   'Two men with backpacks placed in front of them sitting in front of a railing .',
#   'Two men with backpacks are sitting on cardboard along a railing .',
#   'Two older men with backpacks sit at a bus station .'],
#  '1131932671_c8d17751b3': ['A boy is jumping on a bed .',
#   'A boy jumped up from the green bed .',
#   'A boy jumps from one bed to another .',
#   'A small child is jumping on a bed .',
#   'The boy in blue shorts is bouncing on the bed .'],
#  '1132772170_600610c5df': ['A child leaping from bed to bed behind the back of a man .',
#   'A man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room .',
#   'a man wearing a yellow shirt standing in the middle of two beds that a boy is jumping on in the background',
#   'A young child jumping on the bed as a man looks the other way .',
#   'Man standing in the bedroom with little boy jumping into bed .'],
#  '113678030_87a6a6e42e': ['A snowboarder sits on a slope with skiers and boarders nearby .',
#   'A snowboarder takes a rest on the mountainside .',
#   'Snowboarders sitting in the snow while skiers take the hill .',
#   'The snowboarder is sitting down .',
#   'Two skiers stand , two sit on slopes .'],
#  '1138784872_69ade3f2ab': ['A girl in green walks down a city street .',
#   'A small child in green clothing walks past a store opening and a woman in pink pants .',
#   'A small child walks down a sidewalk .',
#   'A young boy is walking in front of some stores',
#   'The child in the green one piece suit is walking past a store window .'],
#  '114051287_dd85625a04': ['A boy dressed in soccer attire and holding his shoes getting out of a car .',
#   'A boy in a red soccer strip is holding his boots in his hand whilst stepping out of a car .',
#   'A boy in glasses is wearing a red shirt .',
#   'A child getting out of the car wearing soccer shoes .',
#   'A young boy gets out of the van and prepares his shoes for wear during a soccer game .'],
#  '1141718391_24164bf1b1': ['A bridge through high green plants , a man and a woman on it .',
#   'A man and a woman are crossing over a rope bridge with greenery all over them .',
#   'A man and a woman are walking across a rope bridge .',
#   'A man and a woman crossing a suspension bridge in a tropical setting .',
#   'Woman and man walking across wooden rope bridge with a caution sign beside it .'],
#  '1141739219_2c47195e4c': ['A family gathered at a painted van',
#   'A girl climbing down from the side of a bright blue truck while others watch .',
#   'A man is helping a girl step down from a colorful truck whilst a woman and three children watch .',
#   'A very colorful bus is pulled off to the side of the road as its passengers load .',
#   'Two women and four children standing next to a brightly painted truck .'],
#  '1142283988_6b227c5231': ['A blond woman poses with a person in a pink costume .',
#   'A smiling woman holds a person dressed in a pig costume .',
#   "A young woman hugs a young man who 's wearing a pink costume .",
#   'Blond embracing young man in pink costume , at event',
#   'Two people are hugging and one is wearing a pink-hooded stretch top .'],
#  '1142847777_2a0c1c2551': ['A bicyclist riding on a city street .',
#   'A woman in a blue helmet and brown shorts rides her bike on a busy street .',
#   'A woman is riding a blue bike .',
#   'A woman is riding her bicycle in traffic',
#   'A woman wearing a blue helmet rides her bicycle in a parking lot .'],
#  '1143373711_2e90b7b799': ['A bicycle rider is crossing a street .',
#   'A bicyclist getting ready to cross a street .',
#   'A biker in spandex riding on a busy street .',
#   'A man in blue and white biking gear rides down a busy street .',
#   'a man wearing a helmet riding his bicycle down the street .'],
#  '1143882946_1898d2eeb9': ['A lady wearing a helmet holding a bike .',
#   'A woman in a blue vest and a sky blue helmet stands with her bicycle in traffic .',
#   'A woman in a helmet rides her bike behind a car .',
#   'A woman with a helmet and a backpack walks next to her bike .',
#   'Women with bike and helmet wait for traffic .'],
#  '1144288288_e5c9558b6a': ['A man in shorts is jogging along a street with a headset .',
#   'A person in blue shorts and wearing a Walkman jogs .',
#   'A woman in a white shirt and blue shorts is wearing headphones .',
#   'A woman walks on a street wearing headphones .',
#   'A woman wearing a white hat and shirt is jogging down a street with a plant store on the corner .'],
#  '1148238960_f8cacec2fc': ['Bicyclists are standing at an intersection .',
#   'Bicyclists waiting at an intersection .',
#   'People on bicycles waiting at an intersection .',
#   'People waiting at a light on bikes .',
#   'three bikers stop in town .'],
#  '1149179852_acad4d7300': ['A man without a shirt on is guiding a large brown horse pulling a green and yellow wagon .',
#   'A shirtless man escorts a horse pulling a carriage along a paved road .',
#   'A shirtless man leading a horse that is pulling a carriage .',
#   'Shirtless man leading a small horse-drawn covered wagon down a road',
#   'The shirtless man is walking the Shetland pony and carriage down the street .'],
#  '114949897_490ca7eaec': ['A boy hits a ball off of a tee ball into to net .',
#   'A child practices hitting a baseball into a net , while two adult men watch .',
#   'A man holds a net while a boys bats a ball into it .',
#   'The man is holding the net for the boy playing baseball .',
#   'Three people put up a batting cage .'],
#  '1151466868_3bc4d9580b': ['A small girl spins in the waves in the bright sun .',
#   'A young girl plays in shallow water .',
#   "A young girl wears a shirt and shorts as she plays in the ocean 's surf .",
#   'Girl running through the water near the shore .',
#   'The little girl splashes through the water .'],
#  '1153704539_542f7aa3a5': ['A girl playing trumpet in a marching band .',
#   'A teenager plays her trumpet on the field at a game .',
#   'a young girl wearing a blue shirt marching in a band playing a trumpet',
#   'Girl playing the trumpet in a marching band',
#   'Girl wearing blue shirt and black shorts plays trumped outside .'],
#  '1155138244_859fd6e079': ['A girl hands out Starbucks samples at a street fair .',
#   'An Asian girl in a green hat and apron is serving drinks on a tray .',
#   'a Starbucks barista offering up a tray of drinks',
#   'The waitress offers complimentary tea to the patrons .',
#   'Woman dressed in a green hat and apron is holding a try full of drink samples .'],
#  '115684808_cb01227802': ['Three men are setting up a sledge on a snowy plain .',
#   'Three men loading items on a sled .',
# ...
#   'A boy is pulling a wild face whilst waving cooking implements in his hands .',
#   'a girl in a tan shirt holding up a fork and knife in one hand and a pot in the other',
#   'A person with cooking utilities poses menacingly in a dark environment .',
#   'A woman with a knife and fork grimmaces .'],
#  '2085726719_a57a75dbe5': ['Two girls bundled up in winter coats pose for a picture .',
#   'Two girls holding drinks and looking at something on a cellphone .',
#   'Two teen girls are looking at a small electronic device while wearing winter coats .',
#   'Two women dressed for cold weather in jackets and gloves look at something on a cellphone screen .',
#   'Two young girls huddle to look at a cellphone .'],
#  '2086513494_dbbcb583e7': ['A girl in a white coat takes pictures .',
#   'A girl in a white puffy jacket takes a picture .',
#   'a group of people looking into their cameras',
#   'Asian woman in white coat takes photo .',
#   'The woman in the white coat is holding a camera in her hand .'],
#  '2086532897_b8714f2237': ['A kayaker falling down a waterfall',
#   'A man is kayaking down a waterfall .',
#   'A man on a kayak coming down a raging waterfall',
#   'A person is on a small boat and going down some very strong water currents .',
#   'White water rafter goes through a rough spot .'],
#  '2086534745_1e4ab80078': ['A man in a yellow boat paddling down rough waters .',
#   'A rafter in a yellow raft in a steamy white river .',
#   'A yellow kayak is descending quickly down a white water rapid .',
#   'Kayacker riding rough current downstream .',
#   'The yellow kayak is in the middle of the rapids .'],
#  '2086678529_b3301c2d71': ['A girl in a purple dress smiling as she climbs an indoor rock wall .',
#   'A girl is in a dress .',
#   'A little girl wearing a purple dress looks down at the camera .',
#   'a young girl climbs a rock wall , in a purple dress .',
#   'A young girl wears a purple dress .'],
#  '2087317114_cf06df5aa5': ['A Mani is kayaking down some calmer rapids .',
#   'A man in a small kayak is floating down the river .',
#   'A man in a yellow jacket is floating on the river in a green kayak .',
#   'A man smiles in his blue and green kayak .',
#   'A man wearing a helmet in a Pyranha kayak floats down some river rapids .'],
#  '2087640654_1a84577a44': ['A blonde dog is digging a deep hole in the ground and its tail is up in the air .',
#   'A dog half way in a hole in the ground .',
#   'A dog is digging a large hole in a yard to find something .',
#   'A dog is digging in the ground and half of his body is under the ground .',
#   'The rear end of an animal whose front end is underground .'],
#  '2088120475_d6318364f5': ['A person dressed up as a snowman is walking through a crowd of people .',
#   'five cold people in the snowstorm , one wearing a snowman head',
#   'People pose for a picture in the snow',
#   'Three young people pose by a snowman in a red tie .',
#   'Two couples pose with a snowman .'],
#  '2088460083_42ee8a595a': ['A broken down hummer gets towed on a truck bed .',
#   'A damaged vehicle is carried by a repair truck in a night-time scene .',
#   'A flat bed truck in a parking lot with an army vehicle on its bed .',
#   'An old , beat-up jeep being towed away .',
#   'Dirty SUV sits on the bed of a tow truck at night .'],
#  '2088532947_c628e44c4a': ['The girl in the white shirt has a bracelet on and has her arm around the girl in the peach shirt .',
#   'The two girls laid on the grass together .',
#   'Two little girls are laying on the grass smiling .',
#   'two young girls holding each other on the grassy ground',
#   'two young girls hug each other in the grass .'],
#  '2088910854_c6f8d4f5f9': ['A large man is wearing a headband with mistletoe attached to it .',
#   'A man in a sweatshirt and cap wears a flower on his head .',
#   'A man wearing a black knit cap with a red and white striped headband with a flower on top .',
#   'An man with a black ski cap and a red and white headband looks into the distance .',
#   'Man wearing a black hat with a christmas theme .'],
#  '2089122314_40d5739aef': ['A dog running with a newspaper in its mouth .',
#   'A dog runs down the street , carrying a newspaper .',
#   'A dog with a newspaper in his mouth runs down a paved path .',
#   'A fluffy , tri-colored dog is running down the road with a paper in its mouth .',
#   'An Australian shepherd dog carrying a newspaper in his mouth .'],
#  '2089350172_dc2cf9fcf6': ['three black dogs are swimming through some murky brown water , one with a yellow object in its mouth .',
#   'three black dogs swimming in dirty water',
#   'Three dark dogs swimming and one of them has a ball .',
#   'Three dogs are up to their necks in water .',
#   'Three dogs swim in the water .'],
#  '2089426086_7acc98a3a8': ['A girl in a hooded jacket presents a cake with candles .',
#   'A girl in a hood jacket holds a birthday cake with many candles .',
#   'A girl in a winter coat with a birthday cake .',
#   'A girl is holding a birthday cake .',
#   'A young girl holding a cake with candles dressed in a heavy coat .'],
#  '2089442007_6fc798548c': ['A brown dog is walking in the water .',
#   'A brown dog takes cautious steps in the calm waters with a sandy bottom .',
#   'A brown dog wades in the water .',
#   'A dog with red fur stands in a body of water .',
#   'A large , golden colored dog is walking through water .'],
#  '2089539651_9e518ec7de': ['A hiker with two hiking poles stands on a hillside with a view of the city below him .',
#   'A hiker with two sticks is a standing on a path that is high up on a hill .',
#   'A hiking man stands on a cliff overlooking a city .',
#   'A man hikes on a dirt path high above a city .',
#   'A person holding poles is standing on a rock ledge with bushes on each side overlooking mountains .'],
#  '2089542487_b4c1ee7025': ['A hiker is ready to take on a rugged outdoor trail .',
#   'a lone hiker on a dirt hiking trail with a hat and sunglasses on with trees in the background',
#   'A man in shorts is hiking in a dry region .',
#   'A man stops for a picture with the scenery during his hike .',
#   'The man is posing for a picture in the desert wearing a green shirt and hat , and holding a metal detector .'],
#  '2089555297_95cf001fa7': ['A man in a hat with long sleeves and long pants stands overlooking a city .',
#   'A man stands on a cliff overlooking a city .',
#   'A man with a backpack and hat is standing by a high cliff where you can see for miles .',
#   'Hiker standing on top of a rock overlooking a town .',
#   'The man wearing a backpack and a hat , stands on a ledge overlooking a city .'],
#  '2090327868_9f99e2740d': ['A woman , a little boy , and a tiny baby are standing in front of a cow statue .',
#   'a woman and two small children posing in front of a large cow statue .',
#   'A woman gives a baby to a small child to hold as they stand in front of a cow statue .',
#   'A woman stands with two children near a decorated bull statue .',
#   'The woman and children are standing next to a statue of a cow .'],
#  '2090339522_d30d2436f9': ['A man in a green hat is someplace up high .',
#   'A man in a green hat is taking a self portrait .',
#   'A man in a hat at a scenic overlook .',
#   'a man wearing a green canvas hat with a distnat city in the background',
#   'Man with green hate and sunglasses on a high up peak'],
#  '2090386465_b6ebb7df2c': ['A woman and man in winter gear stand .',
#   'Three adults wearing cold weather gear .',
#   'Two people are wearing heavy clothing .',
#   'Two people in winter clothing .',
#   'two women bundled up on a snowy day'],
#  '2090387793_274ab4cf7d': ['A boy wearing black walks down the street with his hands in fists .',
#   'A teenage boy dressed in black stands on a snowy street .',
#   'A teenage boy wearing all black tries to look tough with cheap jewelry on .',
#   'A young man wearing a black hat and jacket is walking outside .',
#   'Punk rock teenager walks with a mean look on his face .'],
#  '2090545563_a4e66ec76b': ['the boy laying face down on a skateboard is being pushed along the ground by another boy .',
#   'Two girls play on a skateboard in a courtyard .',
#   'Two people play on a long skateboard .',
#   'Two small children in red shirts playing on a skateboard .',
#   'two young children on a skateboard going across a sidewalk'],
#  '2090723611_318031cfa5': ['Dogs walking in the grassy field .',
#   'Large fluffy grey dog standing in grass in front of a brown dog .',
#   'one dog standing in some grass with his tongue hanging out and a tan dog in the background',
#   'Two dogs of different breeds are standing in a pasture .',
#   'Two dogs stand in the grass .'],
#  '2090997177_76d482b158': ['A black dog bounds across the sand .',
#   'A dog walking across the desert .',
#   'A short black dog is walking over a barren landscape .',
#   'A small black dog running across the sand .',
#   'A small black dog walks in the sand .'],
#  '2091171488_c8512fec76': ['A female wearing pink gloves and a brown jacket is smiling in the snow .',
#   'A woman standing in the snow with people in the background .',
#   'A young woman in a spring coat and purple gloves stands in falling snow .',
#   'A young woman looks happy in winter clothes while it snows .',
#   'Young asian woman with pink gloves stands in the snow .'],
#  '2092177624_13ab757e8b': ['A boy in african clothing runs across a concrete wall .',
#   'A little boy with a green shirt is running on a rock ledge .',
#   'An African boy in large green shirt is running barefoot along a wall .',
#   'A young boy dressed in green running along a smooth , stone wall near a wooded area .',
#   'Boy in green tunic on rock wall .'],
#  '2092419948_eea8001d0f': ['A long haired man walking away beside a canal whist holding onto a railing .',
#   'A man walks down a path next to a waterway .',
#   'A person walks by some blue-green water while holding a rail .',
#   'a person with a long ponytail walks along a waterway under a tunnel',
#   'The man with long hair is walking along a storm drain .'],
#  '2092870249_90e3f1855b': ['A man lies on a street with his head and shoulders under a parked car that is jacked up .',
#   'A man looks under a car on a wet street .',
#   'A man works on a car .',
#   'A person lies half under a car , face-down .',
#   'A person underneath a car with a jack .'],
#  '2094323311_27d58b1513': ["A dog places his head on a man 's face .",
#   'A dog snuggles with a man in sunglasses .',
#   "A dog with a blue collar is licking a man who 's wearing large tinted sunglasses .",
#   "A large brown dog with a blue collar is resting his chin on a man 's face .",
#   'An orange dog is licking a man wearing red sunglasses .'],
#  '2094543127_46d2f1fedf': ["A girl holding a crocodile 's mouth closed",
#   'A girl is posed over a statue of a dangerous animal .',
#   'A girl sits on what appears to be a crocodile .',
#   'A girl sitting on top of a crocodile',
#   'A girl with red hair is sitting on a crocodile holding its jaw .'],
#  '2094810449_f8df9dcdf7': ['A boy stands in the ocean lifting up his shorts .',
#   'A child in blue shorts is standing ankle deep in the water .',
#   'A little boy in blue shorts , glasses , and a coat stands in the surf .',
#   'The kid is wearing a blue jacket and standing in shallow beach water .',
#   'The small child wades ankle deep in the water on the shoreline .'],
#  '2095007523_591f255708': ['A baby looks through his crib .',
#   'A baby , surrounded by some toys , looks out of a playpen .',
#   'Baby in playpen with wide eyes',
#   'Baby looking through playpen bars at camera .',
#   'The infant is laying on its stomach , in a crib , looking up at the camera .'],
#  '2095078658_c14ba89bc2': ['A dog runs through snow in front of the woods .',
#   'Large dog running in snow',
#   'The dog runs through the snow .',
#   'The German shepherd dog is running through the snow .',
#   'The German Shepherd is running through the white snow .'],
#  '2095435987_1b7591d214': ['A dog lying on its back in the sand .',
#   'A white and brown dog rolls on its back in the sand .',
#   'The dog rolls over to scratch its back in the sand .',
#   'The white and brown dog is rolling in the sand .',
#   'The white dog is on its back in the sand with paws in the air .'],
#  '2095444126_201ff9f222': ['A dog is shaking off water .',
#   'A dog shakes his head .',
#   'A dog shakes off water',
#   'A dog shakes off water and gets contorted .',
#   'The dog is shaking water off of his body .'],
#  '2095478050_736c4d2d28': ['A man and a boy play music as little girls watch .',
#   'A man is playing a guitar with a child playing a harmonica while three young girls watch .',
#   'Three children watch a man onstage playing guitar .',
#   'Three little girls look on as a boy plays the harmonica with an adult guiutarist sitting beside him .',
#   'Three little girls watch a band .'],
#  '209605542_ca9cc52e7b': ['a climber wearing a red headband is pulling himself up some grey rocks high above some green foliage .',
#   'A man in a headband climbing a rock .',
#   'a man with a red headband climbing a rock cliff looming over greenery .',
#   'Man climbing a sheet rock face .',
#   'Man in red headband climbing a rock'],
#  '2096771662_984441d20d': ['a man looks through his binoculars while another man holds a drink .',
#   'A man with a thermos is standing next to a man who is gazing through binoculars .',
#   'Two men are standing together while one looks through binoculars .',
#   'Two men look out as one is holding binoculars .',
#   'two people standing next to each other with mountains in the distance .'],
#  '2097398349_ff178b3f1b': ['A hiker waves to the camera as he standing in front of snowcapped mountains .',
#   'A man stands on the snow near the mountains .',
#   'A person poses in the snow .',
#   'A person stands in the snow at the top of a mountian , arms raised .',
#   'A skier in the mountains .'],
#  '2097403787_77a154f5b9': ['a lone person standing on some rocks with large snowy mountains in the background .',
#   'A man is standing on the rocky ground in front of the mountain .',
#   'A man standing in front of an icy mountain .',
#   'The person is standing by the water in front of the snow topped mountains .',
#   'The traveller pauses in front of the mountain view .'],
#  '2097407245_c798e0dcaf': ['A man in a winter jacket and knit cap stand with his arms up at his side in a snow landscape .',
#   'A man is standing on dirt with his hands in the air with mountains and snow behind him .',
#   'A man raises his arms on rocky beach .',
#   'One lone man with fist in the air with large rocky mountains in the background',
#   'Man with outstretched arms standing on snow-covered rocks .'],
#  '2097420505_439f63c863': ['A male hiker wearing a green jacket is posing next to a large glacier .',
#   'A man with a camera and an ice structure behind him .',
#   'A man with a camera crouching on ice .',
#   'A man with a camera kneels in front of a giant hill of snow .',
#   'The mountain climber prepares to take a photo .'],
#  '2097489021_ca1b9f5c3b': ['A girl in a ballet fairy costume is touched by a wand .',
#   'A young girl performing the nutcracker .',
#   'The little girl is standing on a stage dressed up as a pink fairy .',
#   'The tiny girl dressed in a butterfly ballet costume , waves her wand near a nutcracker statue .',
#   'Young girl waving turquiose leotard and pink tutu with wings waving wand .'],
#  '2098174172_e57d86ea03': ['A hiker is posing in front of snowy mountains .',
#   'A hiker is standing in before the mountain holding two walking sticks .',
#   'A man stands in front of snow covered mountains .',
#   'A man with two ski poles stands near a mountaintop .',
#   'The man wears a green hat and jacket while standing in front of a mountain .'],
#  '2098418613_85a0c9afea': ['A brown chow mix dog is standing in front of a van with euro plats in the middle of a messy yard .',
#   'A brown dog standing in a muddy yard .',
#   'A brown dogs walks near a green van and some junk .',
#   'A large brown dog stands in front of a green van in the yard of a house .',
#   'A yellow dog is standing in front of a green car and next to a toilet .'],
#  ...}

# %%
import string

def clean_descriptions(descriptions):
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for key, desc_list in descriptions.items():
		for i in range(len(desc_list)):
			desc = desc_list[i]
			# tokenize
			desc = desc.split()
			# convert to lower case
			desc = [word.lower() for word in desc]
			# remove punctuation from each token
			desc = [w.translate(table) for w in desc]
			# remove hanging 's' and 'a'
			desc = [word for word in desc if len(word)>1]
			# remove tokens with numbers in them
			desc = [word for word in desc if word.isalpha()]
			# store as string
			desc_list[i] =  ' '.join(desc)
			print(desc_list[i])
			return desc

# clean descriptions
cleaned = clean_descriptions(descriptions)
# Out:
# child in pink dress is climbing up set of stairs in an entry way

# %%
cleaned
# Out:
# ['child',
#  'in',
#  'pink',
#  'dress',
#  'is',
#  'climbing',
#  'up',
#  'set',
#  'of',
#  'stairs',
#  'in',
#  'an',
#  'entry',
#  'way']

# %%
# convert the loaded descriptions into a vocabulary of words
def to_vocabulary(descriptions):
	# build a list of all description strings
	all_desc = set()
	for key in descriptions.keys():
		[all_desc.update(d.split()) for d in descriptions[key]]
	return all_desc

# summarize vocabulary
vocabulary = to_vocabulary(descriptions)
print('Vocabulary Size: %d' % len(vocabulary))
# Out:
# Vocabulary Size: 9630

# %%
#Set which contains the vocabulary
print(vocabulary)
# Out:
# {'Slip', 'ADHD', 'swimsuits', 'toppless', 'help', 'faithful', 'stopping', 'amidst', 'protected', 'duffel', 'Arch', 'jockeys', 'coliding', 'typical', 'panelling', 'dreary', 'puck', 'offers', 'remove', 'welcomes', 'tiara', 'broom', 'rainbow', 'microphones', 'collected', 'stretching', 'multi-story', 'Yerba', 'adult', 'images', 'chef', 'infant', 'littered', 'bottoms', 'players', 'bicycle-cross', 'playgroud', 'musicians', 'searching', 'entertainers', 'feel', 'fairground', 'up', 'seek', 'pavement', 'angels', 'wide', 'auditorium', 'notice', 'bathrobe', 'shredded', 'close-cropped', 'rosy', 'gothically', 'sailboat', 'dashboard', 'projector', 'texting', 'horsemen', 'sportman', 'noise', 'maps', 'flip-flop', 'else', 'speedway', 'illuminated', 'forward', 'Santa', 'admired', 'expose', 'wedding', 'hang', 'avoid', 'stick', 'sliiding', 'use', 'met', 'herds', 'begs', 'quilted', 'clay', 'wheelbarrow', 'light-colored', 'flexing', 'divind', 'Fries', 'garage', 'busy', 'aerodynamic', 'changing', 'spaghetti', 'playes', 'pigeons', 'package', 'jersey', 'necklaces', 'course', 'Winter', 'robust', 'PlayStation', 'anti-tax', 'arrow', 'retriever', 'rebound', 'dodging', 'names', 'posh', 'Casterol', 'hackey', 'aross', 'motorcycle', 'stall', 'int', 'submerged', 'hidden', 'see-saw', 'mama', 'polar', 'jetty', 'cot', 'push-up', 'cockpit', 'lapel', 'cheap', 'gradual', 'indicating', 'ally', 'cafeteria', 'staffordshire', 'meeting', 'murals', 'upon', 'plains', 'bmx', 'bearded', 'Cows', 'shielding', 'crown', 'tip', 'stacking', 'acrouss', 'float', 'rodents', 'dries', 'World', 'merchandise', 'reson', 'jet-skis', 'weights', 'Speedskater', 'leave', 'Toddler', 'bald', 'burning', 'camels', 'closeup', 'roiling', 'colorful', 'Candles', 'complimentary', 'padding', 'canal', 'word', 'piste', 'misty', 'ques', 'unhappy', 'texts', 'wheelchair', 'chewed', 'butt', 'colors', 'walk-way', 'backed', 'uniform', 'Snowboarding', 'buckled', 'lecturing', 'bikers', 'skiny', 'directing', 'planting', 'Barefoot', 'picnic', 'coral', 'headcover', 'keeling', 'serves', 'sight', 'vandalized', 'bluejeans', 'sooners', 'talk', 'Zara', 'potrait', 'attire', 'wetsuit', 'grouped', 'Firemen', 'inflated', '11', 'Linet', 'caged', 'Soccer', 'steaks', 'shews', 'youg', 'prays', 'htting', 'bush', 'Jackson', 'concentrates', 'exciting', 'gurnee', 'fastens', '(', 'suit', 'stage', 'adobe', 'programs', 'rappels', 'bubbling', 'lays', 'Lucky', 'attacking', 'Interracial', 'creature', 'clowds', 'dusted', 'nestled', 'medow', 'stores', 'done', 'downhill', 'computer', '!', 'ski', 'sideline', 'huts', 'lighted', 'peoplw', 'bounced', 'dump', 'rotary', 'unique', 'wood-stacked', 'chestnut', 'misspelled', 'interacts', 'rolls', 'bull-run', 'COAL', 'bodysurfs', 'dumbbell', 'Unified', 'seen', 'hilltops', 'juice', 'joking', 'vents', 'beg', 'ARE', 'golf', 'telegraph', 'family', 'trampoline', 'Pokemon', 'accepts', 'whitewater', 'climbers', 'phones', 'suckles', 'naturally', 'extinguishes', 'totter', 'crosswalk', 'acoustic', 'heron', 'Puma', 'desert', 'alley', 'overturned', 'sash', 'post', 'footballer', 'Wolf', 'horseriders', 'rope', 'trendy', 'visible', 'onlookers', 'bedroom', 'satchel', 'mid-swing', 'manequins', 'bunk', 'jumper', 'black', 'three', 'photo', 'stuntman', 'Genocide', 'holy', 'age', 'porcelain', 'crustacean', 'got', 'Ride', 'sack', 'cut-out', 'takeout', 'casino', 'blur', 'bison', 'Nash', 'headwraps', 'winking', 'front', 'boating', 'stretch', 'pour', 'mambo', 'horns', 'underwear', 'teaches', 'except', 'bordering', 'Muscular', 'explosions', 'staircase', 'direct', 'expressway', 'brunettes', 'handcrank', 'cam', 'Groom', '21', 'autumnal', 'perpendicular', 'gymnastic', 'Ralley', 'elf', 'Espana', 'entertainment', 'parachuting', 'Gnome', 'discussion', 'size', 'wristwatch', 'gold', 'african-Americans', 'cowgirl', 'breakdancer', 'on-lookers', 'collides', 'kangaroo', 'breastfeeding', 'chased', 'wake-boards', 'bonnet', 'murky', 'Shoppers', 'eyeing', 'youths', 'kit', 'nations', 'cut-outs', 'widely', 'Japanese-sponsored', 'gesturing', 'midf ...

# %%
# save descriptions to file, one per line
def save_descriptions(descriptions, filename):
	lines = list()
	for key, desc_list in descriptions.items():
		for desc in desc_list:
			lines.append(key + ' ' + desc)
	data = '\n'.join(lines)
	file = open(filename, 'w')
	file.write(data)
	file.close()

# save descriptions
save_descriptions(descriptions, '/content/drive/My Drive/Capstone Data/flickr8k/descriptions.txt')

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line.split('.')[0]
		dataset.append(identifier)
	return set(dataset)

# %%
# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# %%
# load photo features
def load_photo_features(filename, dataset):
	# load all features
	all_features = load(open(filename, 'rb'))
	# filter features
	features = {k: all_features[k] for k in dataset}
	return features

# %%
from pickle import load
# load training dataset (6K)

filename = '/content/drive/My Drive/Capstone Data/flickr8k/Flickr8k_text/Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('/content/drive/My Drive/Capstone Data/descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('/content/drive/My Drive/Capstone Data/features.pkl', train)
print('Photos: train=%d' % len(train_features))
# Out:
# Dataset: 6000
# Descriptions: train=6000
# Photos: train=6000

# %%
train_descriptions
# Out:
# {'1000268201_693b08cb0e': ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#   'startseq A girl going into a wooden building . endseq',
#   'startseq A little girl climbing into a wooden playhouse . endseq',
#   'startseq A little girl climbing the stairs to her playhouse . endseq',
#   'startseq A little girl in a pink dress going into a wooden cabin . endseq'],
#  '1001773457_577c3a7d70': ['startseq A black dog and a spotted dog are fighting endseq',
#   'startseq A black dog and a tri-colored dog playing with each other on the road . endseq',
#   'startseq A black dog and a white dog with brown spots are staring at each other in the street . endseq',
#   'startseq Two dogs of different breeds looking at each other on the road . endseq',
#   'startseq Two dogs on pavement moving toward each other . endseq'],
#  '1002674143_1b742ab4b8': ['startseq A little girl covered in paint sits in front of a painted rainbow with her hands in a bowl . endseq',
#   'startseq A little girl is sitting in front of a large painted rainbow . endseq',
#   'startseq A small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it . endseq',
#   'startseq There is a girl with pigtails sitting in front of a rainbow painting . endseq',
#   'startseq Young girl with pigtails painting outside in the grass . endseq'],
#  '1003163366_44323f5815': ['startseq A man lays on a bench while his dog sits by him . endseq',
#   'startseq A man lays on the bench to which a white dog is also tied . endseq',
#   'startseq a man sleeping on a bench outside with a white and black dog sitting next to him . endseq',
#   'startseq A shirtless man lies on a park bench with his dog . endseq',
#   'startseq man laying on bench holding leash of dog sitting on ground endseq'],
#  '1007129816_e794419615': ['startseq A man in an orange hat starring at something . endseq',
#   'startseq A man wears an orange hat and glasses . endseq',
#   'startseq A man with gauges and glasses is wearing a Blitz hat . endseq',
#   'startseq A man with glasses is wearing a beer can crocheted hat . endseq',
#   'startseq The man with pierced ears is wearing glasses and an orange hat . endseq'],
#  '1007320043_627395c3d8': ['startseq A child playing on a rope net . endseq',
#   'startseq A little girl climbing on red roping . endseq',
#   'startseq A little girl in pink climbs a rope bridge at the park . endseq',
#   'startseq A small child grips onto the red ropes at the playground . endseq',
#   'startseq The small child climbs on a red ropes on a playground . endseq'],
#  '1009434119_febe49276a': ['startseq A black and white dog is running in a grassy garden surrounded by a white fence . endseq',
#   'startseq A black and white dog is running through the grass . endseq',
#   'startseq A Boston terrier is running in the grass . endseq',
#   'startseq A Boston Terrier is running on lush green grass in front of a white fence . endseq',
#   'startseq A dog runs on the green grass near a wooden fence . endseq'],
#  '1012212859_01547e3f17': ['startseq A dog shakes its head near the shore , a red ball next to it . endseq',
#   'startseq A white dog shakes on the edge of a beach with an orange ball . endseq',
#   'startseq Dog with orange ball at feet , stands on shore shaking off water endseq',
#   'startseq White dog playing with a red ball on the shore near the water . endseq',
#   'startseq White dog with brown ears standing near water with head turned to one side . endseq'],
#  '1015118661_980735411b': ['startseq A boy smiles in front of a stony wall in a city . endseq',
#   'startseq A little boy is standing on the street while a man in overalls is working on a stone wall . endseq',
#   'startseq A young boy runs aross the street . endseq',
#   'startseq A young child is walking on a stone paved street with a metal pole and a man behind him . endseq',
#   'startseq Smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him . endseq'],
#  '1015584366_dfcec3c85a': ['startseq A black dog leaps over a log . endseq',
#   'startseq A grey dog is leaping over a fallen tree . endseq',
#   'startseq A large black dog leaps a fallen log . endseq',
#   'startseq A mottled black and grey dog in a blue collar jumping over a fallen tree . endseq',
#   'startseq The black dog jumped the tree stump . endseq'],
#  '101654506_8eb26cfb60': ['startseq A brown and white dog is running through the snow . endseq',
#   'startseq A dog is running in the snow endseq',
#   'startseq A dog running through snow . endseq',
#   'startseq a white and brown dog is running through a snow covered field . endseq',
#   'startseq The white and brown dog is running over the surface of the snow . endseq'],
#  '101669240_b2d3e7f17b': ['startseq A man in a hat is displaying pictures next to a skier in a blue hat . endseq',
#   'startseq A man skis past another man displaying paintings in the snow . endseq',
#   'startseq A person wearing skis looking at framed pictures set up in the snow . endseq',
#   'startseq A skier looks at framed pictures in the snow next to trees . endseq',
#   'startseq Man on skis looking at artwork for sale in the snow endseq'],
#  '1016887272_03199f49c4': ['startseq A collage of one person climbing a cliff . endseq',
#   'startseq A group of people are rock climbing on a rock climbing wall . endseq',
#   'startseq A group of people climbing a rock while one man belays endseq',
#   'startseq Seven climbers are ascending a rock face whilst another man stands holding the rope . endseq',
#   'startseq Several climbers in a row are climbing the rock while the man in red watches and holds the line . endseq'],
#  '1019077836_6fc9b15408': ['startseq A brown dog chases the water from a sprinkler on a lawn . endseq',
#   'startseq a brown dog plays with the hose . endseq',
#   'startseq A brown dog running on a lawn near a garden hose endseq',
#   'startseq A dog is playing with a hose . endseq',
#   'startseq Large brown dog running away from the sprinkler in the grass . endseq'],
#  '1019604187_d087bf9a5f': ['startseq A dog prepares to catch a thrown object in a field with nearby cars . endseq',
#   'startseq A white dog is about to catch a yellow ball in its mouth . endseq',
#   'startseq A white dog is about to catch a yellow dog toy . endseq',
#   'startseq A white dog is ready to catch a yellow ball flying through the air . endseq',
#   'startseq A white dog running after a yellow ball endseq'],
#  '1020651753_06077ec457': ['startseq a black and white dog jumping in the air to get a toy . endseq',
#   'startseq A black and white dog jumps up towards a yellow toy . endseq',
#   'startseq A dog leaps to catch a ball in a field . endseq',
#   'startseq A white dog is trying to catch a ball in midair over a grassy field . endseq',
#   'startseq The white dog is playing in a green field with a yellow toy . endseq'],
#  '1022454428_b6b660a67b': ['startseq A couple and an infant , being held by the male , sitting next to a pond with a near by stroller . endseq',
#   'startseq A couple sit on the grass with a baby and stroller . endseq',
#   'startseq A couple with their newborn baby sitting under a tree facing a lake . endseq',
#   'startseq A man and woman care for an infant along the side of a body of water . endseq',
#   'startseq Couple with a baby sit outdoors next to their stroller . endseq'],
#  '1022975728_75515238d8': ['startseq A black dog running in the surf . endseq',
#   'startseq A black lab with tags frolicks in the water . endseq',
#   'startseq A dog splashes in the water endseq',
#   'startseq The black dog runs through the water . endseq',
#   'startseq This is a black dog splashing in the water . endseq'],
#  '102351840_323e3de834': ['startseq A man drilling a hole in the ice . endseq',
#   'startseq A man is drilling through the frozen ice of a pond . endseq',
#   'startseq A person in the snow drilling a hole in the ice . endseq',
#   'startseq A person standing on a frozen lake . endseq',
#   'startseq Two men are ice fishing . endseq'],
#  '1024138940_f1fefbdce1': ['startseq Two different breeds of brown and white dogs play on the beach . endseq',
#   'startseq Two dogs are making a turn on a soft sand beach . endseq',
#   'startseq Two dogs playing in the sand at the beach . endseq',
#   'startseq Two dogs playing together on a beach . endseq',
#   'startseq Two large tan dogs play along a sandy beach . endseq'],
#  '102455176_5f8ead62d5': ['startseq A man uses ice picks and crampons to scale ice . endseq',
#   'startseq an ice climber in a blue jacket and black pants is scaling a frozen ice wall . endseq',
#   'startseq An ice climber scaling a frozen waterfall . endseq',
#   'startseq A person in blue and red ice climbing with two picks . endseq',
#   'startseq Climber climbing an ice wall endseq'],
#  '1026685415_0431cbf574': ['startseq A black dog carries a green toy in his mouth as he walks through the grass . endseq',
#   'startseq A black dog carrying something through the grass . endseq',
#   'startseq A black dog has a blue toy in its mouth . endseq',
#   'startseq A dog in grass with a blue item in his mouth . endseq',
#   'startseq A wet black dog is carrying a green toy through the grass . endseq'],
#  '1028205764_7e8df9a2ea': ['startseq A man and a baby are in a yellow kayak on water . endseq',
#   'startseq A man and a little boy in blue life jackets are rowing a yellow canoe . endseq',
#   'startseq A man and child kayak through gentle waters . endseq',
#   'startseq A man and young boy ride in a yellow kayak . endseq',
#   'startseq Man and child in yellow kayak endseq'],
#  '1030985833_b0902ea560': ['startseq A black dog and a brown dog are jumping up to catch a red toy . endseq',
#   'startseq A black dog and a brown dog play with a red toy on a courtyard . endseq',
#   'startseq A brown and black lab are outside and the black lab is catching a toy in its mouth . endseq',
#   'startseq Black dog snaps at red and black object as brown dog lunges . endseq',
#   'startseq The Chocolate Lab jumps too late to get the toy as the Black Lab captures it in the driveway . endseq'],
#  '103195344_5d2dc613a3': ['startseq A man in black is sitting next to a modern art structure in front of a glass building . endseq',
#   'startseq A man sits and reads a newspaper by a sculpture outside of an office building . endseq',
#   'startseq a man sits near a large statue . endseq',
#   'startseq A man sitting in front of a metal sculpture in front of a building . endseq',
#   'startseq The man with the backpack is sitting in a buildings courtyard in front of an art sculpture reading . endseq'],
#  '103205630_682ca7285b': ['startseq A tent is being set up on the ice . endseq',
#   'startseq Two men are about to enter an ice fishing tent on a snow covered lake . endseq',
#   'startseq two men setting up a blue ice fishing hut on an iced over lake endseq',
#   'startseq Two men , standing on an ice , looking into something covered with a blue tarp . endseq',
#   'startseq Two people standing outside a blue tent structure on a snowy surface . endseq'],
#  '1032460886_4a598ed535': ['startseq a man is standing in front of a skyscraper endseq',
#   'startseq A man stands in front of a skyscraper . endseq',
#   'startseq A man stands in front of a very tall building . endseq',
#   'startseq Behind the man in a red shirt stands a large skyscraper . endseq',
#   'startseq There is a skyscraper in the distance with a man walking in front of the camera . endseq'],
#  '104136873_5b5d41be75': ['startseq People sit on the mountainside and check out the view . endseq',
#   'startseq Three people are on a hilltop overlooking a green valley . endseq',
#   'startseq Three people hang out on top of a big hill . endseq',
#   'startseq Three people overlook a green valley . endseq',
#   'startseq Three people rest on a ledge above the moutains . endseq'],
#  '1042020065_fb3d3ba5ba': ['startseq A boy in a green shirt is looking down at many inflatable boats . endseq',
#   'startseq A boy in a green shirt watches kayakers . endseq',
#   'startseq A boy looks over a railing at the many boats and rafts below in the water . endseq',
#   'startseq A young boy overlooking a crowd of inflatable boats . endseq',
#   'startseq A young boy wearing a jersey looks down over a ledge at many boats in the water . endseq'],
#  '1042590306_95dea0916c': ['startseq A man and woman pose for the camera while another man looks on . endseq',
#   'startseq A man is holding the hand of a woman up to his mouth in front of some buildings while another man looks on . endseq',
#   'startseq A multiracial couple posing for a picture endseq',
#   'startseq Asian man and blond woman holding hands outdoors , man in background watches . endseq',
#   'startseq Guy in blue shirt biting hand of girl in black striped jacket while another guy watches endseq'],
#  '1048710776_bb5b0a5c7c': ['startseq a couple of several people sitting on a ledge overlooking the beach endseq',
#   'startseq A group of people sit on a wall at the beach . endseq',
#   'startseq A group of teens sit on a wall by a beach . endseq',
#   'startseq Crowd of people at the beach . endseq',
#   'startseq Several young people sitting on a rail above a crowded beach . endseq'],
#  '1052358063_eae6744153': ['startseq A boy takes a jump on his skateboard while another boy with a skateboard watches . endseq',
#   'startseq A child is performing a skateboard trick while another child with a skateboard leans on a wall . endseq',
#   'startseq A little boy skateboarder is doing a trick on his board while another young skateboarder watches . endseq',
#   'startseq a young boy skateboarder jumping on a platform on a skateboard . endseq',
#   'startseq Two skateboarders . endseq'],
#  '105342180_4d4a40b47f': ['startseq A girl paddling down a large river , as seen from behind her . endseq',
#   'startseq A woman kayaking down a river . endseq',
#   'startseq A woman paddles a boat down a river . endseq',
#   'startseq A woman with a paddle . endseq',
#   'startseq A woman with a paddle sits in a boat on the water . endseq'],
#  '1053804096_ad278b25f1': ['startseq A girl in pigtails splashes in the shallow water . endseq',
#   'startseq A girls plays in the surf . endseq',
#   'startseq a girl with pigtails is playing in the ocean by the beach . endseq',
#   'startseq A girl with pigtails plays in the water . endseq',
#   'startseq A young girl in pigtails plays in the water . endseq'],
#  '1055623002_8195a43714': ['startseq A group of four children wearing pajamas have a pillow fight . endseq',
#   'startseq A group of kids have a pillow-fight . endseq',
#   'startseq A group of young children playing pillow fight on a bed . endseq',
#   'startseq Children having a pillow fight . endseq',
#   'startseq Four children are having a pillow fight . endseq'],
#  '1055753357_4fa3d8d693': ['startseq Two constructions workers sit on a beam taking a break . endseq',
#   'startseq Two construction workers are sitting up on the side of a building . endseq',
#   'startseq Two construction workers sitting on an I-beam . endseq',
#   'startseq Two construction workers take a seat on a steel beam . endseq',
#   'startseq Two men take a break from construction . endseq'],
#  '1056359656_662cee0814': ['startseq A little girl looking at a brochure on train rides endseq',
#   'startseq a young blond girl with a magizine in her hands endseq',
#   'startseq A young girl on a train reads a book about train rides . endseq',
#   'startseq A young girl sits on a seat and looks at a train pamphlet . endseq',
#   'startseq Child sitting down looking at train ride brochure endseq'],
#  '1056873310_49c665eb22': ['startseq A brown dog is running after a black dog on a rocky shore . endseq',
#   'startseq A brown dog is running after the black dog . endseq',
#   'startseq Two dogs playing on a beach . endseq',
#   'startseq Two dogs run across stones near a body of water . endseq',
#   'startseq Two dogs run towards each other on a rocky area with water in the background . endseq'],
#  '1057089366_ca83da0877': ['startseq A boy descends off the end of a high diving board . endseq',
#   'startseq A child jumps off a high diving board into the pool . endseq',
#   'startseq A kid jumps off the diving board and into the swimming pool below . endseq',
#   'startseq A little kid is jumping off a high dive at the pool . endseq',
#   'startseq The boy is jumping off a high diving board into the pool . endseq'],
#  '1057210460_09c6f4c6c1': ['startseq A guy stands by a window taking his overshirt off . endseq',
#   'startseq A man in a tank top stands next to a chrome door . endseq',
#   'startseq A man puts his shirt on near an elevator . endseq',
#   'startseq A man stands by an elevator with his head down . endseq',
#   'startseq The man is putting on his shirt near an elevator . endseq'],
#  '1057251835_6ded4ada9c': ['startseq A light-colored dog runs on the beach . endseq',
#   'startseq A small yellow dog runs on a beach endseq',
#   'startseq A tan dog runs on a sandy beach . endseq',
#   'startseq A white dog is running down a rocky beach . endseq',
#   'startseq Light brown dog running along the beach . endseq'],
#  '106514190_bae200f463': ['startseq A hiker standing high on a bluff overlooking the mountains below . endseq',
#   "startseq a person on ski 's looks from hill over snow covered landscape endseq",
#   'startseq A skier is overlooking a snow-covered mountain . endseq',
#   'startseq A skier is overlooking the beautiful white snow covered landscape . endseq',
#   'startseq A skier pauses on a mountaintop . endseq'],
#  '1067180831_a59dc64344': ['startseq A black and white dog is attempting to catch a yellow and purple object in a low cut yard . endseq',
#   'startseq A black and white dog jumps after a yellow toy . endseq',
#   'startseq a black and white dog jumps to get the Frisbee . endseq',
#   'startseq A black dog is jumping up to catch a purple and green toy . endseq',
#   'startseq A dog jumps to catch a toy . endseq'],
#  '1067675215_7336a694d6': ['startseq A man in blue shorts is laying in the street . endseq',
#   'startseq A man in blue shorts lays down outside in a parking lot . endseq',
#   'startseq A man laying down in middle of street during heavy traffic . endseq',
#   'startseq A man lies on a mat in a parking lot between a brown SUV and a yellow pickup with an open door . endseq',
#   'startseq A shirtless man is laying down in the middle of a busy street . endseq'],
#  '1067790824_f3cc97239b': ['startseq A white and black dog and a brown dog in sandy terrain . endseq',
#   'startseq A woolly dog chases a Doberman on a beach . endseq',
#   'startseq One dog is chasing another one on the beach . endseq',
#   'startseq The two large dogs are running through sand . endseq',
#   'startseq Two large dogs chasing each other at the beach . endseq'],
#  '1072153132_53d2bb1b60': ['startseq A black and white dog catches a toy in midair . endseq',
#   'startseq A dog and a tennis ball . endseq',
#   'startseq A dog is jumping to catch a object thrown at it , endseq',
#   'startseq A dog leaps while chasing a tennis ball through a grassy field . endseq',
#   'startseq A multicolor dog jumping to catch a tennis ball in a grassy field . endseq'],
#  '107318069_e9f2ef32de': ['startseq A crowd watching air balloons at night . endseq',
#   'startseq A group of hot air balloons lit up at night . endseq',
#   'startseq People are watching hot air balloons in the park . endseq',
#   'startseq People watching hot air balloons . endseq',
#   'startseq Seven large balloons are lined up at nighttime near a crowd . endseq'],
#  '1075716537_62105738b4': ['startseq A child with a helmet on his head rides a bike . endseq',
#   'startseq A little boy rides a bike down a hill on a miniature dirt bike . endseq',
#   'startseq A young boy in a helmet rides a bike on the road . endseq',
#   'startseq The little boy rides his bicycle in a race . endseq',
#   'startseq The young boy pedals quickly at a BMX race . endseq'],
#  '1075867198_27ca2e7efe': ['startseq A man in a brown shirt and dark shorts plays on the beach with his two black dogs . endseq',
#   'startseq A man in shorts with two black dogs holds a ball throwing toy at the beach . endseq',
#   'startseq a man playing with two black dogs on the beach endseq',
#   'startseq A man with two dogs on a beach endseq',
#   'startseq Man at the beach with two dogs . endseq'],
#  '1075881101_d55c46bece': ['startseq a boy cleans the bubbles off his face . endseq',
#   'startseq A boy covered in suds has his face wiped clean . endseq',
#   'startseq A boy is covered in bubbles . endseq',
#   'startseq A child covered in foam is climbing on a black inflatable ramp . endseq',
#   'startseq A person covered in soapy water is getting cleaned off . endseq'],
#  '1079274291_9aaf896cc1': ['startseq A little boy sticks his tongue out for the camera . Another boy looks on . endseq',
#   'startseq Two boys make faces . endseq',
#   'startseq Two young boys are looking at the camera , one smiling , the other sticking his tongue out . endseq',
#   'startseq Two young boys look up at the camera as one sticks out his tongue . endseq',
#   'startseq two young boys making silly faces . endseq'],
#  '10815824_2997e03d76': ['startseq A blonde horse and a blonde girl in a black sweatshirt are staring at a fire in a barrel . endseq',
#   'startseq A girl and her horse stand by a fire . endseq',
#   "startseq A girl holding a horse 's lead behind a fire . endseq",
#   'startseq A man , and girl and two horses are near a contained fire . endseq',
#   'startseq Two people and two horses watching a fire . endseq'],
#  '1082252566_8c79beef93': ['startseq A bulldog , a sheep dog , and a boxer standing in a yard . endseq',
#   'startseq A large brown dog is pushing a small Boston terrier with his face while anouther dog watches . endseq',
#   'startseq A large skinny dog stands near two smaller dogs int the dirt . endseq',
#   'startseq There are three dogs starring at a ball in the middle of them . endseq',
#   'startseq Three dogs of various sizes . endseq'],
#  '1084104085_3b06223afe': ['startseq a woman in a yellow shirt and green shorts is climbing an artificial red wall whilst wearing a safety harness . endseq',
#   'startseq A woman in blue shorts and a white shirt is indoor rock climbing . endseq',
#   'startseq The girl is climbing a rock wall . endseq',
#   'startseq The girl is in a harness , climbing rocks . endseq',
#   'startseq Woman climbing an artificial rock wall . endseq'],
#  '1087168168_70280d024a': ['startseq A boy is jumping on an inflatable ring and a girl is watching him endseq',
#   'startseq A boy jumping on a water jumphouse endseq',
#   'startseq A teenage boy is jumping on an inflatable slide . endseq',
#   'startseq A young boy jumping and a young girl seating in an inflatable pool . endseq',
#   'startseq Two young kids are playing in the water on an inflated toy . endseq'],
#  '108898978_7713be88fc': ['startseq Skiiers walking up the hill through a forest . endseq',
#   'startseq Two men are skiing in the snow in a wooded area . endseq',
#   'startseq Two people wearing yellow jackets cross-country skiing . endseq',
#   'startseq Two skiers are making their way through woodland . endseq',
#   'startseq Two skiers are sliding down a trail in the woods . endseq'],
#  '108899015_bf36131a57': ['startseq A lone skier is making their way up a mountain . endseq',
#   'startseq Skiiers at the top of a snow covered hill . endseq',
#   'startseq Two hikers climbing a snowy hill . endseq',
#   'startseq Two people are on a snow-covered mountain . endseq',
#   'startseq Two people climbing up a snowy mountain . endseq'],
#  '1089181217_ee1167f7af': ['startseq a brown dog running down a paved pathway endseq',
#   'startseq A brown dog running next to grass . endseq',
#   'startseq A dog is running down a road . endseq',
#   'startseq A light brown dog runs down a path happily . endseq',
#   'startseq Energetic brown dog running endseq'],
#  '109202756_b97fcdc62c': ['startseq A woman dressed in a blue jacket and blue jeans rides a brown horse near a frozen lake and snow-covered mountain . endseq',
#   'startseq A woman in a blue jacket rides a brown pony near water . endseq',
#   'startseq A woman rides a horse near a frozen lake in the wintertime . endseq',
#   'startseq A young blond woman sitting atop a brown draft horse in the snowy mountains . endseq',
#   'startseq Woman n blue jacket sits on daft horse near a frozen lake . endseq'],
#  '109202801_c6381eef15': ['startseq Two draft horses pull a cart through the snow . endseq',
#   'startseq Two golden brown horses pull a sleigh driven by a woman in a blue coat . endseq',
#   'startseq Two horses are pulling a woman in a cart . endseq',
#   'startseq Two horses pull a carriage driven by a woman over snow covered ground . endseq',
#   'startseq Two horses pulling a sled steered by a smiling blond woman . endseq'],
#  '109260216_85b0be5378': ['startseq A person climbing down a sheer rock cliff using a rope endseq',
#   'startseq A person climbs a tall , flat mountain while holding onto a safety rope . endseq',
#   'startseq A person is climbing a rock while holding onto a white rope . endseq',
#   'startseq A person rappels down a steep incline . endseq',
#   'startseq A person wearing a red vest climbs up a steep rock . endseq'],
#  '109260218_fca831f933': ['startseq People stand inside a rock dome . endseq',
#   'startseq Shaft of light in a cave shows three spelunkers endseq',
#   'startseq Spelunkers pose inside a rock cavern while bathed in sunlight from the surface . endseq',
#   'startseq three people sit in a cave . endseq',
#   'startseq Three rock climbers are posing on big rocks . endseq'],
#  '1093716555_801aacef79': ['startseq a group of backpackers lay on the dry ground . endseq',
#   'startseq A group of hikers are resting on the ground in front of some mountains . endseq',
#   'startseq People camp with the mountains in the background . endseq',
#   'startseq Several hikers rest with their gear in front of a mountain . endseq',
#   'startseq The group of hikers is resting in front of a mountain . endseq'],
#  '1093737381_b313cd49ff': ['startseq A woman in a blue dress stands with a chalk portrait of two children playing by a stream . endseq',
#   'startseq A woman standing in front of a chalk drawing endseq',
#   'startseq A woman stands next to a chalk drawing in front of a barn-like structure . endseq',
#   'startseq A woman stands outside near an elaborate chalk illustration . endseq',
#   'startseq A woman wearing a blue dress is drawing a picture of a boy and a girl on the sidewalk with sidewalk chalk . endseq'],
#  '1094462889_f9966dafa6': ['startseq A brown dog plays in a deep pile of snow . endseq',
#   'startseq A dog looking at the camera in snow . endseq',
#   'startseq a dog runs through the snow . endseq',
#   'startseq A tan dog stand in the snow and looks up . endseq',
#   'startseq The brown dog is out in the snow . endseq'],
#  '1095476286_87d4f8664e': ['startseq A boy jumping in a fountain . endseq',
#   'startseq a boy plays in the fountains . endseq',
#   'startseq A child plays in a fountain . endseq',
#   'startseq A little boy playing in the water . endseq',
#   'startseq A young boy is jumping through water being sprayed up from the ground . endseq'],
#  '1095580424_76f0aa8a3e': ['startseq A Corgi runs out of a tunnel . endseq',
#   'startseq A dog runs out of a tunnel on a course . endseq',
#   'startseq Dog running out of tunnel on obstacle course endseq',
#   'startseq The dog is running out of the tunnel on a dog obedience course . endseq',
#   'startseq The small brown and white dog is running out of a small tunnel . endseq'],
#  '1095590286_c654f7e5a9': ['startseq A blond dog and a black and white dog run in a dirt field . endseq',
#   'startseq a dog chases another dog . endseq',
#   'startseq A yellow dog and a black and white dog are running in the dirt . endseq',
#   'startseq Two dogs are running in a field . endseq',
#   'startseq two dogs running around endseq'],
#  '1095980313_3c94799968': ['startseq A little girl in a blue swimsuit is walking along a wooden fence next to a sandy beach . endseq',
#   'startseq A little girl with arms outstretched is posing at the beach . endseq',
#   'startseq A young girl walks on a railing in front of the beach . endseq',
#   'startseq Little girl in blue swimsuit standing on a handrail near a beach . endseq',
#   'startseq The little girl in the blue bathing suit is posing at the beach . endseq'],
#  '1096097967_ac305887b4': ['startseq A black and white dog drinking water from a water spray . endseq',
#   'startseq A black and white dog is being soaked with a jet of water in a blue paddling pool . endseq',
#   'startseq A dog sticking its face into the shower from a garden hose . endseq',
#   'startseq A small white dog gets sprayed by water endseq',
#   'startseq A white and black dog is jumping into a pool . endseq'],
#  '1096165011_cc5eb16aa6': ['startseq a boy smiles underwater . endseq',
#   'startseq A red-headed boy swimming underwater . endseq',
#   'startseq A small boy swimming underwater endseq',
#   'startseq A smiling boy swims underwater in a pool . endseq',
#   'startseq The boys smiles underwater at the pool . endseq'],
#  '109671650_f7bbc297fa': ['startseq A boy in yellow shorts is standing on top of a cliff . endseq',
#   'startseq A boy wearing blue and yellow walking on a cliff edge . endseq',
#   'startseq A little boy standing high in the air on a rock . endseq',
#   'startseq A young child is standing alone on some jagged rocks . endseq',
#   'startseq Child stands near edge of cliff . endseq'],
#  '109738763_90541ef30d': ['startseq A person on a snowmobile in mid jump . endseq',
#   'startseq A snowmobiler flies through the air . endseq',
#   'startseq A snowmobile rider flies through the air on his or her machine in front of tall pine trees . endseq',
#   'startseq Rider jumps snowmobile high in rural area . endseq',
#   'startseq The man is up in the air . endseq'],
#  '109738916_236dc456ac': ['startseq People are riding around on snowmobiles . endseq',
#   'startseq People pose with helmets and goggles on while riding snowmobiles . endseq',
#   'startseq Several people are taking a break while on a snowmobiling ride . endseq',
#   'startseq Three people and two snowmobiles . endseq',
#   'startseq Two helmeted men sit on yellow snowmobiles while another man stands behind watching . endseq'],
#  '109823394_83fcb735e1': ['startseq Three people drive ATVs . endseq',
#   'startseq Three people on ATVs in a brown field turn their heads to look at the camera . endseq',
#   "startseq Three people on ATV 's outside . endseq",
#   "startseq three people on four wheel ATV 's in a field . endseq",
#   'startseq Three people ride their four wheelers through the field . endseq'],
#  '109823395_6fb423a90f': ['startseq A four wheeler jumping in an empty field . endseq',
#   'startseq A man on a four wheeler is flying through the air . endseq',
#   'startseq A person is riding an orange ATV in a large empty field . endseq',
#   'startseq Man jumping with all terrain vehicle endseq',
#   'startseq Man on an ATV catching air ! endseq'],
#  '109823397_e35154645f': ['startseq A man jumps gin the air while riding an ATV endseq',
#   'startseq A man on a four-wheeler jumps near a small building . endseq',
#   'startseq An ATV is airborne over a field in front of a white structure . endseq',
#   'startseq A person dressed in a tan jacket jumps a quad over a harvested cornfield in front of a small out building . endseq',
#   'startseq Man on four wheeler in the air . endseq'],
#  '1104133405_c04a00707f': ['startseq A boy carrying a soccer ball . endseq',
#   'startseq A boy walks with a ball tucked under his arm . endseq',
#   'startseq A boy walks with a soccer ball near a fence . endseq',
#   'startseq A boy wearing a white t-shirt walks on the grass and carries a soccer ball . endseq',
#   'startseq Small boy carries a soccer ball on a field . endseq'],
#  '1105959054_9c3a738096': ['startseq A child painting a picture . endseq',
#   'startseq An artist paints clouds onto a canvas . endseq',
#   'startseq A young girl painting a picture . endseq',
#   'startseq A young girl with braids is painting with water colors on a white paper on the wall . endseq',
#   'startseq The child paints on a large paper with water colors . endseq'],
#  '110595925_f3395c8bd6': ['startseq A cyclist is riding a bicycle on a curved road up a hill . endseq',
#   'startseq A man in aerodynamic gear riding a bicycle down a road around a sharp curve . endseq',
#   'startseq A man on a mountain bike is pedaling up a hill . endseq',
#   'startseq Man bicycle up a road , while cows graze on a hill nearby . endseq',
#   'startseq The biker is riding around a curve in the road . endseq'],
#  '1107471216_4336c9b328': ['startseq A little girl is holding a cine camera in front of her face . endseq',
#   'startseq A young girl is looking through an old fashioned video camera . endseq',
#   'startseq A young girl steadies her aim with a camera endseq',
#   'startseq Girl with rosy cheeks and lips holding black toy gun . endseq',
#   'startseq There is a kid with a gun . endseq'],
#  '1110208841_5bb6806afe': ['startseq A black and white Border Collie catches a Frisbee in front of an audience . endseq',
#   'startseq a brown and white dog catches a Frisbee in it mouth in front of a group of people . endseq',
#   'startseq A brown and white dug jumping up to catch a Frisbee while an audience watches . endseq',
#   'startseq A dog jumps to catch a Frisbee , while many people watch . endseq',
#   'startseq An agile dog catches a Frisbee while a crowd of onlookers watches closely . endseq'],
#  '1112212364_0c48235fc2': ['startseq A baby is sitting on and playing with smooth rocks . endseq',
#   'startseq A baby is stacking rocks on the beach . endseq',
#   'startseq A small boy is playing with rocks endseq',
#   'startseq A toddler sitting on a pile of rocks holding a rock at a beach . endseq',
#   'startseq Toddler sits on a pile of rocks . endseq'],
#  '111537217_082a4ba060': ['startseq A man climbing a rock wall endseq',
#   'startseq A man climbing the side of a cliff . endseq',
#   'startseq A man is rock climbing . endseq',
#   'startseq Man with red shoes , white shirt and grey pants climbing . endseq',
#   'startseq The young man with the white t-shirt and jeans is rappeling up the rock wall . endseq'],
#  '111537222_07e56d5a30': ['startseq A climber wearing a blue helmet and headlamp is attached to a rope on the rock face . endseq',
#   'startseq A man climbs a rocky wall . endseq',
#   'startseq a rock climber climbs a large rock . endseq',
#   'startseq A woman in purple snakeskin pants climbs a rock . endseq',
#   'startseq Person with blue helmet and purple pants is rock climbing . endseq'],
#  '1115565519_d976d4b1f1': ['startseq A child playing with a fountain at the beach . endseq',
#   'startseq A child plays with a fountain . endseq',
#   'startseq A girl looks at a fountain that sprays water . endseq',
#   'startseq A little girl playing in water on a frog sculpture . endseq',
#   'startseq The little girl is playing with a toy in a public fountain . endseq'],
#  '1115679311_245eff2f4b': ['startseq A black dog is jumping over a log along a beach . endseq',
#   'startseq A black dog runs along the beach and jumps over a wood barrior . endseq',
#   'startseq A dog is running on the beach . endseq',
#   'startseq a dog jumping over a small wall at a beach near the water . endseq',
#   'startseq An animal is running on the beach . endseq'],
#  '111766423_4522d36e56': ["startseq A black and white bird eating seeds out of someone 's hand endseq",
#   'startseq A black and white bird standing on a hand . endseq',
#   "startseq A small bird sits in a person 's hand and eats seeds . endseq",
#   'startseq Black and white bird standing on hand of someone holding sunflower seeds endseq',
#   'startseq The small bird is clinging to a finger of the hand holding the seeds . endseq'],
#  '1117972841_2b9261f95f': ['startseq A brown dog is running in the sand . endseq',
#   'startseq A brown dog playing in the sand . endseq',
#   'startseq A brown dog plays at the beach . endseq',
#   'startseq A dog is standing in the sand . endseq',
#   'startseq A dog running fast in the sand . endseq'],
#  '1118557877_736f339752': ['startseq A little boy stands in the surf . endseq',
#   'startseq A small child wades through the water while being guided by another person . endseq',
#   'startseq A young boy laughs while splashing in the ocean . endseq',
#   'startseq a young boy wearing a colorful bathing suit splashing in the ocean endseq',
#   'startseq A young child splashing in water . endseq'],
#  '1119418776_58e4b93eac': ['startseq A black and white dog is running through the field . endseq',
#   'startseq A black , brown and white dog running through a field . endseq',
#   'startseq A brown , black and white dog is running through a large field with its mouth open . endseq',
#   'startseq A dog running in a field . endseq',
#   'startseq A dog with its mouth open running through a field torwards the camera . endseq'],
#  '1119463452_69d4eecd08': ['startseq A girl in a pink swimsuit in a pool endseq',
#   'startseq A girl swimming in a pool . endseq',
#   'startseq A little girl in a pink bathing suit swimming in a pool . endseq',
#   'startseq A little girl swimming in a pool . endseq',
#   'startseq Smiling little girl swimming in outdoor pool . endseq'],
#  '1121416483_c7902d0d49': ['startseq A child is standing on her head . endseq',
#   'startseq A little girl standing on her head . endseq',
#   'startseq A small child doing a handstand on a bed . endseq',
#   'startseq A young girl does a handstand on a bed with blue sheets . endseq',
#   'startseq The girl is upside down on a bed endseq'],
#  '112178718_87270d9b4d': ['startseq A guy stands in the sand with a snowboard behind him . endseq',
#   'startseq A man holds a surfboard on the beach . endseq',
#   'startseq a man holds his snowboard in the sand . endseq',
#   'startseq A man with his surfboard stands in the sand . endseq',
#   'startseq Man is standing on white sand and holding a snowboard . endseq'],
#  '112243673_fd68255217': ['startseq People on ATVs and dirt bikes are traveling along a worn path in a field surrounded by trees . endseq',
#   "startseq Three people are riding around on ATV 's and motorcycles . endseq",
#   'startseq Three people on motorbikes follow a trail through dry grass . endseq',
#   'startseq Three people on two dirt-bikes and one four-wheeler are riding through brown grass . endseq',
#   'startseq Three people ride off-road bikes through a field surrounded by trees . endseq'],
#  '1124448967_2221af8dc5': ['startseq A half naked man is sleeping on his chair outdoors . endseq',
#   'startseq An older man sits back and relaxes on a patio outside an adobe building where many bicycles are propped . endseq',
#   'startseq A shirtless man in a white cap relaxes in a deck chair , close to three parked bicycles . endseq',
#   'startseq Man relaxing in a folding chair on the street . endseq',
#   'startseq Topless old man wearing slippers , navy blue pants and a white hat while reclining in a chair outside . endseq'],
#  '1129704496_4a61441f2c': ['startseq A brown and white and a black and white dog hauling in a floating toy from the ocean . endseq',
#   'startseq Both dogs retrieve the play toy from the water . endseq',
#   'startseq Two dogs in the ocean playing with a toy endseq',
#   'startseq Two dogs run through the water with a rope in their mouths . endseq',
#   'startseq Two dogs tug at a chew toy in the surf . endseq'],
#  '1130017585_1a219257ac': ['startseq There are three young people , one dark haired holding a bottled drink , one with head tilted back and finger in her mouth , and one with spiked hair . endseq',
#   'startseq The young people party in the streets . endseq',
#   'startseq Three girls make faces as one takes a drink while they stand in a busy street . endseq',
#   'startseq Three women on the street drinking and posing endseq',
#   'startseq Three young women pose for the camera at a parade . endseq'],
#  '1130401779_8c30182e3e': ['startseq Two brown dogs are creating large splashes as they run in a river . endseq',
#   'startseq Two brown dogs in the water . endseq',
#   'startseq Two brown dogs running through water . endseq',
#   'startseq Two brown dogs runs through the water . endseq',
#   'startseq Two dogs splash through the water . endseq'],
#  '1131340021_83f46b150a': ['startseq A young boy runs while wearing sandals . endseq',
#   'startseq Little boy in a striped shirt and brown shorts is running . endseq',
#   'startseq The little boy , in a short sleeved shirt and shorts , is running outside . endseq',
#   'startseq The little boy is wearing a black pinstripe shirt and walking on a deck . endseq',
#   'startseq Young boy running outside on the pavement . endseq'],
#  '1131804997_177c3c0640': ['startseq Two men are sitting on the ground and going through their backpacks . endseq',
#   'startseq Two men sitting in front of a railing are looking at something . endseq',
#   'startseq Two men with backpacks placed in front of them sitting in front of a railing . endseq',
#   'startseq Two men with backpacks are sitting on cardboard along a railing . endseq',
#   'startseq Two older men with backpacks sit at a bus station . endseq'],
#  '1132772170_600610c5df': ['startseq A child leaping from bed to bed behind the back of a man . endseq',
#   'startseq A man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room . endseq',
#   'startseq a man wearing a yellow shirt standing in the middle of two beds that a boy is jumping on in the background endseq',
#   'startseq A young child jumping on the bed as a man looks the other way . endseq',
#   'startseq Man standing in the bedroom with little boy jumping into bed . endseq'],
#  '1141718391_24164bf1b1': ['startseq A bridge through high green plants , a man and a woman on it . endseq',
#   'startseq A man and a woman are crossing over a rope bridge with greenery all over them . endseq',
#   'startseq A man and a woman are walking across a rope bridge . endseq',
#   'startseq A man and a woman crossing a suspension bridge in a tropical setting . endseq',
#   'startseq Woman and man walking across wooden rope bridge with a caution sign beside it . endseq'],
#  '1141739219_2c47195e4c': ['startseq A family gathered at a painted van endseq',
#   'startseq A girl climbing down from the side of a bright blue truck while others watch . endseq',
#   'startseq A man is helping a girl step down from a colorful truck whilst a woman and three children watch . endseq',
#   'startseq A very colorful bus is pulled off to the side of the road as its passengers load . endseq',
#   'startseq Two women and four children standing next to a brightly painted truck . endseq'],
#  '1142283988_6b227c5231': ['startseq A blond woman poses with a person in a pink costume . endseq',
#   'startseq A smiling woman holds a person dressed in a pig costume . endseq',
#   "startseq A young woman hugs a young man who 's wearing a pink costume . endseq",
#   'startseq Blond embracing young man in pink costume , at event endseq',
#   'startseq Two people are hugging and one is wearing a pink-hooded stretch top . endseq'],
#  '1142847777_2a0c1c2551': ['startseq A bicyclist riding on a city street . endseq',
#   'startseq A woman in a blue helmet and brown shorts rides her bike on a busy street . endseq',
#   'startseq A woman is riding a blue bike . endseq',
#   'startseq A woman is riding her bicycle in traffic endseq',
#   'startseq A woman wearing a blue helmet rides her bicycle in a parking lot . endseq'],
#  '1143373711_2e90b7b799': ['startseq A bicycle rider is crossing a street . endseq',
#   'startseq A bicyclist getting ready to cross a street . endseq',
#   'startseq A biker in spandex riding on a busy street . endseq',
#   'startseq A man in blue and white biking gear rides down a busy street . endseq',
#   'startseq a man wearing a helmet riding his bicycle down the street . endseq'],
#  '1143882946_1898d2eeb9': ['startseq A lady wearing a helmet holding a bike . endseq',
#   'startseq A woman in a blue vest and a sky blue helmet stands with her bicycle in traffic . endseq',
#   'startseq A woman in a helmet rides her bike behind a car . endseq',
#   'startseq A woman with a helmet and a backpack walks next to her bike . endseq',
#   'startseq Women with bike and helmet wait for traffic . endseq'],
#  '1144288288_e5c9558b6a': ['startseq A man in shorts is jogging along a street with a headset . endseq',
#   'startseq A person in blue shorts and wearing a Walkman jogs . endseq',
#   'startseq A woman in a white shirt and blue shorts is wearing headphones . endseq',
#   'startseq A woman walks on a street wearing headphones . endseq',
#   'startseq A woman wearing a white hat and shirt is jogging down a street with a plant store on the corner . endseq'],
#  '1148238960_f8cacec2fc': ['startseq Bicyclists are standing at an intersection . endseq',
#   'startseq Bicyclists waiting at an intersection . endseq',
#   'startseq People on bicycles waiting at an intersection . endseq',
#   'startseq People waiting at a light on bikes . endseq',
#   'startseq three bikers stop in town . endseq'],
#  '1149179852_acad4d7300': ['startseq A man without a shirt on is guiding a large brown horse pulling a green and yellow wagon . endseq',
#   'startseq A shirtless man escorts a horse pulling a carriage along a paved road . endseq',
#   'startseq A shirtless man leading a horse that is pulling a carriage . endseq',
#   'startseq Shirtless man leading a small horse-drawn covered wagon down a road endseq',
#   'startseq The shirtless man is walking the Shetland pony and carriage down the street . endseq'],
#  '114949897_490ca7eaec': ['startseq A boy hits a ball off of a tee ball into to net . endseq',
#   'startseq A child practices hitting a baseball into a net , while two adult men watch . endseq',
#   'startseq A man holds a net while a boys bats a ball into it . endseq',
#   'startseq The man is holding the net for the boy playing baseball . endseq',
#   'startseq Three people put up a batting cage . endseq'],
#  '1151466868_3bc4d9580b': ['startseq A small girl spins in the waves in the bright sun . endseq',
#   'startseq A young girl plays in shallow water . endseq',
#   "startseq A young girl wears a shirt and shorts as she plays in the ocean 's surf . endseq",
#   'startseq Girl running through the water near the shore . endseq',
#   'startseq The little girl splashes through the water . endseq'],
#  '1153704539_542f7aa3a5': ['startseq A girl playing trumpet in a marching band . endseq',
#   'startseq A teenager plays her trumpet on the field at a game . endseq',
#   'startseq a young girl wearing a blue shirt marching in a band playing a trumpet endseq',
#   'startseq Girl playing the trumpet in a marching band endseq',
#   'startseq Girl wearing blue shirt and black shorts plays trumped outside . endseq'],
#  '1159574340_99ba8c3c59': ['startseq A child jumping into a lake in a wooded area while another child plays on the shore . endseq',
#   'startseq A child jumps into the water with his sneakers on . endseq',
#   'startseq A kid jumping into a pool of water . endseq',
#   'startseq Little boy in sneakers jumping into water . endseq',
#   'startseq The man takes a leap into the water with his shoes on . endseq'],
#  '1160034462_16b38174fe': ['startseq A elderly man in a straw hat is sitting on a bench . endseq',
#   'startseq a elderly man sits alone on a park bench . endseq',
#   'startseq An old man in a straw hat sits on a park bench . endseq',
#   'startseq The old man in the brown hat is sitting on the bench . endseq',
#   'startseq White haired man in gray sweater and a straw hat sitting on a bench under a tree . endseq'],
#  '1160441615_fe6b3c5277': ['startseq Three girls are walking across a bridge covered with wood and surrounded by trees . endseq',
#   'startseq Three girls walking along an arched garden pathway . endseq',
#   'startseq Three girls walk under an arbor on a path surrounded by trees . endseq',
#   'startseq Three women walking through a tunnel in a park . endseq',
#   'startseq Three women walk through a plant covered atrium hallway . endseq'],
#  '1163282319_b729b24c46': ['startseq A girl dressed in a red top , a red cap , and light colored shorts , sits on a rock outside . endseq',
# ...
#   'startseq Four cyclists on a country trail are passing by an electricity pylon . endseq',
#   'startseq The four bicyclists are riding through the desert . endseq',
#   'startseq three bikers bike across the dry land . endseq',
#   'startseq Three cyclists ride near mountain . endseq'],
#  '2245348304_08bc5642f1': ['startseq A man in a hat sits outside near some cardboard boxes . endseq',
#   'startseq a man plays his guitar on the street . endseq',
#   'startseq A man sits on a box and plays a guitar in the street . endseq',
#   'startseq A man sits ourdoors next to cardboard boxes and plays an instrument . endseq',
#   'startseq An older musician perfoms on the street behind a cardboard box . endseq'],
#  '2245618207_fa486ba2b7': ['startseq A child in red jumps on a red object while others laugh . endseq',
#   'startseq A child touching a red plastic object , with a crowd behind him . endseq',
#   'startseq A girl in a crowd laughs and climbs on something . endseq',
#   'startseq Many children having fun outside near large buildings . endseq',
#   'startseq There is a girl in a red jacket smiling with her hand on a red blowup and a crowd behind her . endseq'],
#  '2245914678_1f82fc3d80': ['startseq A girl with dyed red hair wearing striped clothing talking on a cellphone . endseq',
#   'startseq A girl with read dreadlocks is talking on the phone . endseq',
#   'startseq a red haired girl with a black and white striped shirt talking on a cellphone endseq',
#   'startseq A woman with bright red hair and striped clothing talks on a phone . endseq',
#   'startseq A woman with red hair and a black striped shirt talking on the phone . endseq'],
#  '2245916742_73af13c733': ['startseq a man in green holding a camera stands between two of the head statues on Easter island . endseq',
#   'startseq A man stands between to large sculptures on a field . endseq',
#   'startseq A man stands by two face structures on Easter Island . endseq',
#   'startseq A person stands between two giant statues that look like faces . endseq',
#   'startseq A person stands next to the Easter Island statues . endseq'],
#  '2246717855_c0c08fe5d2': ['startseq A crowd of young people in winter clothing , waiting for the train . endseq',
#   'startseq Several people are looking at their phones in a crowded station . endseq',
#   'startseq three Japanese people wait for the train . endseq',
#   'startseq Three people in an Asian transportation station are all focused on their cellphones . endseq',
#   'startseq Three people in jackets , holding bags looking at their phones . endseq'],
#  '224702241_05af393148': ['startseq A blond dog walks in a creek with banks filled with snow . endseq',
#   'startseq A blonde dog makes his way up an icy stream with snow piled up on the sides . endseq',
#   'startseq A tan dog walks down a stream between mounds of snow . endseq',
#   'startseq Brown dog walks through river between snowbanks . endseq',
#   'startseq The dog walks through the cold water . endseq'],
#  '224702242_a62aaa6dff': ['startseq A white dog catching a soccer ball midair . endseq',
#   'startseq A white dog jumps up to catch a soccer ball in landscaped grassy yard . endseq',
#   'startseq A yellow lab jumping up into the air to catch a soccer ball . endseq',
#   'startseq Large white dog jumps in the air to catch a black and white soccer ball . endseq',
#   'startseq White dog leaping in the air for a soccer ball . endseq'],
#  '2247138288_7355861203': ['startseq Adults in winter jackets and hats swing brooms at a little yellow ball while a black dog looks on . endseq',
#   'startseq A group of people and a dog sweeping snow . endseq',
#   'startseq A group of people playing in the snow with brooms . endseq',
#   'startseq A group of people with brooms standing in the snow with a dog in the forefront . endseq',
#   'startseq Group of people standing on a snow covered ground , some are holding brooms , there is a dog with the group . endseq'],
#  '2247192427_5e106f24a9': ['startseq Children play basketball on a court . endseq',
#   'startseq four young boys play basketball . endseq',
#   'startseq Several children are playing a basketball game on a basketball court . endseq',
#   'startseq Three small boys play basketball indoors . endseq',
#   'startseq Three small boys playing basketball . endseq'],
#  '224766705_b77996527f': ['startseq A caravan of green and red vehicles going up a mountain . endseq',
#   'startseq A line of green and red dune buggys on a gravel road near rocks and large pine trees . endseq',
#   'startseq A line of off road vehicles riding along a trail . endseq',
#   'startseq A long line of off-road vehicles on a mountain trail endseq',
#   'startseq Several off-road vehicles are driving down a gravel road . endseq'],
#  '2249141510_f534708374': ['startseq A boy in red is jumping in a playground sand pit . endseq',
#   'startseq A boy in red jumping into a sandbox . endseq',
#   'startseq A boy in red jumps backward onto the sand at a playground . endseq',
#   'startseq A young boy in red leaping into sand at a playground . endseq',
#   'startseq a young boy wearing a bright red outfit jumping into the sand at a playground . endseq'],
#  '2249264723_d08655d9f2': ['startseq a boy jumps on the bright colored pillows . endseq',
#   'startseq A little boy is jumping on a couch that has a yellow and blue cushion resting on it . endseq',
#   'startseq A young boy jumps on the brown couch in his gray and blue Spiderman outfit . endseq',
#   'startseq A young child jumping onto a couch . endseq',
#   'startseq Little boy wearing gray and blue pajamas jumping on furniture with a blue and a orange pillow under him . endseq'],
#  '2249865945_f432c8e5da': ['startseq A dog plays in the snow . endseq',
#   'startseq A dog , wearing a coat , looks up from the snow . endseq',
#   'startseq A small white and grey dog in a jacket standing in the snow . endseq',
#   'startseq A white dog in a black coat is standing in the snow . endseq',
#   'startseq The white dog stands in the snow wearing a black jacket . endseq'],
#  '2250555512_71670078f5': ['startseq A dark haired man in his twenties drinks a green liquid from a plastic mug . endseq',
#   'startseq A distored image of a man drinking a green liquid in a mug . endseq',
#   'startseq A man in an oxford shirt drinks from a beer mug in an large tent . endseq',
#   'startseq A man sipping a drink . endseq',
#   'startseq a single man drinking a mug of green liquid endseq'],
#  '2250870111_8402d2319d': ['startseq A person is reading a magazine on a snowing sidewalk . endseq',
#   'startseq A person wearing jeans and a brown coat is reading and smoking on the sidewalk by a road covered with dirty snow . endseq',
#   'startseq A woman reads on newspaper on a snow covered street . endseq',
#   'startseq A woman smokes a cigarette and looks at a magazine in the middle of a snowy road . endseq',
#   'startseq A woman smoking a cigarette is standing next to the road during a wintery day . endseq'],
#  '2251418114_2b0cd4c139': ['startseq A boy stands on a rocky mountain . endseq',
#   'startseq A child on a rock formation . endseq',
#   'startseq A child sitting on a rock formation . endseq',
#   'startseq a little boy sitts on top of a big rock . endseq',
#   'startseq A person in a red jacket on top of rocks . endseq'],
#  '2251447809_2de73afcdf': ['startseq A man dressed in black walks on an icy sidewalk endseq',
#   'startseq a man walks on the icy sidewalk . endseq',
#   'startseq A quiet sidewalk in a town with a view of a traffic intersection . endseq',
#   'startseq Man walking toward his car on an icy sidewalk in the city . endseq',
#   'startseq There is a man dressed in black walking on a sidewalk with melted snow . endseq'],
#  '2251992614_0c601fae2c': ['startseq A busy street of people and two men are wearing no shirts . endseq',
#   'startseq A man walks with his shirt off and rolled up pants in a busy city street . endseq',
#   'startseq Many people are walking in a crowded street . endseq',
#   'startseq The lady watches the man without a shirt . endseq',
#   'startseq Young people are walking around a public square on a warm day . endseq'],
#  '2252123185_487f21e336': ['startseq A bunch on people are seated in a stadium . endseq',
#   'startseq A crowded stadium is full of people watching an event . endseq',
#   'startseq A crowd of people fill up a packed stadium . endseq',
#   'startseq A crowd sitting in an indoor stadium . endseq',
#   'startseq A stadium full of people watch a game . endseq'],
#  '2252264255_03fefc25af': ['startseq Two boys eating apples playing on a cement car barrier endseq',
#   'startseq Two boys with apples leap over a barrier in the street . endseq',
#   'startseq Two little boys eating apples climing over a retaining wall . endseq',
#   'startseq Two little boys holding apples near the street . endseq',
#   'startseq Two young boys with apples hop a concrete barrier . endseq'],
#  '2252299132_14ca6e584b': ['startseq a boy walks . endseq',
#   'startseq A boy wearing face paint walks along a red track . endseq',
#   'startseq A boy with face paint is running on a track . endseq',
#   'startseq a young boy running a race on a track with a painted face endseq',
#   'startseq Boy with a painted face is walking around a track . endseq'],
#  '2252403744_148fc11f68': ['startseq An Asian girl and boy playing on with a yellow ball on a black and white floor . endseq',
#   'startseq Two children play and one has a beach ball . endseq',
#   'startseq Two children play with a ball on the floor . endseq',
#   'startseq Two young children playing with each other and a ball . endseq',
#   'startseq Young girl in pink dress plays with boy and a ball endseq'],
#  '2252635585_b48b3485b0': ['startseq Two big dogs play in the snow under a tree . endseq',
#   'startseq Two dogs are playing in the snow next to a tree . endseq',
#   'startseq Two dogs are playing with a tennis ball in snow near a tree . endseq',
#   'startseq Two dogs play in the snow on the ground near a tree , with one on top of the other . endseq',
#   'startseq Two dogs tussle in the snow over a tennis ball . endseq'],
#  '2254913901_569f568926': ['startseq A Louis Vuitton store window at night . endseq',
#   'startseq A woman looks at clothes in a Louis Vuitton store window . endseq',
#   'startseq A woman widow shops outside of a Louis Vuitton store . endseq',
#   'startseq The woman in black is looking at outfits in a clothing store window . endseq',
#   'startseq Woman on the street window shops in front of the store , Louis Vuitton . endseq'],
#  '2255266906_8222af18b9': ['startseq A bird sits in a leafless tree . endseq',
#   'startseq A bird sits in a tree . endseq',
#   'startseq a black bird sits in a dead tree . endseq',
#   'startseq A black bird sitting in a leafless tree . endseq',
#   'startseq A grey dove in a bare tree . endseq'],
#  '2255332561_3375897ff0': ['startseq a lone man climbing the side of a large rock wall . endseq',
#   'startseq A man is on the side of a mountain and hiking around huge rocks . endseq',
#   'startseq A man stands on the rocky ledge of a large cliff . endseq',
#   'startseq A person stands atop a rock face . endseq',
#   'startseq The man is on the mountainside . endseq'],
#  '2255338013_566127590b': ['startseq A man is abseiling down a cliff over the ocean . endseq',
#   'startseq A man is repelling down a cliff next to a lake . endseq',
#   'startseq A man is repelling down the side of a mountain over the ocean . endseq',
#   'startseq A person is swinging by a cord over the ocean . endseq',
#   'startseq A person rappelling a cliff above a body of water . endseq'],
#  '2255342813_5b2ac6d633': ['startseq A person climbing down a rocky cliffside with water below . endseq',
#   'startseq A person repelling on the side of a cliff face . endseq',
#   'startseq A person wearing black with a white helmet is going down a mountainside with water below . endseq',
#   'startseq Extreme climbing over ocean endseq',
#   'startseq Looking down on someone climbing a cliff over water . endseq'],
#  '2255685792_f70474c6db': ['startseq Three individuals are posing on skis behind a " no skiing " sign . endseq',
#   'startseq Three people in skiing gear are standing behind a " no skiing " sign . endseq',
#   'startseq Three people on skis are standing behind a no skiing sign . endseq',
#   'startseq Three people standing in the snow behind a No Skiing sign . endseq',
#   'startseq Three people stand , ready to ski , next to a no skiing sign . endseq'],
#  '2256138896_3e24b0b28d': ['startseq A man does technical rock climbing . endseq',
#   'startseq A man dressed in all black is climbing down a mountain supported by cords endseq',
#   'startseq A man is climbing the side of a cliff . endseq',
#   'startseq a man wearing a white helmet is abseiling down a sandy colored rock face . endseq',
#   'startseq A rock climber with a white helmet is repelling . endseq'],
#  '2256218522_53b92bcbb2': ['startseq A black and white dog is running through the sand at a beach . endseq',
#   'startseq A black and white dog playing in the sand . endseq',
#   'startseq A dog bounding across the sandy landscape in front of people watching . endseq',
#   'startseq A dog lunges across a beach . endseq',
#   'startseq Black dog running across dirt . endseq'],
#  '2256231539_05c27179f1': ['startseq A child holds a football and runs from other children . endseq',
#   'startseq A young boy in a blue uniform running with a football while playing a game of flag football . endseq',
#   'startseq A young boy weating blue shorts and cleats holding a football running from other boys . endseq',
#   'startseq A young male carrying a football and running while two other boys run behind him . endseq',
#   'startseq The boy in blue runs with the ball whilst being chased by two boys in red . endseq'],
#  '2256320794_0286c31bfa': ['startseq A dog is waling on sand . endseq',
#   'startseq A dog that looks like Lassie , making a funny face . endseq',
#   'startseq a puppy runs in the sand . endseq',
#   'startseq Dog has mouth open in field . endseq',
#   'startseq The collie is standing outdoors on a sandy area . endseq'],
#  '2257099774_37d0d3aa9a': ['startseq An elderly Asian woman wearing a blue winter coat and red hat in front of a food counter . endseq',
#   'startseq A woman in a red cap in a store . endseq',
#   'startseq A woman wearing a red hat and black coat . endseq',
#   'startseq A woman with a red hat and face stands in front of jars . endseq',
#   'startseq The hapy asian woman is at the market . endseq'],
#  '2257294002_0073263c54': ['startseq The children of a family play while they wait . endseq',
#   'startseq Three Asian kids dance while a man looks on . endseq',
#   'startseq Three children do jumping jacks in a public place while a man sits and looks on . endseq',
#   'startseq Three children jumping while an older man watches from a row of chairs nearby . endseq',
#   'startseq Three young children jump while an older man watches from his seat . endseq'],
#  '2257631407_1529b9db39': ['startseq A couple of playful kids in sweats and jeans romp on the grass . endseq',
#   "startseq A girl on someone 's back is laughing . endseq",
#   'startseq Kids playing around . endseq',
#   'startseq Someone holding a little girl hanging upside down . endseq',
#   'startseq Two peoplw with top of heads on grass . endseq'],
#  '2257798999_d9d1b9a45a': ['startseq As the brown dog looks the other way , a large black and white dog plays with a smaller black dog . endseq',
#   'startseq Orange , brown and white and brown dogs on grass . endseq',
#   'startseq Three dogs playing and laying on the grass . endseq',
#   'startseq Three dogs playing in a yard together . endseq',
#   'startseq three dogs play together . endseq'],
#  '2258662398_2797d0eca8': ['startseq A child in a black wetsuit is in the waves on a surfboard . endseq',
#   'startseq A kid on a surfboard riding a small wave . endseq',
#   'startseq A small boy in black is surfing . endseq',
#   'startseq A young boy in a black wetsuit surfs in the water . endseq',
#   'startseq A young surfer rides a wave . endseq'],
#  ...}

# %%
train_features
# Out:
# {'1420060020_7a6984e2ea': array([[0.01908815, 0.        , 0.        , ..., 0.        , 0.        ,
#          1.8504643 ]], dtype=float32),
#  '2899089320_3e7f6bbaca': array([[0.3431023, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3238654429_d899e34287': array([[2.381139 , 0.       , 4.9182916, ..., 0.       , 1.7189069,
#          0.       ]], dtype=float32),
#  '1989145280_3b54452188': array([[0.       , 0.       , 0.       , ..., 0.       , 0.4332376,
#          2.0392978]], dtype=float32),
#  '2754271176_4a2cda8c15': array([[2.5865297, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.1697955]], dtype=float32),
#  '3569126684_a68b29a57f': array([[2.7713165, 0.       , 1.6055028, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3362805914_72f60ee8cb': array([[0.72025555, 0.        , 0.8143452 , ..., 0.        , 1.6108351 ,
#          0.        ]], dtype=float32),
#  '236474697_0c73dd5d8b': array([[0.6448471, 0.       , 0.       , ..., 0.       , 0.       ,
#          2.0934272]], dtype=float32),
#  '3607489370_92683861f7': array([[2.2458577, 0.       , 0.       , ..., 0.       , 0.       ,
#          6.583731 ]], dtype=float32),
#  '2537119659_fa01dd5de5': array([[0.21849531, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.08224022]], dtype=float32),
#  '3547000169_40191e02ca': array([[0.      , 0.      , 0.      , ..., 0.      , 1.332069, 0.      ]],
#        dtype=float32),
#  '2490365757_b869282cb3': array([[1.1907485 , 3.2030404 , 0.35539347, ..., 0.        , 0.7854142 ,
#          0.        ]], dtype=float32),
#  '3078844565_16e9cdcea2': array([[0.       , 0.       , 0.       , ..., 0.       , 4.32846  ,
#          3.0596309]], dtype=float32),
#  '2929669711_b2d5a640f0': array([[0.62350255, 0.        , 3.603661  , ..., 0.        , 0.        ,
#          1.2145429 ]], dtype=float32),
#  '3325910784_5ecb88310c': array([[0.       , 2.2825422, 4.727402 , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '443885436_6e927e6c58': array([[2.209805  , 0.85699594, 4.5735273 , ..., 0.        , 2.2379932 ,
#          0.        ]], dtype=float32),
#  '3711030008_3872d0b03f': array([[0.       , 0.       , 0.       , ..., 0.       , 5.3610992,
#          0.7375541]], dtype=float32),
#  '3284955091_59317073f0': array([[0.6145092 , 0.        , 0.65258884, ..., 0.        , 1.5589063 ,
#          2.613616  ]], dtype=float32),
#  '3497106366_d1a256e723': array([[0.        , 0.        , 0.        , ..., 0.        , 0.9068235 ,
#          0.04044634]], dtype=float32),
#  '2885382946_f541ea5722': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '294549892_babb130543': array([[1.3560051, 0.       , 0.       , ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  
..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  '3380407617_07b53cbcce': array([[1.6182079, 0.       , 3.092031 , ..., 1.5001416, 6.570341 ,
#          0.       ]], dtype=float32),
#  '2328104318_5a43ca170c': array([[5.232785 , 4.6448846, 0.9030132, ..., 0.       , 3.4171798,
#          0.8002081]], dtype=float32),
#  '3684680947_f1c460242f': array([[2.4348745, 0.       , 0.       , ..., 0.       , 3.9787574,
#          0.       ]], dtype=float32),
#  '2662890367_382eaf83bd': array([[1.968361 , 2.9675596, 2.4344127, ..., 0.       , 4.774307 ,
#          0.       ]], dtype=float32),
#  '2988244398_5da7012fce': array([[1.5733051, 0.       , 0.       , ..., 0.       , 0.       ,
#          1.6737862]], dtype=float32),
#  '3171035252_dba286ae5c': array([[0.       , 0.       , 3.112503 , ..., 0.       , 0.       ,
#          3.1990483]], dtype=float32),
#  '241346580_b3c035d65c': array([[0.        , 0.        , 0.09073946, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '2920305300_a5b1b2329a': array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.558116]],
#        dtype=float32),
#  '335588286_f67ed8c9f9': array([[0.       , 1.5049216, 2.4199445, ..., 0.       , 1.4704287,
#          0.       ]], dtype=float32),
#  '2053441349_a98b5fc742': array([[3.7056265, 0.       , 0.8792931, ..., 1.8015876, 0.       ,
#          0.       ]], dtype=float32),
#  '2918880895_e61f74f2f0': array([[1.3009167, 0.       , 0.       , ..., 0.       , 2.6673074,
#          0.5749782]], dtype=float32),
#  '2934325103_e9b8d7430f': array([[0.8371769 , 0.        , 0.        , ..., 0.        , 1.6350908 ,
#          0.13369548]], dtype=float32),
#  '239807547_4923efc821': array([[0.        , 0.        , 0.        , ..., 0.        , 0.37416047,
#          0.        ]], dtype=float32),
#  '2978394277_4572967b97': array([[2.1212106, 3.2949455, 2.8546267, ..., 0.       , 0.       ,
#          1.0985926]], dtype=float32),
#  '2546667441_bbe87a6285': array([[0.      , 0.      , 0.      , ..., 0.      , 1.344855, 0.      ]],
#        dtype=float32),
#  '2660480624_45f88b3022': array([[0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#          3.9286652]], dtype=float32),
#  '3422394336_e465f60b7c': array([[1.6047742, 4.137627 , 1.8056924, ..., 0.       , 3.0895934,
#          0.       ]], dtype=float32),
#  '181103691_fb2f956abd': array([[0.        , 0.        , 4.0669003 , ..., 0.        , 0.16171518,
#          1.1158558 ]], dtype=float32),
#  '207237775_fa0a15c6fe': array([[0.6973552, 1.5499747, 1.853269 , ..., 0.       , 3.2041829,
#          1.8391137]], dtype=float32),
#  '3182996527_70d9c323d5': array([[0.4094355 , 0.        , 0.90491396, ..., 0.5826185 , 0.        ,
#          4.543356  ]], dtype=float32),
#  '2612608861_92beaa3d0b': array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32),
#  '2638369467_8fc251595b': array([[1.9425094 , 0.        , 0.15511128, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  '3070130228_67dcfee9ae': array([[0.        , 0.        , 0.67575926, ..., 0.        , 0.        ,
#          6.3548703 ]], dtype=float32),
#  ...}

# %%
from keras.preprocessing.text import Tokenizer

# %%
# convert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# fit a tokenizer for cleaned caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 7378

# %%
# calculate the length of the description with the most words
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# %%
descriptions_from_dict_to_list = to_lines(train_descriptions)

# %%
descriptions_from_dict_to_list
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq A girl going into a wooden building . endseq',
#  'startseq A little girl climbing into a wooden playhouse . endseq',
#  'startseq A little girl climbing the stairs to her playhouse . endseq',
#  'startseq A little girl in a pink dress going into a wooden cabin . endseq',
#  'startseq A black dog and a spotted dog are fighting endseq',
#  'startseq A black dog and a tri-colored dog playing with each other on the road . endseq',
#  'startseq A black dog and a white dog with brown spots are staring at each other in the street . endseq',
#  'startseq Two dogs of different breeds looking at each other on the road . endseq',
#  'startseq Two dogs on pavement moving toward each other . endseq',
#  'startseq A little girl covered in paint sits in front of a painted rainbow with her hands in a bowl . endseq',
#  'startseq A little girl is sitting in front of a large painted rainbow . endseq',
#  'startseq A small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it . endseq',
#  'startseq There is a girl with pigtails sitting in front of a rainbow painting . endseq',
#  'startseq Young girl with pigtails painting outside in the grass . endseq',
#  'startseq A man lays on a bench while his dog sits by him . endseq',
#  'startseq A man lays on the bench to which a white dog is also tied . endseq',
#  'startseq a man sleeping on a bench outside with a white and black dog sitting next to him . endseq',
#  'startseq A shirtless man lies on a park bench with his dog . endseq',
#  'startseq man laying on bench holding leash of dog sitting on ground endseq',
#  'startseq A man in an orange hat starring at something . endseq',
#  'startseq A man wears an orange hat and glasses . endseq',
#  'startseq A man with gauges and glasses is wearing a Blitz hat . endseq',
#  'startseq A man with glasses is wearing a beer can crocheted hat . endseq',
#  'startseq The man with pierced ears is wearing glasses and an orange hat . endseq',
#  'startseq A child playing on a rope net . endseq',
#  'startseq A little girl climbing on red roping . endseq',
#  'startseq A little girl in pink climbs a rope bridge at the park . endseq',
#  'startseq A small child grips onto the red ropes at the playground . endseq',
#  'startseq The small child climbs on a red ropes on a playground . endseq',
#  'startseq A black and white dog is running in a grassy garden surrounded by a white fence . endseq',
#  'startseq A black and white dog is running through the grass . endseq',
#  'startseq A Boston terrier is running in the grass . endseq',
#  'startseq A Boston Terrier is running on lush green grass in front of a white fence . endseq',
#  'startseq A dog runs on the green grass near a wooden fence . endseq',
#  'startseq A dog shakes its head near the shore , a red ball next to it . endseq',
#  'startseq A white dog shakes on the edge of a beach with an orange ball . endseq',
#  'startseq Dog with orange ball at feet , stands on shore shaking off water endseq',
#  'startseq White dog playing with a red ball on the shore near the water . endseq',
#  'startseq White dog with brown ears standing near water with head turned to one side . endseq',
#  'startseq A boy smiles in front of a stony wall in a city . endseq',
#  'startseq A little boy is standing on the street while a man in overalls is working on a stone wall . endseq',
#  'startseq A young boy runs aross the street . endseq',
#  'startseq A young child is walking on a stone paved street with a metal pole and a man behind him . endseq',
#  'startseq Smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him . endseq',
#  'startseq A black dog leaps over a log . endseq',
#  'startseq A grey dog is leaping over a fallen tree . endseq',
#  'startseq A large black dog leaps a fallen log . endseq',
#  'startseq A mottled black and grey dog in a blue collar jumping over a fallen tree . endseq',
#  'startseq The black dog jumped the tree stump . endseq',
#  'startseq A brown and white dog is running through the snow . endseq',
#  'startseq A dog is running in the snow endseq',
#  'startseq A dog running through snow . endseq',
#  'startseq a white and brown dog is running through a snow covered field . endseq',
#  'startseq The white and brown dog is running over the surface of the snow . endseq',
#  'startseq A man in a hat is displaying pictures next to a skier in a blue hat . endseq',
#  'startseq A man skis past another man displaying paintings in the snow . endseq',
#  'startseq A person wearing skis looking at framed pictures set up in the snow . endseq',
#  'startseq A skier looks at framed pictures in the snow next to trees . endseq',
#  'startseq Man on skis looking at artwork for sale in the snow endseq',
#  'startseq A collage of one person climbing a cliff . endseq',
#  'startseq A group of people are rock climbing on a rock climbing wall . endseq',
#  'startseq A group of people climbing a rock while one man belays endseq',
#  'startseq Seven climbers are ascending a rock face whilst another man stands holding the rope . endseq',
#  'startseq Several climbers in a row are climbing the rock while the man in red watches and holds the line . endseq',
#  'startseq A brown dog chases the water from a sprinkler on a lawn . endseq',
#  'startseq a brown dog plays with the hose . endseq',
#  'startseq A brown dog running on a lawn near a garden hose endseq',
#  'startseq A dog is playing with a hose . endseq',
#  'startseq Large brown dog running away from the sprinkler in the grass . endseq',
#  'startseq A dog prepares to catch a thrown object in a field with nearby cars . endseq',
#  'startseq A white dog is about to catch a yellow ball in its mouth . endseq',
#  'startseq A white dog is about to catch a yellow dog toy . endseq',
#  'startseq A white dog is ready to catch a yellow ball flying through the air . endseq',
#  'startseq A white dog running after a yellow ball endseq',
#  'startseq a black and white dog jumping in the air to get a toy . endseq',
#  'startseq A black and white dog jumps up towards a yellow toy . endseq',
#  'startseq A dog leaps to catch a ball in a field . endseq',
#  'startseq A white dog is trying to catch a ball in midair over a grassy field . endseq',
#  'startseq The white dog is playing in a green field with a yellow toy . endseq',
#  'startseq A couple and an infant , being held by the male , sitting next to a pond with a near by stroller . endseq',
#  'startseq A couple sit on the grass with a baby and stroller . endseq',
#  'startseq A couple with their newborn baby sitting under a tree facing a lake . endseq',
#  'startseq A man and woman care for an infant along the side of a body of water . endseq',
#  'startseq Couple with a baby sit outdoors next to their stroller . endseq',
#  'startseq A black dog running in the surf . endseq',
#  'startseq A black lab with tags frolicks in the water . endseq',
#  'startseq A dog splashes in the water endseq',
#  'startseq The black dog runs through the water . endseq',
#  'startseq This is a black dog splashing in the water . endseq',
#  'startseq A man drilling a hole in the ice . endseq',
#  'startseq A man is drilling through the frozen ice of a pond . endseq',
#  'startseq A person in the snow drilling a hole in the ice . endseq',
#  'startseq A person standing on a frozen lake . endseq',
#  'startseq Two men are ice fishing . endseq',
#  'startseq Two different breeds of brown and white dogs play on the beach . endseq',
#  'startseq Two dogs are making a turn on a soft sand beach . endseq',
#  'startseq Two dogs playing in the sand at the beach . endseq',
#  'startseq Two dogs playing together on a beach . endseq',
#  'startseq Two large tan dogs play along a sandy beach . endseq',
#  'startseq A man uses ice picks and crampons to scale ice . endseq',
#  'startseq an ice climber in a blue jacket and black pants is scaling a frozen ice wall . endseq',
#  'startseq An ice climber scaling a frozen waterfall . endseq',
#  'startseq A person in blue and red ice climbing with two picks . endseq',
#  'startseq Climber climbing an ice wall endseq',
#  'startseq A black dog carries a green toy in his mouth as he walks through the grass . endseq',
#  'startseq A black dog carrying something through the grass . endseq',
#  'startseq A black dog has a blue toy in its mouth . endseq',
#  'startseq A dog in grass with a blue item in his mouth . endseq',
#  'startseq A wet black dog is carrying a green toy through the grass . endseq',
#  'startseq A man and a baby are in a yellow kayak on water . endseq',
#  'startseq A man and a little boy in blue life jackets are rowing a yellow canoe . endseq',
#  'startseq A man and child kayak through gentle waters . endseq',
#  'startseq A man and young boy ride in a yellow kayak . endseq',
#  'startseq Man and child in yellow kayak endseq',
#  'startseq A black dog and a brown dog are jumping up to catch a red toy . endseq',
#  'startseq A black dog and a brown dog play with a red toy on a courtyard . endseq',
#  'startseq A brown and black lab are outside and the black lab is catching a toy in its mouth . endseq',
#  'startseq Black dog snaps at red and black object as brown dog lunges . endseq',
#  'startseq The Chocolate Lab jumps too late to get the toy as the Black Lab captures it in the driveway . endseq',
#  'startseq A man in black is sitting next to a modern art structure in front of a glass building . endseq',
#  'startseq A man sits and reads a newspaper by a sculpture outside of an office building . endseq',
#  'startseq a man sits near a large statue . endseq',
#  'startseq A man sitting in front of a metal sculpture in front of a building . endseq',
#  'startseq The man with the backpack is sitting in a buildings courtyard in front of an art sculpture reading . endseq',
#  'startseq A tent is being set up on the ice . endseq',
#  'startseq Two men are about to enter an ice fishing tent on a snow covered lake . endseq',
#  'startseq two men setting up a blue ice fishing hut on an iced over lake endseq',
#  'startseq Two men , standing on an ice , looking into something covered with a blue tarp . endseq',
#  'startseq Two people standing outside a blue tent structure on a snowy surface . endseq',
#  'startseq a man is standing in front of a skyscraper endseq',
#  'startseq A man stands in front of a skyscraper . endseq',
#  'startseq A man stands in front of a very tall building . endseq',
#  'startseq Behind the man in a red shirt stands a large skyscraper . endseq',
#  'startseq There is a skyscraper in the distance with a man walking in front of the camera . endseq',
#  'startseq People sit on the mountainside and check out the view . endseq',
#  'startseq Three people are on a hilltop overlooking a green valley . endseq',
#  'startseq Three people hang out on top of a big hill . endseq',
#  'startseq Three people overlook a green valley . endseq',
#  'startseq Three people rest on a ledge above the moutains . endseq',
#  'startseq A boy in a green shirt is looking down at many inflatable boats . endseq',
#  'startseq A boy in a green shirt watches kayakers . endseq',
#  'startseq A boy looks over a railing at the many boats and rafts below in the water . endseq',
#  'startseq A young boy overlooking a crowd of inflatable boats . endseq',
#  'startseq A young boy wearing a jersey looks down over a ledge at many boats in the water . endseq',
#  'startseq A man and woman pose for the camera while another man looks on . endseq',
#  'startseq A man is holding the hand of a woman up to his mouth in front of some buildings while another man looks on . endseq',
#  'startseq A multiracial couple posing for a picture endseq',
#  'startseq Asian man and blond woman holding hands outdoors , man in background watches . endseq',
#  'startseq Guy in blue shirt biting hand of girl in black striped jacket while another guy watches endseq',
#  'startseq a couple of several people sitting on a ledge overlooking the beach endseq',
#  'startseq A group of people sit on a wall at the beach . endseq',
#  'startseq A group of teens sit on a wall by a beach . endseq',
#  'startseq Crowd of people at the beach . endseq',
#  'startseq Several young people sitting on a rail above a crowded beach . endseq',
#  'startseq A boy takes a jump on his skateboard while another boy with a skateboard watches . endseq',
#  'startseq A child is performing a skateboard trick while another child with a skateboard leans on a wall . endseq',
#  'startseq A little boy skateboarder is doing a trick on his board while another young skateboarder watches . endseq',
#  'startseq a young boy skateboarder jumping on a platform on a skateboard . endseq',
#  'startseq Two skateboarders . endseq',
#  'startseq A girl paddling down a large river , as seen from behind her . endseq',
#  'startseq A woman kayaking down a river . endseq',
#  'startseq A woman paddles a boat down a river . endseq',
#  'startseq A woman with a paddle . endseq',
#  'startseq A woman with a paddle sits in a boat on the water . endseq',
#  'startseq A girl in pigtails splashes in the shallow water . endseq',
#  'startseq A girls plays in the surf . endseq',
#  'startseq a girl with pigtails is playing in the ocean by the beach . endseq',
#  'startseq A girl with pigtails plays in the water . endseq',
#  'startseq A young girl in pigtails plays in the water . endseq',
#  'startseq A group of four children wearing pajamas have a pillow fight . endseq',
#  'startseq A group of kids have a pillow-fight . endseq',
#  'startseq A group of young children playing pillow fight on a bed . endseq',
#  'startseq Children having a pillow fight . endseq',
#  'startseq Four children are having a pillow fight . endseq',
#  'startseq Two constructions workers sit on a beam taking a break . endseq',
#  'startseq Two construction workers are sitting up on the side of a building . endseq',
#  'startseq Two construction workers sitting on an I-beam . endseq',
#  'startseq Two construction workers take a seat on a steel beam . endseq',
#  'startseq Two men take a break from construction . endseq',
#  'startseq A little girl looking at a brochure on train rides endseq',
#  'startseq a young blond girl with a magizine in her hands endseq',
#  'startseq A young girl on a train reads a book about train rides . endseq',
#  'startseq A young girl sits on a seat and looks at a train pamphlet . endseq',
#  'startseq Child sitting down looking at train ride brochure endseq',
#  'startseq A brown dog is running after a black dog on a rocky shore . endseq',
#  'startseq A brown dog is running after the black dog . endseq',
#  'startseq Two dogs playing on a beach . endseq',
#  'startseq Two dogs run across stones near a body of water . endseq',
#  'startseq Two dogs run towards each other on a rocky area with water in the background . endseq',
#  'startseq A boy descends off the end of a high diving board . endseq',
#  'startseq A child jumps off a high diving board into the pool . endseq',
#  'startseq A kid jumps off the diving board and into the swimming pool below . endseq',
#  'startseq A little kid is jumping off a high dive at the pool . endseq',
#  'startseq The boy is jumping off a high diving board into the pool . endseq',
#  'startseq A guy stands by a window taking his overshirt off . endseq',
#  'startseq A man in a tank top stands next to a chrome door . endseq',
#  'startseq A man puts his shirt on near an elevator . endseq',
#  'startseq A man stands by an elevator with his head down . endseq',
#  'startseq The man is putting on his shirt near an elevator . endseq',
#  'startseq A light-colored dog runs on the beach . endseq',
#  'startseq A small yellow dog runs on a beach endseq',
#  'startseq A tan dog runs on a sandy beach . endseq',
#  'startseq A white dog is running down a rocky beach . endseq',
#  'startseq Light brown dog running along the beach . endseq',
#  'startseq A hiker standing high on a bluff overlooking the mountains below . endseq',
#  "startseq a person on ski 's looks from hill over snow covered landscape endseq",
#  'startseq A skier is overlooking a snow-covered mountain . endseq',
#  'startseq A skier is overlooking the beautiful white snow covered landscape . endseq',
#  'startseq A skier pauses on a mountaintop . endseq',
#  'startseq A black and white dog is attempting to catch a yellow and purple object in a low cut yard . endseq',
#  'startseq A black and white dog jumps after a yellow toy . endseq',
#  'startseq a black and white dog jumps to get the Frisbee . endseq',
#  'startseq A black dog is jumping up to catch a purple and green toy . endseq',
#  'startseq A dog jumps to catch a toy . endseq',
#  'startseq A man in blue shorts is laying in the street . endseq',
#  'startseq A man in blue shorts lays down outside in a parking lot . endseq',
#  'startseq A man laying down in middle of street during heavy traffic . endseq',
#  'startseq A man lies on a mat in a parking lot between a brown SUV and a yellow pickup with an open door . endseq',
#  'startseq A shirtless man is laying down in the middle of a busy street . endseq',
#  'startseq A white and black dog and a brown dog in sandy terrain . endseq',
#  'startseq A woolly dog chases a Doberman on a beach . endseq',
#  'startseq One dog is chasing another one on the beach . endseq',
#  'startseq The two large dogs are running through sand . endseq',
#  'startseq Two large dogs chasing each other at the beach . endseq',
#  'startseq A black and white dog catches a toy in midair . endseq',
#  'startseq A dog and a tennis ball . endseq',
#  'startseq A dog is jumping to catch a object thrown at it , endseq',
#  'startseq A dog leaps while chasing a tennis ball through a grassy field . endseq',
#  'startseq A multicolor dog jumping to catch a tennis ball in a grassy field . endseq',
#  'startseq A crowd watching air balloons at night . endseq',
#  'startseq A group of hot air balloons lit up at night . endseq',
#  'startseq People are watching hot air balloons in the park . endseq',
#  'startseq People watching hot air balloons . endseq',
#  'startseq Seven large balloons are lined up at nighttime near a crowd . endseq',
#  'startseq A child with a helmet on his head rides a bike . endseq',
#  'startseq A little boy rides a bike down a hill on a miniature dirt bike . endseq',
#  'startseq A young boy in a helmet rides a bike on the road . endseq',
#  'startseq The little boy rides his bicycle in a race . endseq',
#  'startseq The young boy pedals quickly at a BMX race . endseq',
#  'startseq A man in a brown shirt and dark shorts plays on the beach with his two black dogs . endseq',
#  'startseq A man in shorts with two black dogs holds a ball throwing toy at the beach . endseq',
#  'startseq a man playing with two black dogs on the beach endseq',
#  'startseq A man with two dogs on a beach endseq',
#  'startseq Man at the beach with two dogs . endseq',
#  'startseq a boy cleans the bubbles off his face . endseq',
#  'startseq A boy covered in suds has his face wiped clean . endseq',
#  'startseq A boy is covered in bubbles . endseq',
#  'startseq A child covered in foam is climbing on a black inflatable ramp . endseq',
#  'startseq A person covered in soapy water is getting cleaned off . endseq',
#  'startseq A little boy sticks his tongue out for the camera . Another boy looks on . endseq',
#  'startseq Two boys make faces . endseq',
#  'startseq Two young boys are looking at the camera , one smiling , the other sticking his tongue out . endseq',
#  'startseq Two young boys look up at the camera as one sticks out his tongue . endseq',
#  'startseq two young boys making silly faces . endseq',
#  'startseq A blonde horse and a blonde girl in a black sweatshirt are staring at a fire in a barrel . endseq',
#  'startseq A girl and her horse stand by a fire . endseq',
#  "startseq A girl holding a horse 's lead behind a fire . endseq",
#  'startseq A man , and girl and two horses are near a contained fire . endseq',
#  'startseq Two people and two horses watching a fire . endseq',
#  'startseq A bulldog , a sheep dog , and a boxer standing in a yard . endseq',
#  'startseq A large brown dog is pushing a small Boston terrier with his face while anouther dog watches . endseq',
#  'startseq A large skinny dog stands near two smaller dogs int the dirt . endseq',
#  'startseq There are three dogs starring at a ball in the middle of them . endseq',
#  'startseq Three dogs of various sizes . endseq',
#  'startseq a woman in a yellow shirt and green shorts is climbing an artificial red wall whilst wearing a safety harness . endseq',
#  'startseq A woman in blue shorts and a white shirt is indoor rock climbing . endseq',
#  'startseq The girl is climbing a rock wall . endseq',
#  'startseq The girl is in a harness , climbing rocks . endseq',
#  'startseq Woman climbing an artificial rock wall . endseq',
#  'startseq A boy is jumping on an inflatable ring and a girl is watching him endseq',
#  'startseq A boy jumping on a water jumphouse endseq',
#  'startseq A teenage boy is jumping on an inflatable slide . endseq',
#  'startseq A young boy jumping and a young girl seating in an inflatable pool . endseq',
#  'startseq Two young kids are playing in the water on an inflated toy . endseq',
#  'startseq Skiiers walking up the hill through a forest . endseq',
#  'startseq Two men are skiing in the snow in a wooded area . endseq',
#  'startseq Two people wearing yellow jackets cross-country skiing . endseq',
#  'startseq Two skiers are making their way through woodland . endseq',
#  'startseq Two skiers are sliding down a trail in the woods . endseq',
#  'startseq A lone skier is making their way up a mountain . endseq',
#  'startseq Skiiers at the top of a snow covered hill . endseq',
#  'startseq Two hikers climbing a snowy hill . endseq',
#  'startseq Two people are on a snow-covered mountain . endseq',
#  'startseq Two people climbing up a snowy mountain . endseq',
#  'startseq a brown dog running down a paved pathway endseq',
#  'startseq A brown dog running next to grass . endseq',
#  'startseq A dog is running down a road . endseq',
#  'startseq A light brown dog runs down a path happily . endseq',
#  'startseq Energetic brown dog running endseq',
#  'startseq A woman dressed in a blue jacket and blue jeans rides a brown horse near a frozen lake and snow-covered mountain . endseq',
#  'startseq A woman in a blue jacket rides a brown pony near water . endseq',
#  'startseq A woman rides a horse near a frozen lake in the wintertime . endseq',
#  'startseq A young blond woman sitting atop a brown draft horse in the snowy mountains . endseq',
#  'startseq Woman n blue jacket sits on daft horse near a frozen lake . endseq',
#  'startseq Two draft horses pull a cart through the snow . endseq',
#  'startseq Two golden brown horses pull a sleigh driven by a woman in a blue coat . endseq',
#  'startseq Two horses are pulling a woman in a cart . endseq',
#  'startseq Two horses pull a carriage driven by a woman over snow covered ground . endseq',
#  'startseq Two horses pulling a sled steered by a smiling blond woman . endseq',
#  'startseq A person climbing down a sheer rock cliff using a rope endseq',
#  'startseq A person climbs a tall , flat mountain while holding onto a safety rope . endseq',
#  'startseq A person is climbing a rock while holding onto a white rope . endseq',
#  'startseq A person rappels down a steep incline . endseq',
#  'startseq A person wearing a red vest climbs up a steep rock . endseq',
#  'startseq People stand inside a rock dome . endseq',
#  'startseq Shaft of light in a cave shows three spelunkers endseq',
#  'startseq Spelunkers pose inside a rock cavern while bathed in sunlight from the surface . endseq',
#  'startseq three people sit in a cave . endseq',
#  'startseq Three rock climbers are posing on big rocks . endseq',
#  'startseq a group of backpackers lay on the dry ground . endseq',
#  'startseq A group of hikers are resting on the ground in front of some mountains . endseq',
#  'startseq People camp with the mountains in the background . endseq',
#  'startseq Several hikers rest with their gear in front of a mountain . endseq',
#  'startseq The group of hikers is resting in front of a mountain . endseq',
#  'startseq A woman in a blue dress stands with a chalk portrait of two children playing by a stream . endseq',
#  'startseq A woman standing in front of a chalk drawing endseq',
#  'startseq A woman stands next to a chalk drawing in front of a barn-like structure . endseq',
#  'startseq A woman stands outside near an elaborate chalk illustration . endseq',
#  'startseq A woman wearing a blue dress is drawing a picture of a boy and a girl on the sidewalk with sidewalk chalk . endseq',
#  'startseq A brown dog plays in a deep pile of snow . endseq',
#  'startseq A dog looking at the camera in snow . endseq',
#  'startseq a dog runs through the snow . endseq',
#  'startseq A tan dog stand in the snow and looks up . endseq',
#  'startseq The brown dog is out in the snow . endseq',
#  'startseq A boy jumping in a fountain . endseq',
#  'startseq a boy plays in the fountains . endseq',
#  'startseq A child plays in a fountain . endseq',
#  'startseq A little boy playing in the water . endseq',
#  'startseq A young boy is jumping through water being sprayed up from the ground . endseq',
#  'startseq A Corgi runs out of a tunnel . endseq',
#  'startseq A dog runs out of a tunnel on a course . endseq',
#  'startseq Dog running out of tunnel on obstacle course endseq',
#  'startseq The dog is running out of the tunnel on a dog obedience course . endseq',
#  'startseq The small brown and white dog is running out of a small tunnel . endseq',
#  'startseq A blond dog and a black and white dog run in a dirt field . endseq',
#  'startseq a dog chases another dog . endseq',
#  'startseq A yellow dog and a black and white dog are running in the dirt . endseq',
#  'startseq Two dogs are running in a field . endseq',
#  'startseq two dogs running around endseq',
#  'startseq A little girl in a blue swimsuit is walking along a wooden fence next to a sandy beach . endseq',
#  'startseq A little girl with arms outstretched is posing at the beach . endseq',
#  'startseq A young girl walks on a railing in front of the beach . endseq',
#  'startseq Little girl in blue swimsuit standing on a handrail near a beach . endseq',
#  'startseq The little girl in the blue bathing suit is posing at the beach . endseq',
#  'startseq A black and white dog drinking water from a water spray . endseq',
#  'startseq A black and white dog is being soaked with a jet of water in a blue paddling pool . endseq',
#  'startseq A dog sticking its face into the shower from a garden hose . endseq',
#  'startseq A small white dog gets sprayed by water endseq',
#  'startseq A white and black dog is jumping into a pool . endseq',
#  'startseq a boy smiles underwater . endseq',
#  'startseq A red-headed boy swimming underwater . endseq',
#  'startseq A small boy swimming underwater endseq',
#  'startseq A smiling boy swims underwater in a pool . endseq',
#  'startseq The boys smiles underwater at the pool . endseq',
#  'startseq A boy in yellow shorts is standing on top of a cliff . endseq',
#  'startseq A boy wearing blue and yellow walking on a cliff edge . endseq',
#  'startseq A little boy standing high in the air on a rock . endseq',
#  'startseq A young child is standing alone on some jagged rocks . endseq',
#  'startseq Child stands near edge of cliff . endseq',
#  'startseq A person on a snowmobile in mid jump . endseq',
#  'startseq A snowmobiler flies through the air . endseq',
#  'startseq A snowmobile rider flies through the air on his or her machine in front of tall pine trees . endseq',
#  'startseq Rider jumps snowmobile high in rural area . endseq',
#  'startseq The man is up in the air . endseq',
#  'startseq People are riding around on snowmobiles . endseq',
#  'startseq People pose with helmets and goggles on while riding snowmobiles . endseq',
#  'startseq Several people are taking a break while on a snowmobiling ride . endseq',
#  'startseq Three people and two snowmobiles . endseq',
#  'startseq Two helmeted men sit on yellow snowmobiles while another man stands behind watching . endseq',
#  'startseq Three people drive ATVs . endseq',
#  'startseq Three people on ATVs in a brown field turn their heads to look at the camera . endseq',
#  "startseq Three people on ATV 's outside . endseq",
#  "startseq three people on four wheel ATV 's in a field . endseq",
#  'startseq Three people ride their four wheelers through the field . endseq',
#  'startseq A four wheeler jumping in an empty field . endseq',
#  'startseq A man on a four wheeler is flying through the air . endseq',
#  'startseq A person is riding an orange ATV in a large empty field . endseq',
#  'startseq Man jumping with all terrain vehicle endseq',
#  'startseq Man on an ATV catching air ! endseq',
#  'startseq A man jumps gin the air while riding an ATV endseq',
#  'startseq A man on a four-wheeler jumps near a small building . endseq',
#  'startseq An ATV is airborne over a field in front of a white structure . endseq',
#  'startseq A person dressed in a tan jacket jumps a quad over a harvested cornfield in front of a small out building . endseq',
#  'startseq Man on four wheeler in the air . endseq',
#  'startseq A boy carrying a soccer ball . endseq',
#  'startseq A boy walks with a ball tucked under his arm . endseq',
#  'startseq A boy walks with a soccer ball near a fence . endseq',
#  'startseq A boy wearing a white t-shirt walks on the grass and carries a soccer ball . endseq',
#  'startseq Small boy carries a soccer ball on a field . endseq',
#  'startseq A child painting a picture . endseq',
#  'startseq An artist paints clouds onto a canvas . endseq',
#  'startseq A young girl painting a picture . endseq',
#  'startseq A young girl with braids is painting with water colors on a white paper on the wall . endseq',
#  'startseq The child paints on a large paper with water colors . endseq',
#  'startseq A cyclist is riding a bicycle on a curved road up a hill . endseq',
#  'startseq A man in aerodynamic gear riding a bicycle down a road around a sharp curve . endseq',
#  'startseq A man on a mountain bike is pedaling up a hill . endseq',
#  'startseq Man bicycle up a road , while cows graze on a hill nearby . endseq',
#  'startseq The biker is riding around a curve in the road . endseq',
#  'startseq A little girl is holding a cine camera in front of her face . endseq',
#  'startseq A young girl is looking through an old fashioned video camera . endseq',
#  'startseq A young girl steadies her aim with a camera endseq',
#  'startseq Girl with rosy cheeks and lips holding black toy gun . endseq',
#  'startseq There is a kid with a gun . endseq',
#  'startseq A black and white Border Collie catches a Frisbee in front of an audience . endseq',
#  'startseq a brown and white dog catches a Frisbee in it mouth in front of a group of people . endseq',
#  'startseq A brown and white dug jumping up to catch a Frisbee while an audience watches . endseq',
#  'startseq A dog jumps to catch a Frisbee , while many people watch . endseq',
#  'startseq An agile dog catches a Frisbee while a crowd of onlookers watches closely . endseq',
#  'startseq A baby is sitting on and playing with smooth rocks . endseq',
#  'startseq A baby is stacking rocks on the beach . endseq',
#  'startseq A small boy is playing with rocks endseq',
#  'startseq A toddler sitting on a pile of rocks holding a rock at a beach . endseq',
#  'startseq Toddler sits on a pile of rocks . endseq',
#  'startseq A man climbing a rock wall endseq',
#  'startseq A man climbing the side of a cliff . endseq',
#  'startseq A man is rock climbing . endseq',
#  'startseq Man with red shoes , white shirt and grey pants climbing . endseq',
#  'startseq The young man with the white t-shirt and jeans is rappeling up the rock wall . endseq',
#  'startseq A climber wearing a blue helmet and headlamp is attached to a rope on the rock face . endseq',
#  'startseq A man climbs a rocky wall . endseq',
#  'startseq a rock climber climbs a large rock . endseq',
#  'startseq A woman in purple snakeskin pants climbs a rock . endseq',
#  'startseq Person with blue helmet and purple pants is rock climbing . endseq',
#  'startseq A child playing with a fountain at the beach . endseq',
#  'startseq A child plays with a fountain . endseq',
#  'startseq A girl looks at a fountain that sprays water . endseq',
#  'startseq A little girl playing in water on a frog sculpture . endseq',
#  'startseq The little girl is playing with a toy in a public fountain . endseq',
#  'startseq A black dog is jumping over a log along a beach . endseq',
#  'startseq A black dog runs along the beach and jumps over a wood barrior . endseq',
#  'startseq A dog is running on the beach . endseq',
#  'startseq a dog jumping over a small wall at a beach near the water . endseq',
#  'startseq An animal is running on the beach . endseq',
#  "startseq A black and white bird eating seeds out of someone 's hand endseq",
#  'startseq A black and white bird standing on a hand . endseq',
#  "startseq A small bird sits in a person 's hand and eats seeds . endseq",
#  'startseq Black and white bird standing on hand of someone holding sunflower seeds endseq',
#  'startseq The small bird is clinging to a finger of the hand holding the seeds . endseq',
#  'startseq A brown dog is running in the sand . endseq',
#  'startseq A brown dog playing in the sand . endseq',
#  'startseq A brown dog plays at the beach . endseq',
#  'startseq A dog is standing in the sand . endseq',
#  'startseq A dog running fast in the sand . endseq',
#  'startseq A little boy stands in the surf . endseq',
#  'startseq A small child wades through the water while being guided by another person . endseq',
#  'startseq A young boy laughs while splashing in the ocean . endseq',
#  'startseq a young boy wearing a colorful bathing suit splashing in the ocean endseq',
#  'startseq A young child splashing in water . endseq',
#  'startseq A black and white dog is running through the field . endseq',
#  'startseq A black , brown and white dog running through a field . endseq',
#  'startseq A brown , black and white dog is running through a large field with its mouth open . endseq',
#  'startseq A dog running in a field . endseq',
#  'startseq A dog with its mouth open running through a field torwards the camera . endseq',
#  'startseq A girl in a pink swimsuit in a pool endseq',
#  'startseq A girl swimming in a pool . endseq',
#  'startseq A little girl in a pink bathing suit swimming in a pool . endseq',
#  'startseq A little girl swimming in a pool . endseq',
#  'startseq Smiling little girl swimming in outdoor pool . endseq',
#  'startseq A child is standing on her head . endseq',
#  'startseq A little girl standing on her head . endseq',
#  'startseq A small child doing a handstand on a bed . endseq',
#  'startseq A young girl does a handstand on a bed with blue sheets . endseq',
#  'startseq The girl is upside down on a bed endseq',
#  'startseq A guy stands in the sand with a snowboard behind him . endseq',
#  'startseq A man holds a surfboard on the beach . endseq',
#  'startseq a man holds his snowboard in the sand . endseq',
#  'startseq A man with his surfboard stands in the sand . endseq',
#  'startseq Man is standing on white sand and holding a snowboard . endseq',
#  'startseq People on ATVs and dirt bikes are traveling along a worn path in a field surrounded by trees . endseq',
#  "startseq Three people are riding around on ATV 's and motorcycles . endseq",
#  'startseq Three people on motorbikes follow a trail through dry grass . endseq',
#  'startseq Three people on two dirt-bikes and one four-wheeler are riding through brown grass . endseq',
#  'startseq Three people ride off-road bikes through a field surrounded by trees . endseq',
#  'startseq A half naked man is sleeping on his chair outdoors . endseq',
#  'startseq An older man sits back and relaxes on a patio outside an adobe building where many bicycles are propped . endseq',
#  'startseq A shirtless man in a white cap relaxes in a deck chair , close to three parked bicycles . endseq',
#  'startseq Man relaxing in a folding chair on the street . endseq',
#  'startseq Topless old man wearing slippers , navy blue pants and a white hat while reclining in a chair outside . endseq',
#  'startseq A brown and white and a black and white dog hauling in a floating toy from the ocean . endseq',
#  'startseq Both dogs retrieve the play toy from the water . endseq',
#  'startseq Two dogs in the ocean playing with a toy endseq',
#  'startseq Two dogs run through the water with a rope in their mouths . endseq',
#  'startseq Two dogs tug at a chew toy in the surf . endseq',
#  'startseq There are three young people , one dark haired holding a bottled drink , one with head tilted back and finger in her mouth , and one with spiked hair . endseq',
#  'startseq The young people party in the streets . endseq',
#  'startseq Three girls make faces as one takes a drink while they stand in a busy street . endseq',
#  'startseq Three women on the street drinking and posing endseq',
#  'startseq Three young women pose for the camera at a parade . endseq',
#  'startseq Two brown dogs are creating large splashes as they run in a river . endseq',
#  'startseq Two brown dogs in the water . endseq',
#  'startseq Two brown dogs running through water . endseq',
#  'startseq Two brown dogs runs through the water . endseq',
#  'startseq Two dogs splash through the water . endseq',
#  'startseq A young boy runs while wearing sandals . endseq',
#  'startseq Little boy in a striped shirt and brown shorts is running . endseq',
#  'startseq The little boy , in a short sleeved shirt and shorts , is running outside . endseq',
#  'startseq The little boy is wearing a black pinstripe shirt and walking on a deck . endseq',
#  'startseq Young boy running outside on the pavement . endseq',
#  'startseq Two men are sitting on the ground and going through their backpacks . endseq',
#  'startseq Two men sitting in front of a railing are looking at something . endseq',
#  'startseq Two men with backpacks placed in front of them sitting in front of a railing . endseq',
#  'startseq Two men with backpacks are sitting on cardboard along a railing . endseq',
#  'startseq Two older men with backpacks sit at a bus station . endseq',
#  'startseq A child leaping from bed to bed behind the back of a man . endseq',
#  'startseq A man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room . endseq',
#  'startseq a man wearing a yellow shirt standing in the middle of two beds that a boy is jumping on in the background endseq',
#  'startseq A young child jumping on the bed as a man looks the other way . endseq',
#  'startseq Man standing in the bedroom with little boy jumping into bed . endseq',
#  'startseq A bridge through high green plants , a man and a woman on it . endseq',
#  'startseq A man and a woman are crossing over a rope bridge with greenery all over them . endseq',
#  'startseq A man and a woman are walking across a rope bridge . endseq',
#  'startseq A man and a woman crossing a suspension bridge in a tropical setting . endseq',
#  'startseq Woman and man walking across wooden rope bridge with a caution sign beside it . endseq',
#  'startseq A family gathered at a painted van endseq',
#  'startseq A girl climbing down from the side of a bright blue truck while others watch . endseq',
#  'startseq A man is helping a girl step down from a colorful truck whilst a woman and three children watch . endseq',
#  'startseq A very colorful bus is pulled off to the side of the road as its passengers load . endseq',
#  'startseq Two women and four children standing next to a brightly painted truck . endseq',
#  'startseq A blond woman poses with a person in a pink costume . endseq',
#  'startseq A smiling woman holds a person dressed in a pig costume . endseq',
#  "startseq A young woman hugs a young man who 's wearing a pink costume . endseq",
#  'startseq Blond embracing young man in pink costume , at event endseq',
#  'startseq Two people are hugging and one is wearing a pink-hooded stretch top . endseq',
#  'startseq A bicyclist riding on a city street . endseq',
#  'startseq A woman in a blue helmet and brown shorts rides her bike on a busy street . endseq',
#  'startseq A woman is riding a blue bike . endseq',
#  'startseq A woman is riding her bicycle in traffic endseq',
#  'startseq A woman wearing a blue helmet rides her bicycle in a parking lot . endseq',
#  'startseq A bicycle rider is crossing a street . endseq',
#  'startseq A bicyclist getting ready to cross a street . endseq',
#  'startseq A biker in spandex riding on a busy street . endseq',
#  'startseq A man in blue and white biking gear rides down a busy street . endseq',
#  'startseq a man wearing a helmet riding his bicycle down the street . endseq',
#  'startseq A lady wearing a helmet holding a bike . endseq',
#  'startseq A woman in a blue vest and a sky blue helmet stands with her bicycle in traffic . endseq',
#  'startseq A woman in a helmet rides her bike behind a car . endseq',
#  'startseq A woman with a helmet and a backpack walks next to her bike . endseq',
#  'startseq Women with bike and helmet wait for traffic . endseq',
#  'startseq A man in shorts is jogging along a street with a headset . endseq',
#  'startseq A person in blue shorts and wearing a Walkman jogs . endseq',
#  'startseq A woman in a white shirt and blue shorts is wearing headphones . endseq',
#  'startseq A woman walks on a street wearing headphones . endseq',
#  'startseq A woman wearing a white hat and shirt is jogging down a street with a plant store on the corner . endseq',
#  'startseq Bicyclists are standing at an intersection . endseq',
#  'startseq Bicyclists waiting at an intersection . endseq',
#  'startseq People on bicycles waiting at an intersection . endseq',
#  'startseq People waiting at a light on bikes . endseq',
#  'startseq three bikers stop in town . endseq',
#  'startseq A man without a shirt on is guiding a large brown horse pulling a green and yellow wagon . endseq',
#  'startseq A shirtless man escorts a horse pulling a carriage along a paved road . endseq',
#  'startseq A shirtless man leading a horse that is pulling a carriage . endseq',
#  'startseq Shirtless man leading a small horse-drawn covered wagon down a road endseq',
#  'startseq The shirtless man is walking the Shetland pony and carriage down the street . endseq',
#  'startseq A boy hits a ball off of a tee ball into to net . endseq',
#  'startseq A child practices hitting a baseball into a net , while two adult men watch . endseq',
#  'startseq A man holds a net while a boys bats a ball into it . endseq',
#  'startseq The man is holding the net for the boy playing baseball . endseq',
#  'startseq Three people put up a batting cage . endseq',
#  'startseq A small girl spins in the waves in the bright sun . endseq',
#  'startseq A young girl plays in shallow water . endseq',
#  "startseq A young girl wears a shirt and shorts as she plays in the ocean 's surf . endseq",
#  'startseq Girl running through the water near the shore . endseq',
#  'startseq The little girl splashes through the water . endseq',
#  'startseq A girl playing trumpet in a marching band . endseq',
#  'startseq A teenager plays her trumpet on the field at a game . endseq',
#  'startseq a young girl wearing a blue shirt marching in a band playing a trumpet endseq',
#  'startseq Girl playing the trumpet in a marching band endseq',
#  'startseq Girl wearing blue shirt and black shorts plays trumped outside . endseq',
#  'startseq A child jumping into a lake in a wooded area while another child plays on the shore . endseq',
#  'startseq A child jumps into the water with his sneakers on . endseq',
#  'startseq A kid jumping into a pool of water . endseq',
#  'startseq Little boy in sneakers jumping into water . endseq',
#  'startseq The man takes a leap into the water with his shoes on . endseq',
#  'startseq A elderly man in a straw hat is sitting on a bench . endseq',
#  'startseq a elderly man sits alone on a park bench . endseq',
#  'startseq An old man in a straw hat sits on a park bench . endseq',
#  'startseq The old man in the brown hat is sitting on the bench . endseq',
#  'startseq White haired man in gray sweater and a straw hat sitting on a bench under a tree . endseq',
#  'startseq Three girls are walking across a bridge covered with wood and surrounded by trees . endseq',
#  'startseq Three girls walking along an arched garden pathway . endseq',
#  'startseq Three girls walk under an arbor on a path surrounded by trees . endseq',
#  'startseq Three women walking through a tunnel in a park . endseq',
#  'startseq Three women walk through a plant covered atrium hallway . endseq',
#  'startseq A girl dressed in a red top , a red cap , and light colored shorts , sits on a rock outside . endseq',
#  'startseq A little girl in a red hat and yellow flip flops sits on a rock . endseq',
#  'startseq A little girl with a red hood and shirt is sitting with legs sprawled on a rock , her mouth open . endseq',
#  'startseq A young girl wearing yellow flip-flops is sitting on a large boulder . endseq',
#  'startseq The little girl sits on top of a rock . endseq',
#  'startseq A man eats near a tent in the snow . endseq',
#  'startseq A man sitting near a tent in the snow and ice . endseq',
#  'startseq A mountaineer sits in the snow in front of a yellow tent under clear blue sky . endseq',
#  'startseq Person wearing a hooded jacket sitting on snow in front of a yellow tent . endseq',
#  'startseq Young man in hooded jacket sitting on snow in mountain area . endseq',
#  'startseq A man in a red shirt and glasses is bending down towards a small dog on a blanket with several stuffed animals . endseq',
#  'startseq A man in a red shirt is giving toys to a small dog . endseq',
#  'startseq A man is playing tug of war with his dog . endseq',
#  'startseq A man playing with a black dog on a white blanket . endseq',
#  'startseq A man playing with his dog on the blanket on the floor . endseq',
#  'startseq A guy with a nose piercing . endseq',
#  'startseq A man in a red cap with a nose ring . endseq',
#  'startseq A teenage boy has a silver ring protruding from his nose . endseq',
#  'startseq closeup picture of a man with a nose ring and a brown shirt endseq',
#  'startseq Young man with a nose ring and a hat . endseq',
#  'startseq A man is standing by a group of video games in a bar . endseq',
#  'startseq a man standing in a bar with a neon beer sign hanging on the wall endseq',
#  'startseq A man stands next to a bank of computer gambling machines . endseq',
#  'startseq A man stands next to three video game machines and a beer sign . endseq',
#  'startseq A man stands next to three video machines . endseq',
#  'startseq A big brown dog plays with a smaller grey dog on the grass . endseq',
#  'startseq The dark brown dog is playing with the light brown dog . endseq',
#  'startseq Two brown dogs are running through the grass . endseq',
#  'startseq Two brown dogs run side by side . endseq',
#  'startseq Two dogs running and playing rough in the grass . endseq',
#  'startseq A big dog catches a ball on his nose endseq',
#  'startseq A brown and black dog is jumping to catch a red ball . endseq',
#  'startseq A brown and black dog jumps for a red ball . endseq',
#  'startseq Dog jumps to get orange ball on his head . endseq',
#  'startseq The brown and black dog is jumping up to catch a red ball . endseq',
#  'startseq Parents are pushing little children in red car carts . endseq',
#  'startseq twin boys being pushed in small car shaped strollers in a parade endseq',
#  'startseq Twin toddlers dressed alike being pushed in plastic car strollers in a parade endseq',
#  'startseq Two children ride in toy cars . endseq',
#  'startseq Two kids being pushed in car shaped strollers in a parade . endseq',
#  'startseq A boys baseball team wear their uniforms . endseq',
#  'startseq A small boy smiles as he stands with others wearing the same black hats . endseq',
#  'startseq Children sporting their Florida Dolphin caps . endseq',
#  'startseq The boys are all wearing the same baseball hats . endseq',
#  'startseq Three boys wearing Florida Marlins hats . endseq',
#  'startseq A brown dog running through the grass and flowers . endseq',
#  'startseq A dog in a field . endseq',
#  'startseq A dog running in a field of grass and flowers . endseq',
#  'startseq A dog running in shrubbery along a stream . endseq',
#  'startseq A dog walks through a field . endseq',
#  'startseq A small brown and black dog endseq',
# ...
#  'startseq A boy in a grey and white shirt looking at his reflection . endseq',
#  'startseq A boy looking at his reflection . endseq',
#  'startseq A little boy looks at his reflection in a burnished marble wall . endseq',
#  'startseq The child is looking at his reflection in glass . endseq',
#  'startseq The young asian boy looks at his reflection in the park . endseq',
#  'startseq A child in all pink is posing nearby a stroller with buildings in the distance . endseq',
#  'startseq A little girl in pink dances with her hands on her hips . endseq',
#  'startseq A small girl wearing pink dances on the sidewalk . endseq',
#  'startseq The girl in a bright pink skirt dances near a stroller . endseq',
#  'startseq The little girl in pink has her hands on her hips . endseq',
#  'startseq a man sits on a rock . endseq',
#  'startseq A man sitting on a cliff in the mountains . endseq',
#  'startseq A man wearing a blue shirt crouches on a rocky cliff . endseq',
#  'startseq A person posing on a mountaintop . endseq',
#  'startseq The man is sitting at the top of a rocky mountain . endseq',
#  'startseq A close-up of a young girl with a pink shirt laying on grass . endseq',
#  'startseq A girl in a pink shirt lies on her back in the grass . endseq',
#  'startseq A girl wearing a pink shirt lays on the green grass and looks up . endseq',
#  'startseq A young girl is laying in the grass posing for the camera endseq',
#  'startseq Girl in pink shirt with white writing lying in grass . endseq',
#  'startseq A man on bicycle riding down a rocky hill . endseq',
#  'startseq A man rides his dirt bike down a rocky trail . endseq',
#  'startseq A person rides a bike down a rocky hill . endseq',
#  'startseq Blurry picture of mountain biker descending rocky trail . endseq',
#  'startseq The mountain biker in blue rides down a rocky path . endseq',
#  'startseq A little girl in a colorful dress is playing with a blue and red soccer ball . endseq',
#  'startseq A little girl in a dress playing with a soccer ball . endseq',
#  'startseq Girls in brightly-colred clothes plays with a blue ball . endseq',
#  'startseq The young girl is kicking a blue and red soccer ball . endseq',
#  'startseq Young girl in blue dress stepping over a soccer ball . endseq',
#  'startseq An adult and a child sitting on a police motorcycle . endseq',
#  'startseq A woman and a child are sitting on a motorized police vehicle . endseq',
#  'startseq A woman and a young boy sit on a police motorcycle and smile for the camera . endseq',
#  'startseq A woman and boy sit on a police motorcycle . endseq',
#  'startseq A woman and little boy sits on a police motorcycle . endseq',
#  'startseq A man in a red biker suit on a red dirt bike going down a muddy road . endseq',
#  'startseq a man in a red outfit is riding a red motorbike uphill on a motocross circuit . endseq',
#  'startseq A man in red riding gear riding a dirt bike down a path endseq',
#  'startseq A man riding a dirt bike up a muddy hill . endseq',
#  'startseq A motorcycle racer in a red jumpsuit and helmet rides up a dirt hill . endseq',
#  'startseq People walk by a display of underwear hanging in a stall . endseq',
#  'startseq Three pairs of different-colored underwear hanging from a clothesline with people and cars in the background endseq',
#  'startseq Three pairs of granny panties hanging on a line . endseq',
#  'startseq three pairs of underpants are hanging from a line under a red shelter . endseq',
#  "startseq Three pairs of women 's underwear are hanging on a wire under an awning . endseq",
#  'startseq Person standing beside bike in stream . endseq',
#  'startseq Two bicyclists pose by a stream for a picture . endseq',
#  'startseq two biker walk across the ground . endseq',
#  'startseq Two off road bikers stopped in a creek . endseq',
#  'startseq Two people , in bike gear , stand with bicycles near a rocky waterbed . endseq',
#  'startseq A girl in a coral shirt with glasses is smiling while leaning against a fence . endseq',
#  'startseq A girl wearing a pink shirt and overalls is smiling and there is another child that is out of focus . endseq',
#  'startseq Children playing in stopped motion endseq',
#  'startseq Two children are standing on a green metal fence . endseq',
#  'startseq Two girls , one in overalls , holding on to a fence with water behind them . endseq',
#  'startseq A boy has his head down and is wearing a shirt that says ADHD . endseq',
#  'startseq a young boy wearing a clever black and white shirt with his head bowed down endseq',
#  'startseq The boy is wearing a black t-shirt with an AD parody of the AC logo . endseq',
#  'startseq Young boy wearing an AC t-shirt looking down . endseq',
#  'startseq Young boy with a black " ADHD " t-shirt nodding off endseq',
#  'startseq A boy playing in a lake endseq',
#  'startseq A child is splashing in the water endseq',
#  'startseq A little boy is playing in the water with a beautiful sunset and mountains in the background . endseq',
#  'startseq A small child in water with a splash encircling him while the white clouds float over the mountains . endseq',
#  'startseq A young boy plays in the water with the mountains in the background . endseq',
#  'startseq A little girl with arms outstretched plays with others at a sprinkler park . endseq',
#  'startseq Children play in a water fountain . endseq',
#  'startseq Children playing in public waterspouts . endseq',
#  'startseq The two young girls , one wearing a skirt and the other wearing shorts , are playing in a bubbling fountain . endseq',
#  'startseq Two kids playing in a fountain at a water park . endseq',
#  'startseq A person drives in a red car . endseq',
#  'startseq A person in a red car , with a bridge in the background . endseq',
#  'startseq A person waits inside a red compact car . endseq',
#  'startseq A red car driving over a bridge . endseq',
#  'startseq The lady in the red car is crossing the bridge . endseq',
#  'startseq A girl with a black purse sitting on a wooden bench . endseq',
#  'startseq A woman sits alone on a park bench in the sun . endseq',
#  'startseq A woman with a handbag is sitting on a wooden bench . endseq',
#  'startseq A young asian woman wearing long shorts and a gray collared t-shirt is sitting on a wooden bench . endseq',
#  'startseq A young woman with a black purse sits on a wooden bench . endseq',
#  'startseq A girl in a white shirt is sitting on a park bench with a dog next to her . endseq',
#  'startseq A woman eats on a bench while a brown and white leashed dog stands next to her . endseq',
#  'startseq a woman is sitting on a bench with a latte in her lap and a white dog on a blue leash to her side . endseq',
#  'startseq A woman sits on a bench at the park with her dog in front of her . endseq',
#  'startseq Woman sitting on bench and holding the leash of a large white and brown dog . endseq',
#  'startseq A baby girl is attempting to climb out of her green crib endseq',
#  'startseq A baby in pigtails tries to climb out of their playpen . endseq',
#  'startseq A female toddler in pigtails is trying to climb out of a green and white playpen . endseq',
#  'startseq A toddler is in a green playpen . endseq',
#  'startseq Baby with blonde pigtails in yellow room attempting to climb out of green playpen . endseq',
#  'startseq A man in a red jacket looking out over snow-covered mountains . endseq',
#  'startseq A man in red snow gear looks at an expanse of snow and mountains . endseq',
#  'startseq A person in a red and black ski outfit is looking over a snowy , mountainous landscape . endseq',
#  'startseq A person in a red coat looking out at a snowy landscape . endseq',
#  'startseq View from the summit endseq',
#  'startseq A boy in blue with a football sprawls in the grass . endseq',
#  'startseq A boy laying on the grass face down with a football at his feet . endseq',
#  'startseq Boy is lying face down in the grass with his foot on a football . endseq',
#  'startseq The boy is on the ground next to the football . endseq',
#  'startseq The little boy fell face first into the grass while playing football . endseq',
#  'startseq girls seated at table with a candle covered with lit candles endseq',
#  'startseq A birthday celebration taking place for a girl who has reached age 5 . endseq',
#  'startseq Boy and his family celebrating his birthday with a brightly lit cake . endseq',
#  'startseq Smiling children gathered around a birthday cake endseq',
#  'startseq Woman and four little girls , near cake with candles . endseq',
#  'startseq A black dog runs after another black dog who is carrying a ball . endseq',
#  'startseq Two black dogs are running on pavement endseq',
#  'startseq Two black dogs are trotting through an empty public area . endseq',
#  'startseq Two black dogs running endseq',
#  'startseq Two dogs are playing on a hardscape . endseq',
#  'startseq About 12 kids and a few adults get splashed by an off camera source . endseq',
#  'startseq A group of children are in a water fountain . endseq',
#  'startseq A group of children standing in a shallow pool of water . endseq',
#  'startseq A group of young kids play in the water on a sunny day . endseq',
#  'startseq Children and adults play with a sprinkler . endseq',
#  'startseq A man standing on a rocky mountain with gray clouds in the background . endseq',
#  'startseq A man without a shirt is walking on top of lots of rocks . endseq',
#  'startseq A shirtless man is walking on a rocky hill endseq',
#  'startseq A shirtless man with a backpack . endseq',
#  'startseq A topless person with a backpack is shown against on a pile of rocks with a cloudy background . endseq',
#  'startseq A boy dressed in khaki shorts and a red shirt runs on a beach with green , white and blue structures and a half moon behind him . endseq',
#  'startseq A boy in a red sweater running on the beach endseq',
#  'startseq A boy wearing a red shirt runs along a beach . endseq',
#  'startseq A boy wearing a red sweater runs along a colorful beach . endseq',
#  'startseq Young boy in red runs on beach and passes white , blue and green beach huts . endseq',
#  'startseq A boat on a lake . endseq',
#  'startseq A wakeboarder flies sideways in the air . endseq',
#  'startseq A waterskier performs tricks . endseq',
#  'startseq A waterskiing man does a flip behind a speedboat . endseq',
#  'startseq The waterskier does a flip behind a boat . endseq',
#  'startseq A man is pulled behind a boat on a knee board while another doing the same begins to fall . endseq',
#  'startseq Two boys wakeboard . endseq',
#  'startseq Two boys waterskiing . endseq',
#  'startseq Two people are wakeboarding in the water and are being pulled by a boat . endseq',
#  'startseq Two younger people are being pulled on watercraft behind a boat . endseq',
#  'startseq Children sit and watch the fish moving in the pond endseq',
#  'startseq people stare at the orange fish . endseq',
#  'startseq Several people are standing near a fish pond . endseq',
#  'startseq Some children watching fish in a pool . endseq',
#  'startseq There are several people and children looking into water with a blue tiled floor and goldfish . endseq',
#  'startseq a boy in white plays baseball . endseq',
#  'startseq A young boy is getting ready to through a baseball endseq',
#  'startseq Little leaguer getting ready for pitch endseq',
#  'startseq The boy is wearing a white baseball uniform and holding a baseball . endseq',
#  'startseq The young Ohio baseball player contemplates his pitch . endseq',
#  'startseq a african-american woman stands in the crowd . endseq',
#  'startseq A dark-skinned woman in a blue dress is standing near a crowd . endseq',
#  'startseq A girl in a blue dress walks through a crowd of people . endseq',
#  'startseq A woman in a blue dress stands in a crowd . endseq',
#  'startseq The back of a lady wearing a blue halter top is shown , a crowd in the distance . endseq',
#  'startseq A boy with his mouth open and tongue sticking out clinging to a bar next to a platform . endseq',
#  'startseq A chidl climbs a latter as he sticks out his tongue . endseq',
#  'startseq A small boy climbing a backyard play set . endseq',
#  'startseq A young boy with his tongue stuck out is climbing onto a wooden platform . endseq',
#  'startseq The boy is climbing . endseq',
#  'startseq A black and tan dog in the snow endseq',
#  'startseq A Brown furry husky dog sticking out his tongue . endseq',
#  'startseq A dog wearing a blue harness stands in the snow and pants . endseq',
#  'startseq A Husky dog wearing green straps is turning its head away from the object in front of it . endseq',
#  'startseq A husky dog wearing the gear to pull a sled . endseq',
#  'startseq A snow dog in a red harness . endseq',
#  'startseq A white dog and a brown dog attached by harnesses . endseq',
#  'startseq A white dog with red straps on it is looking back . endseq',
#  'startseq The dog has red straps in its back . endseq',
#  'startseq The dogs are joined together with a red harness . endseq',
#  'startseq A black and a white dog on the snow . endseq',
#  'startseq A black dog and a white dog are standing on snow . endseq',
#  'startseq Two dogs , one black and one white , face the camera in a field of snow . endseq',
#  'startseq Two dogs standing in the snow . endseq',
#  'startseq two dogs stand in the snow . endseq',
#  'startseq A big brown dog is jumping in the water and has his mouth wide open . endseq',
#  'startseq A brown dog barks over its shoulder in the water . endseq',
#  'startseq A dog jumping in the water at a beack . endseq',
#  'startseq A dog runs through the water as he looks up at the sky with his mouth open . endseq',
#  'startseq A dog with a collar running through the water endseq',
#  'startseq a brown dog is leaping into a garden swimming pool . endseq',
#  'startseq A brown dog leaps into a swimming pool . endseq',
#  'startseq A brown , fluffy dog jumping into a swimming pool after a red toy . endseq',
#  'startseq A dog jumps into a swimming pool after a toy . endseq',
#  'startseq A dog takes a leap of faith as he jumps into a pool to grab an orange toy . endseq',
#  'startseq A dog jumps for a red ball on the grass . endseq',
#  'startseq A white dog is jumping in the air attempting to catch a red ball . endseq',
#  'startseq A white dog jumping to catch a red ball . endseq',
#  'startseq A white dog with a blue collar plays with a red ball . endseq',
#  'startseq The dog is playing with a red ball . endseq',
#  'startseq A boy jumps from one picnic table to another . endseq',
#  'startseq A boy jumps from one table to another at a park . endseq',
#  'startseq A child is walking from one picnic table to another . endseq',
#  'startseq A young boy is running on picnic tables at a park . endseq',
#  'startseq The boy hops from one picnic table to the other in the park . endseq',
#  'startseq A woman crouches down next to her terrier dog to smile at a little girl sitting on the sidewalk . endseq',
#  'startseq A woman in a red top and a small dog talks to a young girl . endseq',
#  'startseq A woman showing a small dog to an infant endseq',
#  'startseq A woman squatting to face a small child while holding a dog . endseq',
#  'startseq a woman with a brown dog is talking to a toddler who is sat on the ground . endseq',
#  'startseq A female artist showing her painting and signing a paper . endseq',
#  'startseq A man on a phone and woman sitting near a painting . endseq',
#  'startseq A woman drawing portrait while a man on a cellphone watches . endseq',
#  'startseq A woman writing on a notepad near a portrait outdoors endseq',
#  "startseq Standing man on phone with seated woman writing , near artist 's outdoor display . endseq",
#  'startseq A girl dressed in a red and black top with black pants is sitting on a wall . endseq',
#  'startseq A girl in a red and black striped shirt sits on a brick wall in front of a tropical plant . endseq',
#  'startseq A girl wearing a red and black striped shirt is sitting on a brick wall near a flower garden . endseq',
#  'startseq A lady in a red and black striped shirt is sitting on a retaining wall . endseq',
#  'startseq A woman in semi-formal attire is sitting on a concrete wall . endseq',
#  ...]

# %%
number_of_captions = len(descriptions_from_dict_to_list)

# %%
print(number_of_captions)
# Out:
# 30000

# %%
from numpy import array
from pickle import load
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers import add
from keras.callbacks import ModelCheckpoint

# %%
# create sequences of images, input sequences and output words for an image
def create_sequences(tokenizer, max_length, desc_list, photo, vocab_size):
	X1, X2, y = list(), list(), list()
	# walk through each description for the image
	for desc in desc_list:
		# encode the sequence
		seq = tokenizer.texts_to_sequences([desc])[0]
		# split one sequence into multiple X,y pairs
		for i in range(1, len(seq)):
			# split into input and output pair
			in_seq, out_seq = seq[:i], seq[i]
			# pad input sequence
			in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
			# encode output sequence
			out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
			# store
			X1.append(photo)
			X2.append(in_seq)
			y.append(out_seq)
	return array(X1), array(X2), array(y)

# %%
sample_list =[]
for i in range(0,6):
    sample_list.append(descriptions_from_dict_to_list[i])

# %%
sample_list
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq A girl going into a wooden building . endseq',
#  'startseq A little girl climbing into a wooden playhouse . endseq',
#  'startseq A little girl climbing the stairs to her playhouse . endseq',
#  'startseq A little girl in a pink dress going into a wooden cabin . endseq',
#  'startseq A black dog and a spotted dog are fighting endseq']

# %%
photo = train_features['1000268201_693b08cb0e']

# %%
photo
# Out:
# array([[2.507474, 0.      , 0.      , ..., 0.      , 0.      , 0.      ]],
#       dtype=float32)

# %%
# Define the captioning model
def define_model(vocab_size, max_length):
    # Feature extractor model
    inputs1 = Input(shape=(4096,))
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(256, activation='relu')(fe1)
    fe3 = Dropout(0.5)(fe2)
    fe4 = Dense(256, activation='relu')(fe3)  # Corrected variable name fe4

    # Sequence model
    inputs2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size, 500, mask_zero=True)(inputs2)
    se2 = Dropout(0.5)(se1)
    se3 = LSTM(256)(se2)

    # Decoder model
    decoder1 = add([fe4, se3])  # Use fe4 instead of fe2
    decoder2 = Dense(256, activation='relu')(decoder1)
    decoder3 = Dense(256, activation='relu')(decoder2)

    outputs = Dense(vocab_size, activation='softmax')(decoder3)

    # Tie it together [image, seq] [word]
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

    # Summarize model
    print(model.summary())
    plot_model(model, to_file='model.png', show_shapes=True)

    return model

# %%
# data generator, intended to be used in a call to model.fit_generator()
def data_generator(descriptions, photos, tokenizer, max_length, vocab_size):
	# loop for ever over images
	while 1:
		for key, desc_list in descriptions.items():
			# retrieve the photo feature
			photo = photos[key][0]
			in_img, in_seq, out_word = create_sequences(tokenizer, max_length, desc_list, photo, vocab_size)
			yield [in_img, in_seq], out_word

# %%
# load training dataset (6K)
filename = '/content/drive/My Drive/Capstone Data/flickr8k/Flickr8k_text/Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('/content/drive/My Drive/Capstone Data/flickr8k/descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('/content/drive/My Drive/Capstone Data/features.pkl', train)
print('Photos: train=%d' % len(train_features))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
# prepare sequences
X1train, X2train, ytrain = create_sequences(tokenizer, max_length, train_descriptions, train_features, vocab_size)
# Out:
# Dataset: 6000
# Descriptions: train=6000
# Photos: train=6000
# Vocabulary Size: 7378
# Description Length: 40

# %%
# load test set
filename = '/content/drive/My Drive/Capstone Data/flickr8k/Flickr8k_text/Flickr_8k.devImages.txt'
test = load_set(filename)
print('Dataset: %d' % len(test))
# descriptions
test_descriptions = load_clean_descriptions('/content/drive/My Drive/Capstone Data/flickr8k/descriptions.txt', test)
print('Descriptions: test=%d' % len(test_descriptions))
# photo features
test_features = load_photo_features('/content/drive/My Drive/Capstone Data/features.pkl', test)
print('Photos: test=%d' % len(test_features))
# prepare sequences
X1test, X2test, ytest = create_sequences(tokenizer, max_length, test_descriptions, test_features, vocab_size)
# Out:
# Dataset: 1000
# Descriptions: test=1000
# Photos: test=1000

# %%
generator = data_generator(train_descriptions, train_features, tokenizer, max_length, vocab_size)

# %%
# define the model
model = define_model(vocab_size, max_length)
# define checkpoint callback
filepath = 'model-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 4096)]               0         []
#
#  dropout (Dropout)           (None, 4096)                 0         ['input_1[0][0]']
#
#  input_2 (InputLayer)        [(None, 40)]                 0         []
#
#  dense (Dense)               (None, 256)                  1048832   ['dropout[0][0]']
#
#  embedding (Embedding)       (None, 40, 500)              3689000   ['input_2[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense[0][0]']
#
#  dropout_2 (Dropout)         (None, 40, 500)              0         ['embedding[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  65792     ['dropout_1[0][0]']
#
#  lstm (LSTM)                 (None, 256)                  775168    ['dropout_2[0][0]']
#
#  add (Add)                   (None, 256)                  0         ['dense_1[0][0]',
#                                                                      'lstm[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  65792     ['add[0][0]']
#
#  dense_3 (Dense)             (None, 256)                  65792     ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 7378)                 1896146   ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 7606522 (29.02 MB)
# Trainable params: 7606522 (29.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
# train the model, run epochs manually and save after each epoch
batch_size = 4
epochs = 20
steps = int(len(train_descriptions)/batch_size)

for i in range(epochs):
   # create the data generator
   generator = data_generator(train_descriptions, train_features, tokenizer, max_length, vocab_size)
   # fit for one epoch
   model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
   #save model
   model.save('/content/drive/My Drive/Capstone Data/Saved_Models2/model_' + str(i) + '.h5')
# Out:
# <ipython-input-49-abd36aa3f8c4>:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# 1500/1500 [==============================] - 228s 152ms/step - loss: 4.3720 - accuracy: 0.2720
# 1500/1500 [==============================] - 227s 151ms/step - loss: 4.1478 - accuracy: 0.3048
# 1500/1500 [==============================] - 227s 151ms/step - loss: 4.0374 - accuracy: 0.3176
# 1500/1500 [==============================] - 228s 152ms/step - loss: 3.9705 - accuracy: 0.3270
#  862/1500 [================>.............] - ETA: 1:37 - loss: 3.9608 - accuracy: 0.3311
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-abd36aa3f8c4> in <cell line: 6>()
#       8    generator = data_generator(train_descriptions, train_features, tokenizer, max_length, vocab_size)
#       9    # fit for one epoch
# ---> 10    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
#      11    #save model
#      12    model.save('/content/drive/My Drive/Capstone Data/Saved_Models2/model_' + str(i) + '.h5')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2808             stacklevel=2,
#    2809         )
# -> 2810         return self.fit(
#    2811             generator,
#    2812             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1740                         ):
#    1741                             callbacks.on_train_batch_begin(step)
# -> 1742                             tmp_logs = self.train_function(iterator)
#    1743                             if data_handler.should_sync:
#    1744                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     823
#     824       with OptionalXlaContext(self._jit_compile):
# --> 825         result = self._call(*args, **kwds)
#     826
#     827       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     855       # In this case we have created variables on the first call, so we run the
#     856       # defunned version which is guaranteed to never create variables.
# --> 857       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858     elif self._variable_creation_fn is not None:
#     859       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     146       (concrete_function,
#     147        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148     return concrete_function._call_flat(
#     149         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     150
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs)
#    1347         and executing_eagerly):
#    1348       # No tape is watching; skip to running the function.
# -> 1349       return self._build_call_outputs(self._inference_function(*args))
#    1350     forward_backward = self._select_forward_and_backward_functions(
#    1351         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     194         with record.stop_recording():
#     195           if self._bound_context.executing_eagerly():
# --> 196             outputs = self._bound_context.call_function(
#     197                 self.name,
#     198                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1455     cancellation_context = cancellation.context()
#    1456     if cancellation_context is None:
# -> 1457       outputs = execute.execute(
#    1458           name.decode("utf-8"),
#    1459           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None
import numpy as np
# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
	# seed the generation process
	in_text = 'startseq'
	# iterate over the whole length of the sequence
	for i in range(max_length):
		# integer encode input sequence
		sequence = tokenizer.texts_to_sequences([in_text])[0]
		# pad input
		sequence = pad_sequences([sequence], maxlen=max_length)
		# predict next word
		yhat = model.predict([photo,sequence], verbose=0)
		# convert probability to integer
		yhat = np.argmax(yhat)
		# map integer to word
		word = word_for_id(yhat, tokenizer)
		# stop if we cannot map the word
		if word is None:
			break
		# append as input for generating the next word
		in_text += ' ' + word
		# stop if we predict the end of the sequence
		if word == 'endseq':
			break
	return in_text

# %%
from nltk.translate import bleu
from nltk.translate.bleu_score import corpus_bleu

# %%
# evaluate the skill of the model
def evaluate_model(model, descriptions, photos, tokenizer, max_length):
	actual, predicted = list(), list()
	# step over the whole set
	for key, desc_list in descriptions.items():
		# generate description
		yhat = generate_desc(model, tokenizer, photos[key], max_length)
		# store actual and predicted
		references = [d.split() for d in desc_list]
		actual.append(references)
		predicted.append(yhat.split())
    # calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# %%
# prepare tokenizer on train set

# load training dataset (6K)
filename = '/content/drive/My Drive/Capstone Data/flickr8k/Flickr8k_text/Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('/content/drive/My Drive/Capstone Data/flickr8k/descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
# Out:
# Dataset: 6000
# Descriptions: train=6000
# Vocabulary Size: 7378
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-877a86a7d239> in <cell line: 15>()
#      13 print('Vocabulary Size: %d' % vocab_size)
#      14 # determine the maximum sequence length
# ---> 15 max_length = max_length(train_descriptions)
#      16 print('Description Length: %d' % max_length)
#
# TypeError: 'int' object is not callable

# %%
from keras.models import load_model

# %% [markdown]
# ##Test Data

# %%
#extract features from each photo in the directory
def extract_features(directory):
	# load the model
	model = VGG16()
	# re-structure the model
	model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
	# summarize
	print(model.summary())
	# extract features from each photo
	features = dict()
	for name in listdir(directory):
		# load an image from file
		filename = directory + '/' + name
		image = load_img(filename, target_size=(224, 224))
		# convert the image pixels to a numpy array
		image = img_to_array(image)
		# reshape data for the model
		image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
		# prepare the image for the VGG model
		image = preprocess_input(image)
		# get features
		feature = model.predict(image, verbose=0)
		# get image id
		image_id = name.split('.')[0]
		# store feature
		features[image_id] = feature
		print('>%s' % name)
	return features

# extract features from all images
directory = "flickr8K/Images"
features = extract_features(directory)
print('Extracted Features: %d' % len(features))
# save to file
dump(features, open('features.pkl', 'wb'))

# %%
# prepare test set

# load test set
filename = '/content/drive/My Drive/Capstone Data/flickr8k/Flickr8k_text/Flickr_8k.testImages.txt'
test = load_set(filename)
print('Dataset: %d' % len(test))
# descriptions
test_descriptions = load_clean_descriptions('/content/drive/My Drive/Capstone Data/descriptions.txt', test)
print('Descriptions: test=%d' % len(test_descriptions))
# photo features
test_features = load_photo_features('/content/drive/My Drive/Capstone Data/features.pkl', test)
print('Photos: test=%d' % len(test_features))

# load the model
filename = '/content/drive/My Drive/Capstone Data/Saved_Models/model_49.h5'
model = load_model(filename)
# Out:
# Dataset: 1000
# Descriptions: test=1000
# Photos: test=1000

# %%
# evaluate model
evaluate_model(model, test_descriptions, test_features, tokenizer, max_length)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-d1a8ee4451ee> in <cell line: 2>()
#       1 # evaluate model
# ----> 2 evaluate_model(model, test_descriptions, test_features, tokenizer, max_length)
#
# <ipython-input-45-df41671e6bb8> in evaluate_model(model, descriptions, photos, tokenizer, max_length)
#       5         for key, desc_list in descriptions.items():
#       6                 # generate description
# ----> 7                 yhat = generate_desc(model, tokenizer, photos[key], max_length)
#       8                 # store actual and predicted
#       9                 references = [d.split() for d in desc_list]
#
# <ipython-input-43-c3f8185645b7> in generate_desc(model, tokenizer, photo, max_length)
#      17                 sequence = pad_sequences([sequence], maxlen=max_length)
#      18                 # predict next word
# ---> 19                 yhat = model.predict([photo,sequence], verbose=0)
#      20                 # convert probability to integer
#      21                 yhat = np.argmax(yhat)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2519                     )
#    2520
# -> 2521             data_handler = data_adapter.get_data_handler(
#    2522                 x=x,
#    2523                 batch_size=batch_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1676             return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1677         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1678     return DataHandler(*args, **kwargs)
#    1679
#    1680
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1283
#    1284         adapter_cls = select_data_adapter(x, y)
# -> 1285         self._adapter = adapter_cls(
#    1286             x,
#    1287             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     353         indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     354
# --> 355         dataset = self.slice_inputs(indices_dataset, inputs)
#     356
#     357         if shuffle == "batch":
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     394             )
#     395
# --> 396         dataset = dataset.map(grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     397
#     398         # Default optimizations are disabled to avoid the overhead of
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2276     # pylint: disable=g-import-not-at-top,protected-access
#    2277     from tensorflow.python.data.ops import map_op
# -> 2278     return map_op._map_v2(
#    2279         self,
#    2280         map_func,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/map_op.py in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      38         input_dataset, map_func, preserve_cardinality=True, name=name)
#      39   else:
# ---> 40     return _ParallelMapDataset(
#      41         input_dataset,
#      42         map_func,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/map_op.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     146     self._input_dataset = input_dataset
#     147     self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 148     self._map_func = structured_function.StructuredFunctionWrapper(
#     149         map_func,
#     150         self._transformation_name(),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     270         fn_factory = trace_tf_function(defun_kwargs)
#     271
# --> 272     self._function = fn_factory()
#     273     # There is no graph to add in eager mode.
#     274     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1187   def get_concrete_function(self, *args, **kwargs):
#    1188     # Implements GenericFunction.get_concrete_function.
# -> 1189     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1190     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1191     return concrete
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1167       if self._variable_creation_fn is None:
#    1168         initializers = []
# -> 1169         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1170         self._initialize_uninitialized_variables(initializers)
#    1171
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     692     # Force the definition of the function for these arguments
#     693     self._concrete_variable_creation_fn = (
# --> 694         self._variable_creation_fn    # pylint: disable=protected-access
#     695         ._get_concrete_function_internal_garbage_collected(
#     696             *args, **kwds))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#     174     """Returns a concrete function which cleans up its graph function."""
#     175     with self._lock:
# --> 176       concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     177     return concrete_function
#     178
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_concrete_function(self, args, kwargs)
#     169       kwargs = {}
#     170
# --> 171     return self._maybe_define_function(args, kwargs)
#     172
#     173   def _get_concrete_function_internal_garbage_collected(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_function(self, args, kwargs)
#     380         with ag_ctx.ControlStatusCtx(
#     381             status=ag_status, options=self._autograph_options):
# --> 382           func_graph = func_graph_module.FuncGraph(
#     383               self._name, capture_by_value=self._capture_by_value)
#     384           if self.input_signature is None and self._reduce_retracing:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in __init__(self, name, collections, capture_by_value, structured_input_signature, structured_outputs)
#     190         information.
#     191     """
# --> 192     super().__init__()
#     193     self.name = name
#     194     # TODO(panzf): Separate captures from non-captures inputs in self.inputs
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in __init__(self)
#    2690   def __init__(self):
#    2691     """Creates a new, empty Graph."""
# -> 2692     super().__init__()
#    2693     # Protects core state that can be returned via public accessors.
#    2694     # Thread-safety is provided on a best-effort basis to support buggy
#
# KeyboardInterrupt:

# %%
'''
from tensorflow.keras.preprocessing.image import load_img
from keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import img_to_array
from keras.models import load_model
from keras.applications.vgg16 import preprocess_input
from keras.models import Model
'''

# %%
'''
# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
'''

# %%
'''
def extract_features(filename):
    # load the model
    model = VGG16()
    # re-structure the model
    model.layers.pop()
    model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
    # load the photo
    image = load_img(filename, target_size=(224, 224))
    # convert the image pixels to a numpy array
    image = img_to_array(image)
    # reshape data for the model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    # prepare the image for the VGG model
    image = preprocess_input(image)
    # get features
    feature = model.predict(image, verbose=0)
    return feature
'''

# %%
'''
import cv2
import numpy as np
import matplotlib.pyplot as plt
'''

# %%
'''
#Image downloaded from internet and given to the model to generate a caption
img_to_test = "/content/drive/My Drive/Capstone Data/flickr8k/children_playing.jpg"
img = cv2.imread(img_to_test)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
'''

# %%
'''
# pre-define the max sequence length (from training)
max_length = 40
tokenizer = create_tokenizer(train_descriptions)
# load the model
model = load_model('/content/drive/My Drive/Capstone Data/flickr8k/model_7.h5')
# load and prepare the photograph
photo = extract_features(img_to_test)
'''

# %%
'''
generate description
description = generate_desc(model, tokenizer, photo, max_length)
description = ' '.join(description.split()[1:-1])
'''

# %%
#description
