# %%
pip install gtts

# %%
from gtts import gTTS
from IPython.display import Audio, display
from PIL import Image
from IPython.display import display as ipy_display
import io
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gtts import gTTS
from IPython.display import Audio, display
from PIL import Image
from IPython.display import display as ipy_display
import io

def text_to_speech_with_image(text, image_path, output_folder, filename="output.mp3"):
    # Create a gTTS object from the input text
    tts = gTTS(text)

    # Define the full path for the output audio file
    output_path = os.path.join(output_folder, filename)

    # Save the speech as an audio file
    tts.save(output_path)



    # Display the image related to the text
    image = Image.open(image_path)
    ipy_display(image)

    # Display the input text
    print("Input Text:")
    print(text)

    # Play the generated audio using IPython Audio widget
    with open(output_path, 'rb') as audio_file:
        audio_data = audio_file.read()
        display(Audio(data=audio_data, autoplay=True))

# Example usage:
text = "Hello, this is a text-to-speech conversion example."
image_path = 'your_image.png'  # Replace with the path to your image file
output_folder = '/content'  # Update this with your desired folder path
text_to_speech_with_image(text, image_path, output_folder)

# %%
def text_to_speech_with_image(text, image_path, output_folder, filename="output.mp3"):
    # Create a gTTS object from the input text
    tts = gTTS(text)

    # Define the full path for the output audio file
    output_path = os.path.join(output_folder, filename)

    # Save the speech as an audio file
    tts.save(output_path)

    # Display the input text
    print("Input Text:")
    print(text)

    with Image.open(image_path) as img:
      img = img.resize((15, 12))
      display(IPImage(data=io.BytesIO(img.tobytes())))

    # Play the generated audio using IPython Audio widget
    with open(output_path, 'rb') as audio_file:
        audio_data = audio_file.read()
        display(Audio(data=audio_data, autoplay=True))

# %%
from gtts import gTTS
from IPython.display import Audio, display, Image as IPImage
from PIL import Image
import io
import os

# %%
# Example usage:
text = "Hello, this is a text-to-speech conversion example."
image_path = '/content/drive/MyDrive/Capstone Data/flickr8k/bird.png'  # Replace with the path to your image file
output_folder = '/content/drive/MyDrive/Capstone Data/Audio'  # Update this with your desired folder path
text_to_speech_with_image(text, image_path, output_folder)
# Out:
# Input Text:
# Hello, this is a text-to-speech conversion example.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not '_io.BytesIO'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
import cv2

# %%
def text_to_speech_with_image(text, image_path, output_folder):

    # Create a gTTS object from the input text
    tts = gTTS(text)

    # Define the output audio filename
    filename = "output.mp3"

    # Define the full path for the output audio file
    output_path = os.path.join(output_folder, filename)

    # Save the speech as an audio file
    tts.save(output_path)

    # Display the input text
    print("Input Text:")
    print(text)

    # Read and display the image related to the text using cv2
    image = cv2.imread(image_path)
    display(Audio(data=audio_data, autoplay=True))
    cv2.imshow('Image Related to Text', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Example usage:
text = "Hello, this is a text-to-speech conversion example."
image_path = '/content/drive/MyDrive/Capstone Data/flickr8k/bird.png'  # Replace with the path to your image file
output_folder = '/content/drive/MyDrive/Capstone Data/Audio'  # Update this with your desired folder path
text_to_speech_with_image(text, image_path, output_folder)
# Out:
# Input Text:
# Hello, this is a text-to-speech conversion example.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f65e82f168fc> in <cell line: 30>()
#      28 image_path = '/content/drive/MyDrive/Capstone Data/flickr8k/bird.png'  # Replace with the path to your image file
#      29 output_folder = '/content/drive/MyDrive/Capstone Data/Audio'  # Update this with your desired folder path
# ---> 30 text_to_speech_with_image(text, image_path, output_folder)
#
# <ipython-input-11-f65e82f168fc> in text_to_speech_with_image(text, image_path, output_folder)
#      19     # Read and display the image related to the text using cv2
#      20     image = cv2.imread(image_path)
# ---> 21     display(Audio(data=audio_data, autoplay=True))
#      22     cv2.imshow('Image Related to Text', image)
#      23     cv2.waitKey(0)
#
# NameError: name 'audio_data' is not defined
